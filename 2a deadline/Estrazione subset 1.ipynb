# %%
import pandas as pd

df = pd.read_csv("../data/data_prepared_python.csv")

# %%
df.head(100)
# Out:
#                filename filing_date publication_date priority_date  \
# 0   US2009216698_A1.txt  2008-02-22       2009-08-27    2008-02-22
# 1   US2020018760_A1.txt  2019-09-23       2020-01-16    2007-03-27
# 2      EP3340117_A1.txt  2017-11-15       2018-06-27    2016-12-20
# 3   WO2019070570_A1.txt  2018-10-01       2019-04-11    2017-10-06
# 4   US2016259635_A1.txt  2015-03-04       2016-09-08    2015-03-04
# ..                  ...         ...              ...           ...
# 95  US2019052676_A1.txt  2018-08-08       2019-02-14    2017-08-08
# 96     EP3742675_A1.txt  2020-01-24       2020-11-25    2019-05-24
# 97    CN111369631_A.txt  2020-03-06       2020-07-03    2020-03-06
# 98    US10476391_B2.txt  2017-05-15       2019-11-12    2016-05-20
# 99  US2019130909_A1.txt  2017-04-13       2019-05-02    2016-04-18
#
#                                           ipc_classes  \
# 0                                  G06F15/18,G06N5/02
# ...

# %%
df.isna().sum()
# Out:
# filename                0
# filing_date             0
# publication_date        0
# priority_date           0
# ipc_classes           925
# assignee             1733
# inventors             530
# docdb_family_id         0
# title                   0
# abstract             3092
# claims              82443
# dtype: int64

# %%
df_subset_1 = df.dropna(subset=["claims"])

df_subset_1.isna().sum()
# Out:
# filename               0
# filing_date            0
# publication_date       0
# priority_date          0
# ipc_classes          614
# assignee            1589
# inventors            168
# docdb_family_id        0
# title                  0
# abstract            2116
# claims                 0
# dtype: int64

# %%
df_subset_1.to_csv("../data/data_subset1.csv", index=None)

# %%
df_subset_1["contains"] = df_subset_1.claims.apply(lambda x: "nails" in x)
# Out:
# <ipython-input-11-ae3d60ab1260>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subset_1["contains"] = df_subset_1.claims.apply(lambda x: "nails" in x)

# %%
df_subset_1[df_subset_1.contains == True]
# Out:
#                    filename filing_date publication_date priority_date  \
# 5218    US2018217731_A1.txt  2018-01-25       2018-08-02    2017-01-31
# 9238      US10838697_B2.txt  2018-09-19       2020-11-17    2014-12-29
# 10555   US2009232409_A1.txt  2008-03-17       2009-09-17    2008-03-17
# 15433   US2018055407_A1.txt  2017-08-25       2018-03-01    2016-08-25
# 17368      US7024636_B2.txt  2002-11-20       2006-04-04    2002-11-20
# ...                     ...         ...              ...           ...
# 288928  US2013063495_A1.txt  2011-09-10       2013-03-14    2011-09-10
# 289872     US9055343_B1.txt  2013-06-07       2015-06-09    2013-06-07
# 290976  US2013088517_A1.txt  2010-01-28       2013-04-11    2009-01-28
# 294015     US8189880_B2.txt  2007-05-29       2012-05-29    2007-05-29
# 294926  US2014111547_A1.txt  2014-01-02       2014-04-24    2010-01-05
#
#                                               ipc_classes  \
# ...
