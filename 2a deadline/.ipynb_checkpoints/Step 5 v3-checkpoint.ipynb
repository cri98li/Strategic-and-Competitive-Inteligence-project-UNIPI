# %%
import pandas as pd
from tqdm.auto import tqdm
import numpy as np

pd.set_option('display.max_columns', 500)
pd.set_option('display.max_colwidth', 300)
pd.set_option('display.max_rows', 300)

# %%
import json

with open("../data/fix_ipc_class_dict.json") as json_file:
    ipc_class_dict = json.load(json_file)

# %%
#df = pd.read_csv("../data/subest1_filtrato.csv")
df = pd.read_csv("../data/data_subset1.csv")

# %%
df.title = df.title.str.lower()
df.abstract = df.abstract.str.lower()
df.claims = df.claims.str.lower()
df.ipc_classes = df.ipc_classes.apply(lambda x: x.replace(",", ", ") if type(x)==str else "")

# %%
df.head()
# Out:
#               filename filing_date publication_date priority_date  \
# 0  US2009216698_A1.txt  2008-02-22       2009-08-27    2008-02-22
# 1  US2020018760_A1.txt  2019-09-23       2020-01-16    2007-03-27
# 2     EP3340117_A1.txt  2017-11-15       2018-06-27    2016-12-20
# 3  WO2019070570_A1.txt  2018-10-01       2019-04-11    2017-10-06
# 4  US2016259635_A1.txt  2015-03-04       2016-09-08    2015-03-04
#
#                                                                 ipc_classes  \
# 0                                                       G06F15/18, G06N5/02
# 1                                                                G01N33/574
# 2                                                       G06N3/04, G06N3/063
# 3                                                                 A61B5/103
# 4  G06F15/18, G06F17/27, G06F8/65, G06F8/71, G06F9/44, G06F9/445, G06N99/00
#
#                                                   assignee  \
# 0  XEROX CORPORATIONANDREOLI, JEAN-MARCBOUCHARD, GUILLAUME
# 1                                                IMMUNOVIA
# 2                                        INTEL CORPORATION
# 3                                          TELLUS YOU CARE
# 4        IBM (INTERNATIONAL BUSINESS MACHINES CORPORATION)
#
#                                                                   inventors  \
# 0                                    ANDREOLI, JEAN-MARCBOUCHARD, GUILLAUME
# 1            BORREBAECK, CARL, ARNE, KRISTERWINGREN, LARS, BERTIL, CHRISTER
# 2                                                            LIN, TSUNG-HAN
# 3                                                      HSU KEVINCOKE, TANIA
# 4  EL MAGHRAOUI, KAOUTARJANN, JOEFONPATTNAIK, PRATAP C.PICKOVER CLIFFORD A.
#
#    docdb_family_id  \
# 0         40999265
# 1         39493874
# 2         60327233
# 3         65993331
# 4         56849635
#
#                                                            title  \
# 0              temporal events analysis employing tree induction
# 1  protein signature/markers for the detection of adenocarcinoma
# 2             unsupervised learning using neuromorphic computing
# 3          non-contact activity sensing network for elderly care
# 4     software patch management incorporating sentiment analysis
#
#                                                                                                                                                                                                                                                                                                       abstract  \
# 0  an events analysis method comprises: optimizing respective to a set of training data a set of branching transition likelihood parameters associating parent events of type k with child events of type k' in branching processes; inferring a most probable branching process for a set of input data co...
# 1  the present invention provides a method for determining the presence of pancreatic adenocarcinoma in an individual and/or for determining the survival time of an individual afflicted with pancreatic adenocarcinoma comprising the steps of: (a) providing a serum or plasma sample to be tested; and ...
# 2  a spiking neural network (snn) is implemented on a neuromorphic computers and includes a plurality of neurons, a first set of the plurality of synapses defining feed-forward connections from a first subset of the neurons to a second subset of the neurons, a second subset of the plurality of syna...
# 3  determining a physical state of a person includes detecting positions of different portions of the person, transforming detected positions of the person into a point cloud having a density that varies according to movement of each of the portions, correlating movement and position data from the ...
# 4  a method and system are provided. the method includes generating, by a machine-based sentiment prediction generator, respective machine-determined sentiment predictions for each of a plurality of software patches using sentiment analysis. the method further includes setting, by a sentiment-based...
#
#                                                                                                                                                                                                                                                                                                         claims
# 0  1. an events analyzer comprising: a probabilistic branching process learning engine configured to optimize respective to a set of training data a set of branching transition likelihood parameters associating parent events of type k with child events of type k′ in branching processes; and a proba...
# 1  1. a method for determining the presence of pancreatic adenocarcinoma in an individual comprising the steps of: a) providing a serum or plasma sample to be tested; b) determining a protein signature of the test sample by measuring the presence and/or amount in the test sample of one or more prot...
# 2  1. a method comprising: defining a spiking neural network (snn) comprising a plurality of artificial neurons interconnected by a plurality of artificial synapses, wherein the snn is to comprise: a first subset of the plurality of synapses to define feedforward connections from a first subset of ...
# 3  1. a method of determining a physical state of a person, comprising:detecting positions of different portions of the person;transforming detected positions of the person into a point cloud having a density that varies according to movement of each of the portions;correlating movement and positio...
# 4  1. 1-18. (canceled)19. a computer program product for software patch management, the computer program product comprising a computer readable storage medium having program instructions embodied therewith, the program instructions executable by a computer to cause the computer to perform a method ...

# %%
len(df)
# Out:
# 216986

# %% [markdown]
# <h3>Keyword della professoressa:</h3>
#
# <img src="keyword prof.png" style="width:800px;"/>

# %%
keywords_other = []
"""["molecule",
                  "particle", 
                  "pharmacological",
                  "technolog",
                  "nano(-| )?tech(nolog)?",
                  "alter(ing)?",
                  "nano",
                  "nano(-| )?bot",
                  "nano(-| )?emulsion",
                  "nano(-| )?particle",
                  "nano(-| )?tube",
                  "nano(-| )?sphere",
                  "quantum",
                  "graphene",
                  "cloud",
                  "software",
                  "product"
                 ]"""

"""
Possiamo cercare i vincoli espressi dalla professoressa sia in "stile pandas" 
    (cercare documenti che contengono sia "body" che "care": df[(df.body >= 1) & (df.care >= 1)])
    
    che tramite l'uso delle espressioni regolari per implmentare l'operatore che l'Ing Ghironi 
    ha chiamto NEAR. Ad esempio per cercare "skin NEAR care" possiamo aggiungere alla lista sotto
    "lip(\w|\W){1,20}?stick". Agli estremi ci sono le 2 parole in cui siamo interessati, 
    "(\w|\W){1,20}?" serve invece a dire "permetti la presenza tra 
    0 e 20 caratteri o numeri tra le 2 parole". Se volete fare dei test: https://pythex.org/
"""

keywords_cosmetics = ["cosmetic",
                      "beauty", 
                      "body", 
                      "skin", 
                      "nail", 
                      "fingernail", 
                      "cleans(e|ing)", # 
                      "manicur(e|ing)", #manicure and manicuring
                      "pedicur(e|ing)",
                      "varnish", 
                      "polish",
                      "nail(s| |-)*polish",
                      " lip(s)?",
                      "lip( |-)?stic( |k)+",
                      "blush",
                      "mascara",
                      "make(s| |-)*up",#makes up, make-up
                      " cream",
                      " soap",
                      "toothpaste",
                      "sunscreen",
                      "lotion",
                      "deodorant",
                      "care",
                      "lip(s| |-)*(care|polish)",
                      "skin(s| |-)*(care|polish)",
                      "skin(s| |-)*(care|polish)",
                      "nail(s| |-)*(care|polish)",
                      "baby(s| |-)*(care|polish)",
                      "anti(-)?ag(e|ing)",
                      "colour|color",
                      "finger"
                     ]

# %%
df_original = df.copy()

# %% [markdown]
# ### Controllo IPC (DA AFFINARE)
# ##### IPC A45D+
#
# HAIRDRESSING OR SHAVING EQUIPMENT ; EQUIPMENT FOR COSMETICS OR COSMETIC TREATMENTS, e.g. FOR MANICURING OR PEDICURING

# %%
df_selected = pd.DataFrame()

# %%
df_candidate = df[(df.ipc_classes.str.count("(^| )A45D")>0)
                 & (df.ipc_classes.str.count("(^| )G06")==0) #Escludo "COMPUTING; CALCULATING; COUNTING"
                  & (df.ipc_classes.str.count("(^| )A61B5")==0) #	Measuring for diagnostic purposes
                 ]
df_candidate[["title", "ipc_classes","claims"]]
# Out:
#                                                                                                     title  \
# 3240    system for dispensing at least one makeup product and method for dispensing and evaluating makeup
# 20938                                                 automatic nail polish application system and method
# 31462                                                                          training system and device
# 38540                                                                           cosmetic cleaning product
# 53114                                            portable apparatus for supporting a hand held hair dryer
# 53136                                                          improvements in and relating to hair irons
# 61966                                                                                    complete compact
# 63517                               disposable single use applicator assembly with a chemical composition
# 69896                             method for simulating the rendering of a make-up product on a body area
# 81748                          system for targeted application of topical agents to an isolated body part
# 92758                                                          hair iron and methods of operation thereof
# 98501                                                                              hair roller and setter
# 99221                                                          hair iron and methods of operation thereof
# 129645                                                                 device for personalizing fragrance
# 134898                                                           system for dispensing a cosmetic product
# 138761   method for manufacturing a disposable single use applicator assembly with a chemical composition
# 148877                                                        hair iron and method for straightening hair
# 153668                                                                      systems for custom coloration
# 158644                            method for simulating the rendering of a make-up product on a body area
# 166422                                                      cosmetic package including a liquid reservoir
# 168759                                                              hair straightening and styling device
# 169482                                                                          cosmetic cleaning product
# 176252                              disposable single use applicator assembly with a chemical composition
# 199904                                   method for determining a composition of pigments in a hair fiber
# 202844                                                              systems and methods for coloring hair
# 208791                                           portable apparatus for supporting a hand held hair dryer
#
#                                                                                                                                                                                           ipc_classes  \
# 3240                                                                                                                        A45D40/00, A45D40/26, A45D44/00, B01F13/10, B01F15/02, B01F5/06, G01J3/46
# 20938                                                                                                                                           A45D29/00, A45D29/11, A45D29/12, A45D29/14, A45D34/04
# 31462                                                                                                                                                        A45D1/00, G09B19/00, G09B19/24, G09B5/04
# 38540                                                                                 A45D34/04, A61H15/02, A61H7/00, A61K8/00, A61K8/02, A61K8/31, A61K8/37, A61K8/42, A61K8/44, A61Q19/10, A61Q5/02
# 53114                                                                                                                                                      A45D20/12, A45D20/14, F16M11/00, F16M13/02
# 53136                                                                                                                                                                              A45D1/06, A45D1/28
# 61966                                                                                                                                             A45D33/00, A45D33/26, A45D44/00, G01N1/22, G01N1/24
# 63517                                                                                                                                            A45D37/00, A45D40/00, A45D40/26, A61K8/04, A61Q19/00
# 69896                                                                                                                                                                                       A45D44/00
# 81748                                                                            A45D40/30, A45D44/00, A61K8/02, A61K8/368, A61P17/10, A61Q19/00, B32B38/10, B32B7/06, B33Y10/00, B33Y80/00, B44C3/02
# 92758                                                                                                                  A45D1/00, A45D1/04, A45D1/06, A45D1/28, A45D2/00, A45D7/02, H05B1/02, H05B3/02
# 98501                                                                                                                                                A45D2/12, A45D2/14, A45D2/18, A45D2/22, A45D2/36
# 99221                                                                                                                  A45D1/00, A45D1/04, A45D1/06, A45D1/28, A45D2/00, A45D7/02, H05B1/02, H05B3/02
# 129645                                                                                                                                                      A45D33/22, A45D40/00, A45D40/24, B65D6/24
# 134898                                                                                                             A45D34/04, A45D40/24, A45D44/00, A61K8/19, A61K8/73, A61K8/81, A61Q1/02, A61Q19/00
# 138761  A45D37/00, A45D40/00, A61K8/19, A61K8/25, A61K8/26, A61K8/34, A61K8/36, A61K8/58, A61Q1/02, B65B11/50, B65B41/16, B65B51/10, B65B57/10, B65B61/00, B65D75/30, B65H16/00, B65H20/02, B65H35/00
# 148877                                                                                                                                                                             A45D1/06, A45D1/28
# 153668     A45D19/02, A45D44/00, A45D44/02, A61K8/02, A61K8/34, A61K8/40, A61K8/41, A61K8/46, A61K8/49, A61K8/73, A61K8/81, A61Q5/10, B01F1/00, B01F13/10, B01F15/02, G01J3/00, G01N21/47, G01N33/483
# 158644                                                                                                                                                                                      A45D44/00
# 166422                                                                                                                                                                                      A45D34/04
# 168759                                                                                                                                                                  A45D2/00, A45D2/44, A45D24/06
# 169482                                                                                A45D34/04, A61H15/02, A61H7/00, A61K8/00, A61K8/02, A61K8/31, A61K8/37, A61K8/42, A61K8/44, A61Q19/10, A61Q5/02
# 176252                                                                                                                                           A45D37/00, A45D40/00, A45D40/26, A61K8/04, A61Q19/00
# 199904                                                                                                                                           A45D44/00, G01J3/28, G01J3/46, G01N21/31, G01N21/359
# 202844                                                                                                                                                                                      A45D19/00
# 208791                                                                                                                                                     A45D20/12, A45D20/14, F16M11/00, F16M13/02
#
#                                                                                                                                                                                                                                                                                                              claims
# 3240    1. a system for dispensing at least one makeup product and that can be manipulated in one hand, the system comprising: a cup; and a dispenser for filling the cup from a bottom of the cup with at least two base products, wherein: the cup is secured to the dispenser at least while the cup is being...
# 20938   1. a system for automatically polishing a nail of a user including:an end-effector havinga cartridge receiving unit,a cartridge including nail polish, anda nozzle;a sensor, to generate target signals from a target location;a nail determination unit, receiving said target signals, to automaticall...
# 31462   1. a beauty product system for performing a treatment on a user, the system comprising:an input for allowing the user to specify a desired treatment to be performed; a beauty product device that is manipulate by the user to perform the desired treatment on the user; the beauty product device hav...
# 38540   1. a cosmetic cleaning product, comprising: a massage applicator comprising a container body and a massage device having (a) at least one massage pin device, said pin device having at least one first surface which is configured to be in contact with the surface to be massaged, wherein a force ca...
# 53114   1. a portable hair dryer support apparatus, comprising: a hair dryer holding structure for holding a hair dryer; at least one vertical support element pivotally and directly connected at a bottom end to the hair dryer holding structure via a hinge having an axis of rotation perpendicular to the ...
# 53136   1. an electric hair iron comprising at least one heating element and control means comprising a temperature sensor and a control circuit and wherein the control means is arranged such that power is only supplied to the heating element or elements when the temperature sensed by the sensor is at o...
# 61966   i claim:1. a method for determining aroma comprising: (a) providing at least one means of aroma sensing capable of approximately discerning the presence or absence of at least one characteristic of the aroma, (b) sampling aroma with said aroma sensing means, (c) discerning said aroma characteris...
# 63517   i claim:1. an assembly for storing and transporting, said assembly comprising: a wrapper having a top sheet and a bottom sheet, said top sheet being sealed to said bottom sheet so as to form a border along a perimeter of said top sheet and said bottom sheet; and an insert having a top surface an...
# 69896   1. a method (200) for simulating a rendering of a makeup product on a body area, the method being performed by a processor (1 1 ), and comprising :o acquiring (210) an image of the body area without makeup of a subject, o determining (230) first color parameters of the pixels of the image corres...
# 81748   1. a method for targeted application of topical agents to an isolated body part comprising the steps of: (a) capturing an image of the isolated body part; (b) transforming the image data to mathematical model of the geometry of the isolated body part; (c) forming an applicator mask having an app...
# 92758   1. an electric hair iron comprising at least one heating element and control means comprising a temperature sensor and a control circuit and wherein the control means is arranged such that power is only supplied to the at least one heating element when the temperature sensed by the sensor is at ...
# 98501   1. a hair roller for shaping human hair, said roller comprising: a generally elongated, flexible inner core having a first modulus of elasticity; a generally elongated, flexible outer layer surrounding said inner core and having a second modulus of elasticity that is greater than said first modu...
# 99221   1. an electric hair iron comprising at least one heating element and control means comprising a temperature sensor and a control circuit and wherein the control means is arranged such that power is only supplied to the at least one heating element when the temperature sensed by the sensor is at ...
# 129645  1. a device, comprising: a first module comprising a first container having a first hemispherical cap and a first attacher, the first module further comprising a first modular cap that receives the first hemispherical cap; a first fragrance formulation contained by the first container, when the ...
# 134898  1. a system for dispensing a product, comprising a dispenser that receives at least two cartridges that each have a reservoir comprising a base product, a first base product comprising at least 0.1% by mass of particles exhibiting a difference in density with a medium which contains them, the pa...
# 138761  i claim:1. a method of manufacturing, comprising the steps of: mounting a first roll having wrapper material; dispensing said wrapper material in a first direction; splitting said wrapper material into a top sheet material and a bottom sheet material; conveying said bottom sheet material in a se...
# 148877  an electric hair iron comprising at least one heating element and control means comprising a temperature sensor and a control circuit , characterised in that the control means is arranged such that power is only supplied to the heating element or elements when the temperature sensed by the senso...
# 153668  1. a method of treating keratinous fibers, the method comprising: disintegrating at least one solid formulation in a first aqueous medium, to thereby obtain an aqueous composition; and contacting said composition with the keratinous fibers for a time period suitable to treat the keratinous fiber...
# 158644  1. a method (200) for simulating a rendering of a makeup product on a body area, the method being performed by a processor (11), and comprising : ∘ acquiring (210) an image of the body area without makeup of a subject, ∘ determining (230) first color parameters of the pixels of the image corresp...
# 166422  the embodiments of the invention in which an exclusive property or privilege is claimed are defined as follows:1. a cosmetic formula container, comprising: a container body configured to retain a portion of a cosmetic formula within a cavity, the container body having a neck configured to receiv...
# 168759  1. a device for smoothing, straightening and styling hair, comprising: a sleeve and a head, said head having a plurality of combs and a heater for smoothing the hair, wherein said plurality of combs have a pinching element, and wherein said pinching element exerts a continuous tension on the hai...
# 169482  that which is claimed:1. a cosmetic cleaning product, comprising: a massage applicator comprising a container body and a massage device having (a) at least one massage pin device, said pin device having at least one first surface which is configured to be in contact with the surface to be massag...
# 176252  i claim:1. an assembly for storing and transporting, said assembly comprising: a wrapper having a top sheet and a bottom sheet, said top sheet being sealed to said bottom sheet so as to form a border along a perimeter of said top sheet and said bottom sheet; and an insert having a top surface an...
# 199904  1. a method (100) for determining a composition of pigments in a hair fiber (202), the method comprising: - exposing (110) a region (203) of the hair fiber (202) to electromagnetic radiation (215) comprising wavelengths in a visible range (310) between 400 nm and 700 nm, as well as wavelengths i...
# 202844  1. a system comprising:a scanning device for measuring a color of a client's hair;a hair dye dispensing system comprising:a first input for reading the measured color from the scanning device; a processor configured to compare the measured color to a desired target hair color and develop a color...
# 208791  1. a portable hair dryer support apparatus, comprising: a hair dryer holding structure for holding a hair dryer; and at least one vertical support element connected at a first end to the hair dryer holding structure and having at a second opposed end at least one securing portion for securing th...

# %%
df_selected = pd.concat([df_selected, df_candidate])

len(df_selected)
# Out:
# 26

# %% [markdown]
# ##### IPC C11B9/00 (riportato nelle slide come C11B/009)

# %%
df_candidate = df[(df.ipc_classes.str.count("(^| )C11B9/00")>0)
                 & (df.ipc_classes.str.count("G06")==0) #Escludo "COMPUTING; CALCULATING; COUNTING"
                 ]
df_candidate[["title", "ipc_classes","claims"]]
# Out:
#                                                                          title  \
# 5337                                           method of making perfumed goods
# 135822                    method of resolving allergens in perfume ingredients
# 174990                                         method of making perfumed goods
# 210149  methods for identifying, compounds identified and compositions thereof
#
#                                                              ipc_classes  \
# 5337                                                  C11B9/00, C11D3/50
# 135822  B01J20/26, B01J20/281, C11B9/00, G01N30/46, G01N30/86, G16C20/20
# 174990                 A61L9/01, A61Q19/00, C11B9/00, C11D3/22, C11D3/50
# 210149                                               A23L27/00, C11B9/00
#
#                                                                                                                                                                                                                                                                                                              claims
# 5337    1. a method comprising: a.) using an odt value determined by mathematical modelling to select one or more perfume raw materials; b.) combining and/or processing said one or more perfume raw materials with one or more additional materials to form a product.2. the method of claim 1, wherein said p...
# 135822  1. a method of resolving defined known or suspected allergens in a complex mixture of perfume ingredients using two-dimensional gas chromatography (2d-gc), wherein the combination of first and second stationary phases is selected on the basis of a clustering analysis of defined known or suspecte...
# 174990  what is claimed is:1. a method comprising:a.) using a malodour reduction value determined by mathematical modelling toselect one or more perfume raw materials;b.) combining and/or processing said one or more perfume raw materials with one or more additional materials to form a product. 2. the me...
# 210149  1. a flavor/fragrance composition, comprising an effective amount of one or more compounds selected from tables 1-42.2. the flavor/fragrance composition of claim 1, wherein the composition is formulated as a spray, lotion, foam, gel, suspension, or emulsion.3. the flavor/fragrance composition of...

# %%
df_selected = pd.concat([df_selected, df_candidate])

len(df_selected)
# Out:
# 30

# %% [markdown]
# ## Analisi Per keyword
# #### Vedi slides Ing. Ghironi

# %%
for key in tqdm(keywords_cosmetics):
    df[key] = df.title.str.count(key).fillna(0) + df.abstract.str.count(key).fillna(0) + df.claims.str.count(key).fillna(0)
    
for key in tqdm(keywords_other):
    df[key] = df.title.str.count(key).fillna(0) #+ df.abstract.str.count(key).fillna(0) + df.claims.str.count(key).fillna(0)
# Out:
#   0%|          | 0/32 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]

# %%
df["total_cosmetics"] = 0
for key in keywords_cosmetics:
    if key == "body" or key == "lip(s)?": continue
    df["total_cosmetics"] += df[key]
    
df["total_other"] = 0
for key in keywords_other:
    df["total_other"] += df[key]

# %%
keywords_cosmetics
# Out:
# ['cosmetic',
#  'beauty',
#  'body',
#  'skin',
#  'nail',
#  'fingernail',
#  'cleans(e|ing)',
#  'manicur(e|ing)',
#  'pedicur(e|ing)varnish',
#  'polish',
#  'nail(s| |-)*polish',
#  'lip(s)?',
#  'lip( |-)?stic( |k)+',
#  'blush',
#  'mascara',
#  'make(s| |-)*up',
#  'cream',
#  'soap',
#  'toothpaste',
#  'sunscreen',
#  'lotion',
#  'deodorant',
#  'care',
#  'lip(s| |-)*(care|polish)',
#  'skin(s| |-)*(care|polish)',
#  'skin(s| |-)*(care|polish)',
#  'nail(s| |-)*(care|polish)',
#  'baby(s| |-)*(care|polish)',
#  'anti(-)?ag(e|ing)',
#  'colour|color',
#  'finger']

# %% [markdown]
# ##### cosmetic

# %%
keyword = keywords_cosmetics[0]
keyword
# Out:
# 'cosmetic'

# %%
df[df[keyword] > 0][["title", "ipc_classes","abstract", "claims"]]
# Out:
#                                                                                                                                                                             title  \
# 1827                               in vitro toxicogenomics for toxicity prediction using probabilistic component modeling and a compound-induced transcriptional response pattern
# 3240                                                                            system for dispensing at least one makeup product and method for dispensing and evaluating makeup
# 5009                                                                                                               automated characterization and classification of microoganisms
# 6806                                                                                                                         methods and systems for dynamic content provisioning
# 7363                                                                                                                                                           personal appliance
# 7691                                                                                            systems and methods for measuring and categorizing colors and spectra of surfaces
# 8521                                                                                                                    use of artificial intelligence in providing beauty advice
# 8593                                                                                                                            system for beauty, cosmetic, and fashion analysis
# 11576                                                                                     detecting physiological responses based on multispectral data from head-mounted cameras
# 11645                                                                                                                                methods and systems for specifying an avatar
# 12314                                                                                                                                  immune system modeling devices and methods
# 14726                                                                                                                          age estimation method and sex determination method
# 16428                                                                                                       systems and methods for modeling the breast using spherical harmonics
# 16533                                                                                                                            image data normalization for a monitoring system
# 17489                                                                                                                           system for beauty, cosmetic, and fashion analysis
# 17570                                                                neural network based physical condition evaluation of electronic devices, and associated systems and methods
# 18306                                                                                                                                      determining age ranges of skin samples
# 21060                                                                                             automated welding apparatus and computer-implemented method for filing a volume
# 21464                                                          methods for assessing repellant quality of organic materials and methods and compositions for repelling arthropods
# 21685                                                                                                                                  visual intent triggering for visual search
# 24039                                                                                                               apparatus and method for determining cosmetic skin attributes
# 25321                                                                                                                      detecting an allergic reaction from nasal temperatures
# 25804                                                                                                                                                     botulinum nanoemulsions
# 27784                                               moisture control device, moisture control method, program, storage medium, generated substance, product, device and equipment
# 28316                                                                                                                                                      body image enhancement
# 30061                                                                                                                                                                   ar system
# 30649                                                                                                                            improvements in or relating to organic compounds
# 31438                                                                                                                                   method and system for managing treatments
# 34366                                                                                                  sensor instrument system including method for detecting analytes in fluids
# 35892                                                                                                                           inspection and cosmetic grading system and method
# 37811                                                                                                                                                 system for portable sensing
# 38540                                                                                                                                                   cosmetic cleaning product
# 39592                                                                                                                                                  cosmetic affinity indexing
# 41847                                                                                    system and method for analysis of light-matter interaction based on spectral convolution
# 41972                                                                                                                           systems and methods for providing beauty guidance
# 42414                                                                     mobile hyperspectral camera system and human skin monitoring using a mobile hyperspectral camera system
# 42558                      business method and apparatus for employing induced multimedia classifiers based on unified representation of features reflecting disparate modalities
# 43992                                                                                                                           system for beauty, cosmetic, and fashion analysis
# 44214                                                                           method for determining parameters specific to the customised hair-colouring of a given individual
# 46338                                                                                                                         systems and methods for computer assisted operation
# 46462                                                                                              method and apparatus for determining particle size and composition of mixtures
# 47201                                                                                            methods for diagnosing perceived age based on an ensemble of phenotypic features
# 47882                              in vitro toxicogenomics for toxicity prediction using probabilistic component modeling and a compound-induced transcriptional response pattern
# 51371                                                                                                                                         augmented reality product selection
# 52887                                                                                                      topical composition for restoring microbial diversity of amenable skin
# 52891                                                                                                               systems and methods for interactive virtual makeup experience
# 53815                                       a pump actuating cap for pump dispensers, system and method for remote monitoring of product consumption from said pump actuating cap
# 54029                                                                                                  real time monitoring of cosmetic laser aesthetic skin treatment procedures
# 55401                                                                        methods and systems for improving perceived age based on phenotypic and genetic features of the skin
# 56797                                                                                  systems and methods for providing personalized product recommendations using deep learning
# 57661                                                                                                                                system, device and method for dermal imaging
# 58420                                                                                          authenticating physical objects using machine learning from microscopic variations
# 59333                                                                                                                    method and apparatus for cosmetic product recommendation
# 59480                                                                                                                                                  personalized beauty system
# 61057                                                                                                                              method and composition for removing waxy soils
# 61715                                                                                                                     analysis and feedback system for personal care routines
# 61778                                                                                                             automated characterization and classification of microorganisms
# 61884                                                                                                                                                    augmented reality system
# 62406                                                                                                                                                          personal appliance
# 63517                                                                                                       disposable single use applicator assembly with a chemical composition
# 65842                                                                                           simulation of effects of cosmetic products using a three-dimensional facial image
# 66402                                                                                                 method and apparatus for providing personalized skin care guide information
# 67654                                                                                                            panels of genetically diverse samples and methods of use thereof
# 67693                                                                                                                                                  cosmetic defect evaluation
# 69544                                                                                                              machine-implemented beauty assistant for predicting face aging
# 69603                                                                                                                                                                   ar system
# 70595                                                                                  method of evaluating cosmetic products on a consumer with future predictive transformation
# 70656                                                                                                                                          computer code for portable sensing
# 71271                                                                                                                            image data normalization for a monitoring system
# 73457                                                          methods for assessing repellant quality of organic materials and methods and compositions for repelling arthropods
# 76624                                                                                                                                                     extended reality system
# 77455                                                                                                                                                    augmented reality system
# 77869                                                                                                                                          computer code for portable sensing
# 78297                                                                                                                            image data normalization for a monitoring system
# 79795                                                                                           simulation of effects of cosmetic products using a three-dimensional facial image
# 81413                                                                                                               apparatus and method for determining cosmetic skin attributes
# 81549                                                                                        virtual representation creation of user for fit and style of apparel and accessories
# 81791                                                                                                                                     systems and methods for fitting product
# 82678                                                                                                        methods of providing a patient with aesthetic improvement procedures
# 82722                                                                                             automated welding apparatus and computer-implemented method for filing a volume
# 84184                                                                                                      methods and systems for determining interest in a cohort-linked avatar
# 85534                                                                                                    portable scanning device for ascertaining attributes of sample materials
# 86229                                                                                                         adhesive patch or bandage for use in treating blood vessel diseases
# 87026                      business method and apparatus for employing induced multimedia classifiers based on unified representation of features reflecting disparate modalities
# 87044                                                                                                                        cold plasma generating devices, systems, and methods
# 88605                                                                                                                             analysis using a three-dimensional facial image
# 90992                                                          methods for assessing repellant quality of organic materials and methods and compositions for repelling arthropods
# 91200                                                                                                                                                     botulinum nanoemulsions
# 94262                                                                                                                                                  personalized beauty system
# 95067                                                          methods for assessing repellant quality of organic materials and methods and compositions for repelling arthropods
# 95247                                                                                                                                      determining age ranges of skin samples
# 96125                                                                                                                                                  novel reprogramming method
# 96733                                                                                                  patient -centered system and methods for total orthodontic care management
# 98335                                                                                               methods and systems for microbiome characterization, monitoring and treatment
# 99466                                       method and system for determining a characteristic of a keratinous surface and method and system for treating said keratinous surface
# 99476                                                        computer implemented method, computer system and software for reducing errors associated with a situated interaction
# 101646                                                                                     methods and systems for predicting and/or tracking changes in external body conditions
# 101761                                                                                       apparatus and method for visualizing visually imperceivable cosmetic skin attributes
# 104879                                                                                            sensor having integrated electrodes and method for detecting analytes in fluids
# 106008                                                                                                                                                     skin assessment device
# 106389                                                                                    scalable portable sensory and yield expert system for biomass monitoring and production
# 106799                                                                                                                                                     body image enhancement
# 108520                                                                makeup assistance device, makeup assistance system, makeup assistance method, and makeup assistance program
# 109106                                                                                                                              method and computer code for portable sensing
# 110753                                                                                                                                    systems and methods for fitting product
# 113451                                          methods and systems for identifying molecules or processes of biological interest by using knowledge discovery in biological data
# 114791                                                                                             method and apparatus for determining particle size and composition of mixtures
# 116454                                                                                                                      body image templates with pre-applied beauty products
# 117931                                                                                                                                                         personal appliance
# 118143                                                                                                    methods for enabling secured and personalised genomic sequence analysis
# 118693                                                                                                                                    systems and methods for fitting product
# 118709  multilayer material for screening out ultraviolet, composition comprising same, process for treating keratin materials using same, and process for preparing the material
# 119212                                                                                                                apparatus for recognizing iris and operating method thereof
# 120231                                                                                                                                  label with integrated thin film magnifier
# 120868                                                                           system and method for semi-supervised conditional generative modeling using adversarial networks
# 120991                         pump- actuated dispenser with integrated switch, system and method for remote monitoring of product consumption from said pump- actuated dispenser
# 121331                                                         methods for assessing repellant quality of organic materials and methods and compositions for repelling arthropods
# 121651                                                                                                                                                   ahr signature marker set
# 124725                                                                                                                            systems and methods for adaptive skin treatment
# 125951                                                                                                     selecting triggers of an allergic reaction based on nasal temperatures
# 127640                                                                makeup assistance device, makeup assistance system, makeup assistance method, and makeup assistance program
# 128860                                                                                          driving state analysis method and apparatus, driver monitoring system and vehicle
# 129519                                                                                                                                    systems and methods for fitting product
# 130055                                                                                 composition comprising mannose oligosaccharide and process for making same and use thereof
# 131498                                        pump actuating cap for pump dispensers, system and method for remote monitoring of product consumption from said pump actuating cap
# 132578                                                                           system and method for semi-supervised conditional generative modeling using adversarial networks
# 134898                                                                                                                                   system for dispensing a cosmetic product
# 136755                                                                                                                                  methods involving artificial intelligence
# 137258                                                                                                           panels of genetically diverse samples and methods of use thereof
# 137417                                                                                                                                                  virtual beauty consultant
# 137610                                                                                                                          system for beauty, cosmetic, and fashion analysis
# 138761                                                                           method for manufacturing a disposable single use applicator assembly with a chemical composition
# 138844                                                                                                                                                     body image enhancement
# 138987                                                                                                                     detecting an allergic reaction from nasal temperatures
# 139755                                                            microbiome based systems, apparatus and methods for monitoring and controlling industrial processes and systems
# 139942                                                                                                                  use of artificial intelligence in providing beauty advice
# 140305                                                                                                                    method for prognosing a risk of occurrence of a disease
# 140736                                                                                                                                                         personal appliance
# 141219                                                                                                                   method and apparatus for cosmetic product recommendation
# 142432                                                           method, system, and device of virtual dressing utilizing image processing, machine learning, and computer vision
# 145153                                                                                                   system and method for collaborative shopping, business and entertainment
# 145461                                                                                                                    analysis and feedback system for personal care routines
# 145728                                                                                                                                                  extensible user interface
# 146956                                                                                       virtual representation creation of user for fit and style of apparel and accessories
# 147791                                                         methods for assessing repellant quality of organic materials and methods and compositions for repelling arthropods
# 147934                                                               neural network based physical condition evaluation of electronic devices, and associated systems and methods
# 154122                                                                                                                             methods for remote characterization of an odor
# 155945                                                                                                                            in vitro toxicogenomics for toxicity prediction
# 156472                                                         microparticles of cellulose nanocrystals with pigment nanoparticles bound thereto and method of production thereof
# 159284                                                                                                                apparatus for recognizing iris and operating method thereof
# 159496                                                                                                      apparatus and method for informed personal well-being decision making
# 159712                                      method and system for determining a characteristic of a keratinous surface and method and system for treating said keratinous surface
# 162667                                                                makeup assistance device, makeup assistance system, makeup assistance method, and makeup assistance program
# 166045                                                                                                                               ar-enabled labeling using aligned cad models
# 166422                                                                                                                              cosmetic package including a liquid reservoir
# 167239                                                                                                     selecting triggers of an allergic reaction based on nasal temperatures
# 168302                                                                                                              apparatus and method for visualizing cosmetic skin attributes
# 168515                                                                                                                                                    botulinum nanoemulsions
# 169482                                                                                                                                                  cosmetic cleaning product
# 170705                                                                                                   system and method for collaborative shopping, business and entertainment
# 175919                                                                                                            automated characterization and classification of microorganisms
# 176252                                                                                                      disposable single use applicator assembly with a chemical composition
# 177564                                                                                                           method for computer-assisted determination of a cosmetic product
# 177581                                                                                    detecting physiological responses based on multispectral data from head-mounted cameras
# 178219                                                                                                                                                   augmented reality system
# 179275                                                                                                                                                 personalized beauty system
# 182147                                            moisture control apparatus, moisture control method, program, storage medium, produced object, product, apparatus, and facility
# 182169                                                                                                                                 intelligent disposition of returned assets
# 182672                                                                                                                            compositions and methods for treating neoplasia
# 183784                                                                                                                                                   method for data analysis
# 185729                                                                                                                          system for beauty, cosmetic, and fashion analysis
# 187482                                                                                                                                                         personal appliance
# 187698                                                                                                 inspection and cosmetic grading through image processing system and method
# 189703                                                                                                  dispensing system and method for learning to use such a dispensing system
# 190105                    system and method for providing a user with recommendations indicating a fitness level of one or more topical skin products with a personal care device
# 191294                                                                                                                                          beauty advisory system and method
# 191944                                                                                             method for operating makeup robot based on expert knowledge and system thereof
# 192304                                                                                                                           phototherapy system for treating nasal disorders
# 192616                                                                               communication between machines and feed-forward control in event-based product manufacturing
# 194374                                                                                                                                                  advice information system
# 196020                                          methods and systems for identifying molecules or processes of biological interest by using knowledge discovery in biological data
# 196265                                                                                                                        smart beauty delivery system linking smart products
# 198899                    system and method for providing a user with recommendations indicating a fitness level of one of more topical skin products with a personal care device
# 199628                                                                                                   system and method for collaborative shopping, business and entertainment
# 200168                                                                                               system and method for creation of topical agents with improved image capture
# 200396                                                                                                                           image data normalization for a monitoring system
# 201954                                                                                                                               system, device and method for dermal imaging
# 205924                                                                                                                                               personalized cosmetic system
# 208977                                                                                                                                    systems and methods for fitting product
# 209315                                                                                                                                     determining age ranges of skin samples
# 209584                                                                                         driving state detection method and apparatus, driver monitoring system and vehicle
# 210130                                                                                                 sensor instrument system including method for detecting analytes in fluids
# 210149                                                                                                     methods for identifying, compounds identified and compositions thereof
# 210373                                                                                                                       simulation of an aesthetic feature on a facial image
# 211447                                                                                                                    method for prognosing a risk of occurrence of a disease
# 212642                                                                                            sensor having integrated electrodes and method for detecting analytes in fluids
# 213268                                                                                                                                                   historical beauty record
# 214657                                                                                              methods and systems for microbiome characterization, monitoring and treatment
# 215294                                            systems, models and methods for identifying and evaluating skin-active agents effective for treating an array of skin disorders
# 215702                                                                                 systems and methods for providing personalized product recommendations using deep learning
# 216451                                                                                                                                                  treatment delivery system
# 216476                                                                                                                                        augmented reality product selection
#
#                                                                                                                                                                                                                                                                                                         ipc_classes  \
# 1827                                                                                                                                                                                                    C12Q1/68, C12Q1/6876, G06F19/12, G06F19/20, G16B20/00, G16B25/00, G16B5/00, G16C20/10, G16C20/30, G16C20/70
# 3240                                                                                                                                                                                                                                      A45D40/00, A45D40/26, A45D44/00, B01F13/10, B01F15/02, B01F5/06, G01J3/46
# 5009                                                                                                                                                                                                                                                                                          G01N21/65, G01N33/569
# 6806                                                                                                                                                                                                                                                                  G06F16/435, G06F16/438, G06F16/483, G06Q50/00
# 7363                                                                                                                                                                                                                                                                                           B26B19/38, B26B21/40
# 7691                                                                                                                                                                                                                                                                        A45D44/00, A61B5/00, G01J3/02, G01J3/46
# 8521                                                                                                                                                                                                               A45D44/00, A61B5/103, G06F15/00, G06F15/18, G06F17/30, G06F19/00, G06F7/00, G06Q30/06, G06T11/00
# 8593                                                                                                                                                                                                                                                             G06K9/00, G06K9/66, G06T11/00, G06T11/60, G06T3/00
# 11576                                                                                                                                                                                                                    A61B5/00, A61B5/01, A61B5/16, G01J5/00, G01J5/12, G02B27/01, G06K9/00, H04N5/225, H04N5/33
# 11645                                                                                                                                                                                                                                                                                                     G06F17/30
# 12314                                                                                                                                                                                                                                                  C12M1/00, C12M3/00, C12M3/06, C12Q1/02, G01N33/50, G01N33/53
# 14726                                                                                                                                                                                                                                                                                  G06K9/00, G06K9/36, G06T7/00
# 16428                                                                                                                                                                                                                                                                                                      A61B5/00
# 16533                                                                                                                                                                                                                                                                                 A61B5/00, G06K9/80, H04N5/243
# 17489                                                                                                                                                                                                                                                            G06K9/00, G06K9/66, G06T11/00, G06T11/60, G06T3/00
# 17570                                                                                                                                                                                                                                                           G02B27/30, G06N3/08, G06Q30/02, G06T7/00, H04N5/225
# 18306                                                                                                                                                                                                                          A61K31/56, A61K38/16, A61K38/43, A61K8/18, A61Q17/04, C12Q1/68, C40B30/04, C40B40/06
# 21060                                                                                                         B23K101/00, B23K103/18, B23K15/00, B23K15/02, B23K26/03, B23K26/08, B23K26/082, B23K26/30, B23K26/32, B23K26/34, B23K26/342, B23K9/00, B23K9/032, B23K9/04, B23K9/095, B23K9/167, B23K9/173, B23K9/23
# 21464   A01N31/02, A01N31/06, A01N33/10, A01N35/02, A01N35/04, A01N35/06, A01N35/10, A01N37/10, A01N37/18, A01N37/20, A01N37/22, A01N37/36, A01N37/44, A01N37/46, A01N43/12, A01N43/16, A01N43/32, A01N43/38, A01N43/40, A01N43/42, A01N43/50, A01N43/54, A01N43/60, A01N43/78, A01N43/90, A01N47/16, A01N47/42,...
# 21685                                                                                                                                                                                                                                                                      G06F17/11, G06K9/62, G06N5/04, G06N99/00
# 24039                                                                                                                                                                                                                 A45D44/00, A61B5/00, A61B5/103, G06K9/00, G06K9/20, G06K9/46, G16H50/20, G16H50/30, G16H50/70
# 25321                                                                                                                                                                                                                              A61B5/00, A61B5/01, A61B5/04, A61B5/16, G01J5/00, G02B27/01, H04N5/225, H04N5/33
# 25804                                                                                                                                                                                                                 A61K38/48, A61K47/02, A61K47/42, A61K8/06, A61K8/64, A61K8/66, A61K9/00, A61K9/107, A61Q19/08
# 27784                                                                                                                                                                                                                            A23L3/26, A23L3/30, A23L3/32, A23L5/30, A47J37/12, B01J19/08, B01J19/10, B01J19/12
# 28316                                                                                                                                                                                                               A45D44/00, A61B5/103, G01J3/52, G06F19/00, G06Q50/00, G06T1/00, G06T11/00, G06T11/80, H04N7/173
# 30061                                                                                                                                                          A61B5/00, A61B5/0205, A61B5/103, A61B5/107, A61B5/11, A61B5/16, G01G19/44, G06Q30/06, G06T11/00, G06T17/00, G06T19/00, G06T19/20, G06T3/00, G06T7/20
# 30649                                                                                                                                                                                                                                                                                          G01N30/46, G01N30/86
# 31438                                                                                                                                                                                                                                                A61B5/00, A61N5/06, G01N21/25, G01N21/55, G01N21/84, G06F19/00
# 34366                                                                                                                                                                                                                                            B82Y15/00, G01N27/00, G01N27/327, G01N27/414, G01N33/543, H04Q9/00
# 35892                                                                                                                                                                                                                            A24C5/34, B61L23/04, G01B11/02, G01N21/88, G06T7/00, G06T7/521, G06T7/62, H04N7/18
# 37811                                                                                                                                                                                                                                                                                          G01N31/00, G06F19/00
# 38540                                                                                                                                                                                               A45D34/04, A61H15/02, A61H7/00, A61K8/00, A61K8/02, A61K8/31, A61K8/37, A61K8/42, A61K8/44, A61Q19/10, A61Q5/02
# 39592                                                                                                                                                                                                                                                                                          G06Q30/02, G06Q30/06
# 41847                                                                                                                                                                                                                                                              G06K9/46, G06K9/52, G06K9/62, G06T7/00, G06T7/40
# 41972                                                                                                                                                                                                                                                                    A45D44/00, A61B5/103, G06F19/00, G06T11/00
# ...
# 159712  [claim 1 ] [method for determining at least one physical and/or chemicalcharacteristic of a keratinous surface of a user, the method comprising the steps of :- receiving data corresponding to at least one image of the keratinous surface,- processing the image by applying at least one machine lea...
# 162667  1. a cosmetic assist device comprising: a camera that captures a face image of a user; a database that stores cosmetic techniques associated with image adjustment parameters including different colors; a memory that stores instructions; and a processor that executes the instructions stored in th...
# 166045  1. a computer-implemented method for facilitating efficient collection of training data for training an image-detection artificial intelligence (ai) engine, the method comprising: obtaining a three-dimensional (3d) model of a physical object placed in a scene; generating a virtual object corresp...
# 166422  the embodiments of the invention in which an exclusive property or privilege is claimed are defined as follows:1. a cosmetic formula container, comprising: a container body configured to retain a portion of a cosmetic formula within a cavity, the container body having a neck configured to receiv...
# 167239  we claim:1. a system configured to select a trigger of an allergic reaction of a user, comprising: an inward-facing head-mounted thermal camera (cam) configured to take thermal measurements of a region on the nose (thn) of the user; and a computer configured to: detect extents of the allergic re...
# 168302  what is claimed is:1. a method of visualizing at least one cosmetic skin attribute of a subject, the method comprising the steps of:a) obtaining a first digital image of at least a portion of a face of the subject, wherein the first digital image is selected from at least an area of an input ima...
# 168515  1. a sterile liquid pharmaceutical composition formulated for administration by injection, which composition comprises: a nanoparticle composition that is an oil-in-water or water-in-oil nanoemulsion in that oily particles are dispersed within an aqueous dispersion medium or aqueous particles ar...
# 169482  that which is claimed:1. a cosmetic cleaning product, comprising: a massage applicator comprising a container body and a massage device having (a) at least one massage pin device, said pin device having at least one first surface which is configured to be in contact with the surface to be massag...
# 170705  1. a method of sharing the amount of an online purchase transaction comprising the steps of: a) initiating a transaction between one or more users from among a plurality of users; b) selecting one or more of the users participating in the transaction; c) allocating the amount of the transaction ...
# 175919  1. a method for detection of an outbreak without prior suspicion of an outbreak and without requiring prior taxonomic classification, which method comprises: obtaining vibration spectrum for a microorganism in a sample of interest using an instrument comprising a vibrational spectrometer, a proc...
# 176252  i claim:1. an assembly for storing and transporting, said assembly comprising: a wrapper having a top sheet and a bottom sheet, said top sheet being sealed to said bottom sheet so as to form a border along a perimeter of said top sheet and said bottom sheet; and an insert having a top surface an...
# 177564  1. a method for computer-assisted determination of a cosmetic product, the method comprising the steps of: providing an activation signal to a portable data-processing device, the activation signal being configured to activate software in the portable data-processing device; providing product ca...
# 177581  we claim:1. a system configured to detect a physiological response, comprising: an inward-facing head-mounted thermal camera (cam) configured to take thermal measurements of a first region of interest (throi1) on a user's face; an inward-facing head-mounted visible-light camera (vcam) configured...
# 178219  1. a method for recommending products, comprising: receiving a three-dimensional (3d) model of one or more products; performing motion tracking and understanding an environment with points or planes and estimating light or color in the environment; acquiring sensor data from sensors and optimizi...
# 179275  1. a method for cosmetic maintenance of a subject, comprising: capturing one or more images of a subject with a camera; using a genetic analyzer to generate subject genetic information; receiving into computer memory a test dataset comprising, for the subject, genetic information from the subjec...
# 182147  1. a moisture control or current comprising: at least one electrode configured to generate at least one of an electric field, a magnetic field, an electromagnetic field, electromagnetic waves, sound waves, and ultrasonic waves, wherein a predetermined voltage or current including a dc component ...
# 182169  1. a system, comprising: a disposition engine comprising at least a processor, a memory, and computer-executable instructions stored in memory which when executed by the processor cause the processor to: receive data describing an item of a product wherein the data is comprised of at least produ...
# 182672  1. a composition comprising: a combination of a toll-like receptor 7 (tlr7) agonist, non-steroidal anti-inflammatory drug(s) (nsaids), a glucocorticoid anti-inflammatory agent, a vitamin a derivative, a vitamin d3 derivative, a mechanistic target of rapamycin (mtor) inhibitor or a combination th...
# 183784  we claim:1. a method of transforming data, comprising (i) identifying at least one pattern in a data structure resulting from or resembling data resulting from one or more stochastic mechanisms, wherein the stochastic mechanism comprises at least one stochastic process, the stochastic process co...
# 185729  what is claimed is:1. a system for analyzing an image of a human face for the presence of makeup, comprising:one or more processors and memory, including a dataset comprising images of human faces, the images comprising facial images of multiple human subjects, and including multiple images asso...
# 187482  1. a razor comprising: a. a handle comprising an implement connecting structure; b. an implement connected to the implement connecting structure; c. an implement displacement sensor positioned in the handle; d. a follower positioned in the handle, the follower having a first end and an opposing ...
# 187698  1. a device for inspecting and evaluating object surface defects, comprising: a computing device with one or more processors and memory; an automated control system controlled by a processor, operatively configured to receive instructions from a control module comprising computer-executable inst...
# 189703  1. a dispensing system having a dispenser for delivering a mixture of variable colour, the dispenser being able to be manipulated in one hand, and a computer system for operating the dispenser, this computer system having a touch screen on which the colour of the mixture can be displayed and a c...
# 190105  1. a system (10) configured to provide a user with recommendations indicating a fitness level of one or more topical skin products (15) with a personal care device (16), the system comprising:one or more hardware processors (18) configured by machine-readable instructions to:obtain information t...
# 191294  1. a method for providing beauty advice, the method comprising: obtaining personal information about a subject, the personal information including at least demographic information about the subject, the demographic information reflecting a geographic area location of the subject; determining loc...
# 191944  1. a makeup system based on expert knowledge, comprising: a makeup robot controlled to apply a cosmetic to a face of a user; a makeup server expert system including makeup information associated with makeup application and command profile information created by programming operation commands of ...
# 192304  1. a system, comprising: a support adapted to be worn on a head and support a light source to administer an effective amount of light to a nose of the head sufficient to treat a nasal disorder; and an adjustable nosepiece adapted to support the light source, wherein the adjustable nosepiece has ...
# 192616  1. a method of communicating event-based data relating to a material between machines during processing for feed-forward control in an event-based manufacturing system, the method comprising: collecting material-specific event-based data in response to events occurring during manufacturing, said...
# 194374  1. a makeup advice system which comprises:  a) an image data reception means for receiving image data transmitted by a remote located user, e.g. via network, such as an electronic network;  b) an imaging means for visually displaying the image data;  c) an image assessing means for determining a...
# 196020  1. a method for identifying molecules and processes of biological interest, comprising:  a) creating a map of biological elements, comprising the following steps: identifying seed nodes, adding related nodes, linking the seed nodes and the related nodes, optionally adding artificial nodes, addin...
# 196265  we claim:1. a cosmetics application system comprising: a smart looking glass; a housing comprising one or more openings; one or more product holders configured to be respectively received in said one or more openings in said housing; an id tag respectively secured to each said product holder, ea...
# 198899  1. a system configured to provide a user with recommendations indicating a fitness level of one or more topical skin products with a personal care device, the system comprising: one or more hardware processors configured by machine-readable instructions to: obtain information that identifies the...
# 199628  1. a method of sharing the amount of an online purchase transaction comprising the steps of: a) initiating a transaction between one or more users from among a plurality of users; b) selecting one or more of the users participating in the transaction; c) allocating the amount of the transaction ...
# 200168  we claim:1. a method comprising:displaying an image of a body portion of a user on an optical display of a device employed by the user, wherein the device comprises an image sensor and the image of the body portion of the user is sensed by the sensor;determining whether a position of the body po...
# 200396  a method for providing normalized physiological monitoring data of an individual with a measure of the quality of the normalization, comprising; providing a reference feature (367) based on a physiological attribute of the individual for which an attribute value can be determined and which can b...
# 201954  what is claimed is:1. a non-invasive imaging device, comprising: an illumination source comprising an incident light source to direct light upon skin; and a detector for detecting the degree of polarization of light reflected from the skin.2. the device of claim 1, wherein the illumination sourc...
# 205924  1. a method for recommending beauty products for a subject, comprising: using a genetic analyzer to generate subject genetic information; aggregating genetic information and cosmetic product response from a patient population; learning with a computer to generate at least one computer implemente...
# 208977  1. a method for rendering reality for an object, comprising: performing motion tracking and area learning of an environment; selecting a pattern or color from a plurality of product variations; blending the pattern or color of the object and the environment; and displaying the color on the objec...
# 209315  1. a method for determining the age range of a skin sample of a subject comprising analyzing nucleic acid from one or more genes listed in table 1, table 2, table 3, or any combination thereof, in a sample of the skin from the subject, thereby determining the age range of the skin of the subject...
# 209584  1. a driving state detection method, comprising: performing head pose detection and eye state detection on a driver image to obtain head pose information and eye state information; determining whether a deviation angle of a head location of a driver exceeds a preset range according to head locat...
# 210130  1. a sensor instrument system, comprising: a central station remote to a sensor instrument, said instrument is comprised of at least one sensor containing a gaseous sample of an analyte in a fluid that is connected to a detection module, a transmission module and a global positioning system (gps...
# 210149  1. a flavor/fragrance composition, comprising an effective amount of one or more compounds selected from tables 1-42.2. the flavor/fragrance composition of claim 1, wherein the composition is formulated as a spray, lotion, foam, gel, suspension, or emulsion.3. the flavor/fragrance composition of...
# 210373  1. a method of enabling simulated use of an aesthetic feature on a simulated facial image, the method comprising: enabling an individual to construct a simulated facial image using a facial construction computer program, the facial construction computer program permitting the individual to selec...
# 211447  1. a method for prognosing a risk of occurrence of a disease in a subject, comprising: a) determining respective values of a plurality of disease risk-factors for the subject; b) providing a database of individuals for whom the values of the plurality of disease risk-factors have been determined...
# 212642  1. a sensor, comprising: a. an analytical sensor including first, second and third identical electrodes, which are positioned equally spaced apart in order, alignment and parallel with each other, wherein said first and third electrodes are electrically connected in parallel by a first electrica...
# 213268  1. a beauty care method, comprising: obtaining first information representative of an external body condition of a subject; obtaining second information representative of the external body condition of the subject after the subject uses a beauty product; facilitating storage of information refle...
# 214657  1. a method of classifying a microbe, comprising: obtaining a nucleic acid sequence of a 16s or 23s ribosomal subunit contained within a single read length of a first microbe; and comparing said nucleic acid sequence of a first microbe to a reference; and identifying the first microbe at the str...
# 215294  1. a method of evaluating the influence of perturbagens on skin homeostasis for cosmetic use, the method comprising:causing a computer processor to query a data architecture of stored skin instances with an unhealthy skin gene expression signature, wherein each skin instance is associated with a...
# 215702  the embodiments of the invention in which an exclusive property or privilege is claimed are defined as follows:1. a method of training a machine learning model to detect cosmetic products in a face image, the method comprising: determining, by a computing device, a product present in the face im...
# 216451  the claims defining the invention are as follows:1) a system for delivering treatment to a biological subject, the system including:a) at least one substrate including a plurality of microstructures configured to breach a stratum comeum of the subject;b) at least one sensor operatively connected...
# 216476  1. a method for recommending products, comprising: performing motion tracking and understanding an environment with points or planes; acquiring sensor data from sensors and optimizing features extracted from each image and sensor data; selecting products each with dimensions from a 3d model plus...

# %%
#escludiamo tutti i sistemi per "raccomandare un prodotto"

df_candidate = df[(df[keyword] > 0) 
                  & (df.ipc_classes.str.count("G06")==0) #Escludo "COMPUTING; CALCULATING; COUNTING"
                  & (df.ipc_classes.str.count("G01")==0) #Escludo "MEASURING; TESTING"
                  & (df.ipc_classes.str.count("A61")==0) #MEDICAL OR VETERINARY SCIENCE; HYGIENE
                  & (df.ipc_classes.str.count("A01N")==0) #SOIL WORKING IN AGRICULTURE OR FORESTRY; PARTS, DETAILS, OR ACCESSORIES OF AGRICULTURAL MACHINES OR IMPLEMENTS, IN GENERAL
                  & (df.ipc_classes.str.count("(^| )A")>0)].query("title not in @df_selected")

df_candidate[["filename", "title", "ipc_classes","claims"]]
# Out:
#                    filename  \
# 27784      EP3733278_A1.txt
# 106389  US2012003728_A1.txt
# 120991     EP3769852_A1.txt
# 166422  US2020405037_A1.txt
# 182147  US2020329742_A1.txt
# 210149  US2020399558_A1.txt
#
#                                                                                                                                                      title  \
# 27784                        moisture control device, moisture control method, program, storage medium, generated substance, product, device and equipment
# 106389                                                             scalable portable sensory and yield expert system for biomass monitoring and production
# 120991  pump- actuated dispenser with integrated switch, system and method for remote monitoring of product consumption from said pump- actuated dispenser
# 166422                                                                                                       cosmetic package including a liquid reservoir
# 182147                     moisture control apparatus, moisture control method, program, storage medium, produced object, product, apparatus, and facility
# 210149                                                                              methods for identifying, compounds identified and compositions thereof
#
#                                                                                                    ipc_classes  \
# 27784                       A23L3/26, A23L3/30, A23L3/32, A23L5/30, A47J37/12, B01J19/08, B01J19/10, B01J19/12
# 106389                                                                A01G31/02, C12M1/34, F21V33/00, G02F1/01
# 120991                                                     A47K5/12, B05B11/00, B05B12/00, B05B15/30, H02N2/18
# 166422                                                                                               A45D34/04
# 182147  A23L3/26, A23L3/30, A23L3/32, A23L5/10, A23L5/30, A47J37/12, B01J19/08, B01J19/10, B01J19/12, C02F1/48
# 210149                                                                                     A23L27/00, C11B9/00
#
#                                                                                                                                                                                                                                                                                                              claims
# 27784   1. a moisture control apparatus, wherein a predetermined voltage or current including a dc component and/or an ac component is applied to at least one electrode that generates at least one of an electric field, a magnetic field, an electromagnetic field, electromagnetic waves, sound waves, and u...
# 106389  1. a system for optimizing plant growth in a liquid environment within an enclosed growth chamber, comprising: illumination means for controlling spatial, temporal and spectral characteristics of illumination surrounding the growth chamber, said illumination means comprising an array of individu...
# 120991  1. a pump-actuated dispenser (1) comprising: a compression pump (2) and a pump actuator (3) to operate the compression pump (2), the pump actuator (3) having a nozzle (4) for the output of a product to be dispensed, wherein the pump actuator (3) is displaceable between two end positions, a resti...
# 166422  the embodiments of the invention in which an exclusive property or privilege is claimed are defined as follows:1. a cosmetic formula container, comprising: a container body configured to retain a portion of a cosmetic formula within a cavity, the container body having a neck configured to receiv...
# 182147  1. a moisture control or current comprising: at least one electrode configured to generate at least one of an electric field, a magnetic field, an electromagnetic field, electromagnetic waves, sound waves, and ultrasonic waves, wherein a predetermined voltage or current including a dc component ...
# 210149  1. a flavor/fragrance composition, comprising an effective amount of one or more compounds selected from tables 1-42.2. the flavor/fragrance composition of claim 1, wherein the composition is formulated as a spray, lotion, foam, gel, suspension, or emulsion.3. the flavor/fragrance composition of...

# %%
df_selected = pd.concat([df_selected, df_candidate])
len(df_selected)
# Out:
# 36

# %% [markdown]
# ##### beauty

# %%
keyword = keywords_cosmetics[1]
keyword
# Out:
# 'beauty'

# %%
df_candidate = df[(df[keyword] > 0)
                  & (df.ipc_classes.str.count("G06")==0) #Escludo "COMPUTING; CALCULATING; COUNTING"
                  & (df.ipc_classes.str.count("G01")==0) #Escludo "MEASURING; TESTING"
                  & (df.ipc_classes.str.count("A61")==0) #MEDICAL OR VETERINARY SCIENCE; HYGIENE
                  & (df.ipc_classes.str.count("C12Q")==0) #MEASURING OR TESTING PROCESSES INVOLVING ENZYMES, NUCLEIC ACIDS ...
                  & (df.ipc_classes.str.count("H04")==0) #ELECTRIC COMMUNICATION TECHNIQUE
                 ].query("title not in @df_selected")

df_candidate[["filename", "title", "ipc_classes","abstract", "claims"]]
# Out:
#                    filename  \
# 5337    US2016369204_A1.txt
# 7363    WO2019143922_A1.txt
# 27784      EP3733278_A1.txt
# 31462   WO2019122838_A1.txt
# 62406   US2019224871_A1.txt
# 140736  US2020171687_A1.txt
# 182147  US2020329742_A1.txt
#
#                                                                                                                                   title  \
# 5337                                                                                                    method of making perfumed goods
# 7363                                                                                                                 personal appliance
# 27784     moisture control device, moisture control method, program, storage medium, generated substance, product, device and equipment
# 31462                                                                                                        training system and device
# 62406                                                                                                                personal appliance
# 140736                                                                                                               personal appliance
# 182147  moisture control apparatus, moisture control method, program, storage medium, produced object, product, apparatus, and facility
#
#                                                                                                    ipc_classes  \
# 5337                                                                                        C11B9/00, C11D3/50
# 7363                                                                                      B26B19/38, B26B21/40
# 27784                       A23L3/26, A23L3/30, A23L3/32, A23L5/30, A47J37/12, B01J19/08, B01J19/10, B01J19/12
# 31462                                                                 A45D1/00, G09B19/00, G09B19/24, G09B5/04
# 62406                                                                          B26B19/38, B26B21/40, B26B21/52
# 140736                                                                                    B26B19/38, B26B21/40
# 182147  A23L3/26, A23L3/30, A23L3/32, A23L5/10, A23L5/30, A47J37/12, B01J19/08, B01J19/10, B01J19/12, C02F1/48
#
#                                                                                                                                                                                                                                                                                                            abstract  \
# 5337                                                                                                       the present invention relates to methods of designing and making perfumed products and perfume raw materials for use in products and perfume raw materials selected by such methods and the use of same.
# 7363    a personal appliance. the personal appliance includes a handle having an implement connecting structure. an implement is connected to the implement connecting structure. an implement displacement sensor is positioned in the handle. the implement displacement sensor measures a displacement of the...
# 27784   provided are a moisture control apparatus, a moisture control method, a program, a storage medium, a produced object, a product, an apparatus, and a facility that can improve the characteristics of an object through moisture control. in a moisture control apparatus according to one aspect of the...
# 31462   a beauty product device is disclosed which includes a variety of sensors for sensing the way in which a user is operating the device. the sensor data can be processed and compared with pre-stored data representative of a desired style and feedback messages generated and provided back to the user...
# 62406   a personal appliance. the personal appliance includes a handle having an implement connecting structure. an implement is connected to the implement connecting structure. an implement displacement sensor is associated with the handle. the implement displacement sensor measures a displacement of t...
# 140736  a personal appliance. the personal appliance includes a handle having an implement connecting structure. an implement is connected to the implement connecting structure. an implement displacement sensor is positioned in the handle. the implement displacement sensor measures a displacement of the...
# 182147  provided are a moisture control apparatus, a moisture control method, a program, a storage medium, a produced object, a product, an apparatus, and a facility that can improve the characteristics of an object through moisture control. in a moisture control apparatus according to one aspect of the...
#
#                                                                                                                                                                                                                                                                                                              claims
# 5337    1. a method comprising: a.) using an odt value determined by mathematical modelling to select one or more perfume raw materials; b.) combining and/or processing said one or more perfume raw materials with one or more additional materials to form a product.2. the method of claim 1, wherein said p...
# 7363    what is claimed is:1. a personal appliance comprising:a. a handle comprising an implement connecting structure;b. an implement connected to the implement connecting structure;c. an implement displacement sensor positioned in the handle, the implement displacement sensor measuring a displacement ...
# 27784   1. a moisture control apparatus, wherein a predetermined voltage or current including a dc component and/or an ac component is applied to at least one electrode that generates at least one of an electric field, a magnetic field, an electromagnetic field, electromagnetic waves, sound waves, and u...
# 31462   1. a beauty product system for performing a treatment on a user, the system comprising:an input for allowing the user to specify a desired treatment to be performed; a beauty product device that is manipulate by the user to perform the desired treatment on the user; the beauty product device hav...
# 62406   1. a personal appliance comprising: a. a handle comprising an implement connecting structure; b. an implement connected to the implement connecting structure; c. an implement displacement sensor associated with the handle, the implement displacement sensor measuring a displacement of the impleme...
# 140736  1. a personal appliance comprising: a. a handle comprising an implement connecting structure; b. an implement connected to the implement connecting structure; c. an implement displacement sensor positioned in the handle; and d. a follower positioned in the handle, the follower having a first end...
# 182147  1. a moisture control or current comprising: at least one electrode configured to generate at least one of an electric field, a magnetic field, an electromagnetic field, electromagnetic waves, sound waves, and ultrasonic waves, wherein a predetermined voltage or current including a dc component ...

# %%
df_selected = pd.concat([df_selected, df_candidate])
len(df_selected)
# Out:
# 43

# %% [markdown]
# ##### body (troppo rumore)

# %%
keyword = keywords_cosmetics[2]
keyword
# Out:
# 'body'

# %%
df_candidate = df[(df[keyword] > 0)
                  & (df.ipc_classes.str.count("G06")==0) #Escludo "COMPUTING; CALCULATING; COUNTING"
                  & (df.ipc_classes.str.count("G01")==0) #Escludo "MEASURING; TESTING"
                  & (df.ipc_classes.str.count("A61")==0) #MEDICAL OR VETERINARY SCIENCE; HYGIENE
                  & (df.ipc_classes.str.count("A63H")==0) #TOYS, e.g. TOPS, DOLLS, HOOPS OR BUILDING BLOCKS
                  & (df.ipc_classes.str.count("G09")==0) #EDUCATION; CRYPTOGRAPHY; DISPLAY; ADVERTISING; SEALS
                  & (df.ipc_classes.str.count("G10")==0) #MUSICAL INSTRUMENTS; ACOUSTICS
                  & (df.ipc_classes.str.count("(^| )A")>0)
                  ].query("title not in @df_selected")[["title", "ipc_classes","abstract", "claims"]]

df_candidate
# Out:
#                                                                                                                                                                 title  \
# 566                                                                                                       systems and methods for data-driven movement skill training
# 2654                                                                                                                         mobile robot and control method therefor
# 3478                                                                                                              connected food preparation system and method of use
# 4902                                                                                                     dribbling and ball control sports training system and method
# 5260                                                                                                                                                 a connected oven
# 8076                                                                                       multiview body camera system with environmental sensors and alert features
# 8368                                                                 robot cleaner and robot cleaning system having the same and method for operating a robot cleaner
# 10150                                                                                                                 apparatus and method for analysing a golf swing
# 11158                                                                                                             robot cleaner and a controlling method for the same
# 11876                                                                                                                                    personally powered appliance
# 13067                                                                                                  method for matching a golfer with a particular golf club style
# 14519                                                                                                    measurement of protease activity in post-mortem meat samples
# 14785                                                                                                                                 ladle and robot having the same
# 17087                                                                    method and device for associating frames in a video of an activity of a person with an event
# 17151                                                                                                                         game channels in messaging applications
# 19154                                                                                                     moving robot, method for controlling the same, and terminal
# 19330                                                                                                         robot cleaner and robot cleaning system having the same
# 20079                                                                        dryer for receiving herbaceous material with independently controlled heating subsystems
# 20738                                                                                                                                                    mobile robot
# 21464                                              methods for assessing repellant quality of organic materials and methods and compositions for repelling arthropods
# 22011                                                                                                            clean room, clean room suit and arrangement therefor
# 24874                                                                                                                              limb sleeve to be worn by a wearer
# 25711                                                                                                                               automated flying insect separator
# 26173                                                                                                                                  a robotic fruit picking system
# 27058                                                                 method and device for determining attitude of virtual object in virtual environment, and medium
# 29204                                                                                           intein-modified enzymes, their production and industrial applications
# 29434                                                                                                                     robot system and control method of the same
# 30204                                                                                                                    method and system for analysing a golf swing
# 30547                                                                                                  optimal feeding based on signals in an aquaculture environment
# 32095                                                                                                                               disposable cup with fold-down lid
# 32237                                                                                                                           system for controlling wearable media
# 33575                                                                                    vertical grow tower conveyance system for controlled environment agriculture
# 35815                                                                    beverage capsule for preparing a beverage by centrifugation in a beverage preparation device
# 35916                                                                                               bendable sensor device for monitoring joint extension and flexion
# 38426                                                                                                                         moving robot and control method thereof
# 40011                                                                                                                               disposable cup with fold-down lid
# 41265                                                                                                                                                    seat cushion
# 41294                                                                                              irrigation system for vertical grow tower crop production facility
# 41298                                                                                                                 apparatus and method for analyzing a golf swing
# 42587                                                                                                                             context-aware gamification platform
# 42806                                                                                                                            games tabs in messaging applications
# 43505                                                                      real-time, fully interactive, virtual sports and wellness trainer and physiotherapy system
# 44073                                                                                                        golf club head with improved aerodynamic characteristics
# 46330                                                                                                                        mobile robot and control method therefor
# 48627                                                                                                                              lighting module for indoor farming
# 50542                                                                                                                                      automatic beverage machine
# 52844                                                                                                                  vaporizer device with improved wick saturation
# 53254                                                                                                                 apparatus and method for analysing a golf swing
# 54482                                                                                                                                      automatic beverage machine
# 58209                                                                                                                            interactive personal training system
# 58340                                                                                                                                mobile cleaning robot for floors
# 58373                                                                                                                                  energy return orthotic systems
# 58450                                                                                              custom footwear and custom footwear fabrication system and methods
# 58460                                                                                                          puff sensing and power circuitry for vaporizer devices
# 59052                                                                                                        golf club head with improved aerodynamic characteristics
# 60334                                                                                                 artificial intelligence moving robot and control method thereof
# 60488                                                                                                                                  energy return orthotic systems
# 60621                                                                                                             connected food preparation system and method of use
# 60738                                                                                  table furniture and assembly kit for generating an array of items of furniture
# 62995                                                                                                                                cartridges for vaporizer devices
# 63004                                                                                                                                                    seat cushion
# 63152                                                                                                         robot cleaner and robot cleaning system having the same
# 63185                                                                                                      assembly kit for generating an array of items of furniture
# 63464                                                                                                      racing helmet with visual and audible information exchange
# 66257                                                                                                                                                     game design
# 66701                                                                                                              method and apparatus for sex sorting of mosquitoes
# 67398                                                                                                                                             gardening apparatus
# 68175                                                                                                                                           inspection of poultry
# 69575                                                                                                                          method of controlling a livestock farm
# 69896                                                                                         method for simulating the rendering of a make-up product on a body area
# 73204                                                                                                        detecting illegal moves in a game using inertial sensors
# 73457                                              methods for assessing repellant quality of organic materials and methods and compositions for repelling arthropods
# 74528                                                                  methods and articles for providing a body jewelry accessory comprising an edible candy portion
# 74932                                                                                                                      gameplay threads in messaging applications
# 75145                                                                                                                                      automatic beverage machine
# 77686                                                                                                         fall protection equipment connection status and control
# 78245                                                                                           intein-modified enzymes, their production and industrial applications
# 78879                                                                        training system and methods for designing, monitoring and providing feedback of training
# 79432                                                                                                                             vaporizer device with subassemblies
# 79582                                                                                                  method for matching a golfer with a particular golf club style
# 80578                                                            a method for providing and analyzing an animal population having an essentially identical metabolome
# 83065                                                                                                                       beverage machines with a removable module
# 84021                                                                                                          wearable technology for sleep environment modification
# 87468                                                                                                                                          themed eating utensils
# 88464                                                                                                                            system for monitoring pasture intake
# 89087                                                                                                   near-realistic sports motion analysis and activity monitoring
# 90055                                                                                                                                                    mobile robot
# 90992                                              methods for assessing repellant quality of organic materials and methods and compositions for repelling arthropods
# 91709                    movable automatic feeding device, companion animal care robot, companion animal care system comprising same, and method for controlling same
# 92321                                                                                                                         mobile robot and control method thereof
# 92650                                                                                                                       smart safety apparatus, system and method
# 93229                                                                                                                                      automatic beverage machine
# 93745                                                                                                                                         unmanned aerial vehicle
# 94442                                                                                                                                         unmanned aerial vehicle
# 94577                                                                                                                            games tabs in messaging applications
# 94626                                                                                                                                            vent valve flow fuse
# 95067                                              methods for assessing repellant quality of organic materials and methods and compositions for repelling arthropods
# 96265                                                                                                                        a system for capturing tennis match data
# 97703                                                                                                                                                           robot
# 100473                                                                                                                         beverage package with induction heater
# 101841                                                                                                                 macroscopic quantum effects for computer games
# 102139                                                                                                                                            vaporization device
# 103405                                                                                                     combined, bilateral, adjustable agricultural tool platform
# 103883                                                                                                                                       detachable training hold
# 104152                                                                                       posture coaching system and method for weight training by motion pattern
# 104392                                                                                               plurality of robot cleaner and a controlling method for the same
# 104659                                                                            fall protection equipment having inductive sensor for connection status and control
# 104861                                                                                                artificial intelligence moving robot and control method thereof
# 104945                                                                               collection device and method for stimulating and stabilizing a biological sample
# 105285                                                                                             systems and methods for delivering a personalised dose of exercise
# 105451                                                                                                                                                   burger press
# 107245                                                                                                        fall protection equipment connection status and control
# 108731                                                                                                                                                nursing garment
# 108810                                                                                                                                a spray apparatus for a vehicle
# 108964                                                                                                           robot cleaner, robot cleaning system having the same
# 109847                                                                                                                  method and apparatus for breeding virtual pet
# 111004                                                                                                                                     automatic beverage machine
# 111789                                                                                                                            context-aware gamification platform
# 111965                                                                                          intein-modified enzymes, their production and industrial applications
# 112846                                                                                                  table with one or more tap gesture-activated light indicators
# 114725  methods, systems, and non-transitory computer readable media for estimating maximum heart rate and maximal oxygen uptake from submaximal exercise intensities
# 114914                                                                                                                    farm asset tracking, monitoring, and alerts
# 116166                                                                                                                      tool holder with tabs and/or suction cups
# 116338                                                                                                                                                          robot
# 117247                                                                                     multiview body camera system with environmental sensors and alert features
# 118149                                                                                                                                 energy return orthotic systems
# 118233                                                                                                                                   method for design of insoles
# 118261                                                                                                     slide rail mechanism and adjusting assembly for slide rail
# 119076                                                                                          methods and systems for food preparation in a robotic cooking kitchen
# 119112                                                                                                                                        wireless device pairing
# 119738                                                                                                                                                   smart device
# 121331                                             methods for assessing repellant quality of organic materials and methods and compositions for repelling arthropods
# 123525                                                                                                               golf equipment identification and fitting system
# 124027                                                                                             automatic machine for user-controlled production of a food product
# 124209                                                                                                     assembly kit for generating an array of items of furniture
# 126216                                                                                          system, method and apparatus for exercise or rehabilitation equipment
# 131716                                                                                                                                     automatic beverage machine
# 132213                                                                                                      user interface and user experience for a vaporizer device
# 132553                                                                                                                apparatus and method for analysing a golf swing
# 132697                                                                                                           method and system for real-time livestock management
# 134253                                                                                                              robot cleaner and method for controlling the same
# 135443                                                                                                                     electronic watch clasp systems and methods
# 138207                                                                                                                          sports competition application system
# 138483                                                                                                            connected food preparation system and method of use
# 138871                                                                                                                                          robot and drone array
# 139736                                                                                                                                     surface cleaning apparatus
# 139812                                                                                                                     intelligent table game and methods thereof
# 140423                                                                                                                apparatus and method for analysing a golf swing
# 140622                                                                                 table furniture and assembly kit for generating an array of items of furniture
# 141067                                                                             method and apparatus for controlled rehabilitation and training of muscular system
# 141436                                                                 robot cleaner, robot cleaning system having the same, and method for operating a robot cleaner
# 141856                                                                                                                                                   burger press
# 143426                                                                                                                                    portable exercise equipment
# 143567                                                                                          database establishment and analysis method for the behavior from game
# 144560                                                                                                                                pupae singulator and sex sorter
# 145112                                                                   system, apparatus and method of item location, list creation, routing, imaging and detection
# 146109                                                                                                                                      autonomous cleaning robot
# 146700                                                                                                                                 energy return orthotic systems
# 147003                                                                                                            connected food preparation system and method of use
# 147791                                             methods for assessing repellant quality of organic materials and methods and compositions for repelling arthropods
# 148002                                                                                                        robot cleaner and robot cleaning system having the same
# 148783                                                                                                                      angled hitting stand apparatus and method
# 149045                                                                                      information processing device, information processing method, and program
# 149412                                                                                                                         submersible fishing device for fishing
# 149688                                                                                                                                 energy return orthotic systems
# 150710                                                                                                                            biosynthetic genes and polypeptides
# 150979                                                                             method and apparatus for controlled rehabilitation and training of muscular system
# 152901                                                                                                                apparatus and method for analysing a golf swing
# 153763                                                                                                                        golf swing training and exercise method
# 154214                                                                                                    dynamic technique for fitting pressure-suits to individuals
# 155987                                                                                  method and apparatus for displaying virtual pet, terminal, and storage medium
# 156403                                                           a method for providing and analyzing an animal population having an essentially identical metabolome
# 158609                                                                                                                apparatus and method for analyzing a golf swing
# 158644                                                                                        method for simulating the rendering of a make-up product on a body area
# 159633                                                                                                                                       custom golf club fitting
# 160188                                                                                      mobile robot using artificial intelligence and controlling method thereof
# 161143                                                                                                                 extensively reconfigurable vehicle seat design
# 162498                                                                                                   table and kit for creating an assembly of items of furniture
# 166422                                                                                                                  cosmetic package including a liquid reservoir
# 166541                                                                                                                     interchangeable footwear system and method
# 166708                                                                                                    method and system for tracking health in animal populations
# 167040                                                                                                                                     surface cleaning apparatus
# 168546                                                                   method of real time monitoring of a person during an event and event dynamics system thereof
# 170015                                                                                                                                        unmanned aerial vehicle
# 170567                                                                                                                                         themed eating utensils
# 171741                                                                     real-time, fully interactive, virtual sports and wellness trainer and physiotherapy system
# 172125                                                                 robot cleaner, robot cleaning system having the same, and method for operating a robot cleaner
# 172607                                                                                                                                    portable exercise equipment
# 172650                                                                                                                         system for capturing tennis match data
# 172834                                                                                                                                                   burger press
# 173554                                                    system and method to automatically determine irregular polygon for environmental hazard containment modules
# 173565                                                                                                                                             cultivation system
# 173929                                                                                                                     electronic watch clasp systems and methods
# 174064                                                                                                                              disposable cup with fold-down lid
# 174215                                                                                                                  interactive liquid spraying system and method
# 176110                                                                                                          a robot cleaner and a controlling method for the same
# 176647                                                                                                              method and apparatus for automated plant necrosis
# 177420                                                                                                                                                   burger press
# 177683                                                                                                                         system for capturing tennis match data
# 177793                                                                                                                   mobile robot and method for controlling same
# 177821                                                                                                                    bedding system with support surface control
# 177926                                                                                                                             seat and posture estimation system
# 180460                                                                                                           method and system for real-time livestock management
# 182396                                                                                                                  method and system for a similarity-based game
# 185266                                                                                                            connected food preparation system and method of use
# 189846                                                                                                                            seamless wearable structure garment
# 191569                                                                                                             optical based wireless pairing of vaporizer device
# 191721                                                                                                             electric home appliance and control method thereof
# 192272                                                                                                 electronic device and method for providing information thereof
# 192431                                                                                                 method for matching a golfer with a particular golf club style
# 195508                                                                                                               golf equipment identification and fitting system
# 195520                                                                                                                         processing system for straddle vehicle
# 195521                                                                                                                     interchangeable footwear system and method
# 196207                                                               robot cleaner and robot cleaning system having the same and method for operating a robot cleaner
# 196556                                                                   method of real time monitoring of a person during an event and event dynamics system thereof
# 196649                                                                                                                                 energy return orthotic systems
# 198364                                                                                               upper saddle to secure the barrel of a weapon for weapon storage
# 199061                                                                                                          autonomous lawn mower blade sharpening and task robot
# 199718                                                                                             methods and apparatus for unmanned aircraft-based object detection
# 199799                                                                                             methods and apparatus for unmanned aircraft-based object detection
# 201532                                                                                                               grip with electronic system and exterior venting
# 201715                                                                                                                     electronic watch clasp systems and methods
# 206173                                                                                                                apparatus and method for analysing a golf swing
# 207444                                                                                                                                               vaporizer device
# 207937                                                                           smart cattle reproduction management and digital farm to market transparency metrics
# 208832                                                                                                apparatus and method for rehabilitation employing a game engine
# 209104                                                                                                            system and method for automated grounds maintenance
# 209967                                                                                                                     electronic watch clasp systems and methods
# 209972                                                                                                                       mobile robot and control method therefor
# 210758                                                                                                              transgenic chicken that produces human antibodies
# 214088                                                                                                     slide rail mechanism and adjusting assembly for slide rail
# 215703                                                                                                                                                   work vehicle
# 216900                                                                                                                      vaporizer devices with integrated sensors
#
#                                                                                                                                                                                                                                                                                                         ipc_classes  \
# 566                                                                                                                                                                                                                                                                                 A63B24/00, A63B69/40, A63B71/06
# 2654                                                                                                                                                                                                                                                   A47L9/28, B25J11/00, B25J19/02, B25J9/00, B25J9/16, G05D1/02
# 3478                                                                                                                                                                                                                              A23L5/10, A47J36/32, A47J37/06, F24C15/00, F24C3/12, F24C7/08, H04W4/80, H05B1/02
# 4902                                                                                                                                                                                                                                                                                                      A63B69/00
# 5260                                                                                                                                                                                                          A23L5/10, A47J36/32, A47J37/06, F24C15/00, F24C3/12, F24C7/06, F24C7/08, H04W4/80, H05B1/02, H05B6/68
# 8076                                                                                                                                                                                                                                        A41D1/00, A41D1/04, A42B3/04, G02B27/01, H04N5/00, H04N5/225, H04N5/247
# 8368                                                                                                                                                                                                                                                                                                       A47L9/28
# 10150                                                                                                                                                                                                                                                                                                     A63B69/36
# 11158                                                                                                                                                                                                                                                                                           A47L11/40, G05D1/02
# 11876                                                                                                                                                                                                                                                           A43B3/00, G08B21/02, H01L41/113, H04B1/38, H04Q9/00
# 13067                                                                                                                                                                                                                                                                               A63B57/00, A63B59/00, A63B69/36
# 14519                                                                                                                                                                                                                                                                                                     A23L13/00
# 14785                                                                                                                                                                                                                                                                     A47J43/28, B25J15/00, B25J15/04, B25J9/16
# 17087                                                                                                                                                                                                                                                        A63B69/00, G11B27/031, G11B27/10, G11B27/19, G11B27/30
# 17151                                                                                                                                                                                                 A63F13/30, A63F13/35, A63F13/79, A63F13/795, A63F13/87, A63F13/92, H04L12/58, H04L29/06, H04L29/08, H04M1/725
# 19154                                                                                                                                                                                                                                                                                 A01D34/08, B25J5/00, G05D1/02
# 19330                                                                                                                                                                                                                                                                                                      A47L9/28
# 20079                                                                                                                                                                                                                                                                     A24B3/04, F26B11/02, F26B11/04, F26B11/06
# 20738                                                                                                                                                                                                                                                 A47L11/24, A47L11/40, A47L5/00, A47L9/28, B62D57/00, G05D1/02
# 21464   A01N31/02, A01N31/06, A01N33/10, A01N35/02, A01N35/04, A01N35/06, A01N35/10, A01N37/10, A01N37/18, A01N37/20, A01N37/22, A01N37/36, A01N37/44, A01N37/46, A01N43/12, A01N43/16, A01N43/32, A01N43/38, A01N43/40, A01N43/42, A01N43/50, A01N43/54, A01N43/60, A01N43/78, A01N43/90, A01N47/16, A01N47/42,...
# 22011                                                                                                                                                                                                                                                                                           A62B17/00, B01L1/04
# 24874                                                                                                                                                                                                                                                                                A41D1/00, A41D27/10, A41D31/30
# 25711                                                                                                                                                                                                                                                                                         A01K29/00, A01K67/033
# 26173                                                                                                                                                                                                                                                                                                     A01D46/30
# 27058                                                                                                                                                                                                                                                                                                     A63F13/55
# 29204                                                                                                                                                                                                                                                 A01H5/00, C07K14/415, C12N15/63, C12N9/14, C12N9/42, C12Q1/34
# ...
# 168546  1. a method of monitoring at least one person in an event, comprising: providing at least one sensor, measuring data using the at least one sensor, wherein the measured data includes data representative of a motion of at least one part of the person's body; the method further comprising, by a pr...
# 170015  1. an unmanned aerial vehicle (10) for application of an active ingredient to agricultural crops, comprising: - at least one liquid reservoir (20); - at least one liquid application unit (30); - a processing unit (40); - at least one set of rotor blades (50); and - a plurality of legs (60); wher...
# 170567  1. a utensil incorporating depictions of animal features in an animal theme comprising : a first utensil element depicting a first feature of an animal depiction corresponding to said animal theme ; and a second utensil element depicting a second feature of an animal depiction corresponding to s...
# 171741  what is claimed is:1. a telehealth training system comprising:a three-dimensional camera programmed for capturing image data associated with an exercise program performed by a user;a computer-implemented body pose analysis and scoring module programmed for analyzing and scoring body poses of the...
# 172125  1. a robot cleaner comprising: a main body; a traveling unit that moves the main body; a cleaning unit that executes a cleaning operation; a camera that captures an image of a foreign substance; a communication unit that exchanges data with a mobile terminal or a server; and a controller that co...
# 172607  1. a portable exercise device, comprising: a) a squat, substantially rectangular body having an upper surface, said upper surface being of sufficient size to completely support the feet of a user of said portable exercise device; b) a first guide mechanism disposed proximate a front, right corne...
# 172650  1. a system for capturing personal tennis match data of a tennis player comprising: a voice receiving device comprising a microphone for recording words spoken by said tennis player during a tennis match, a dedicated tennis match vocabulary adapted to describe tennis match action, a voice analyz...
# 172834  [0049] the embodiments of the invention in which an exclusive property or  privilege is claimed are defined as follows:1. a burger press comprising: a base having upward extending sidewalls; a lifter sized and shaped to fit within the base; and a plunger having a handle attached to a first side ...
# 173554  1. an environmental hazard containment module, comprising: a module body extending along an axis from a first end to a second end opposite the first end: a communication device to exchange location information with a plurality of remote containment modules having similar structures: a first moti...
# 173565  1. a cultivation system comprising: a plurality of cultivation containers each capable of accommodating a plant and a cultivation medium used for growing the plant and each provided with a recording medium recording identification information identifying the accommodated plant; a cultivation she...
# 173929  1. a watch comprising: a mechanical watch, the mechanical watch having a mechanical watch housing, and a mechanical watch face retained at least partially within the mechanical watch housing; a first watch band portion having a first end and a second end, wherein the first end of the first watch...
# 174064  1. a disposable cup having a body portion and a lid portion, said lid portion extending upwardly from one side of said body portion of the cup when in an open position, and arranged to flip from convex to concave along an arcuate first score line into a position within the body of the cup and ac...
# 174215  having this described the invention, what is claimed as new and desired to be secured by letters patent is:1. an interactive liquid spraying system, which comprises: a fluid source adapted for containing a quantity of spraying liquid; a pump with an inlet connected to the fluid source; a flow co...
# 176110  what is the claimed is:1. a mobile robot, comprising: a main body; a moving unit configured to move the main body; a communication unit configured to communicate with a second mobile robot that emits a signal; and a controller configured to: recognize a position of the second mobile robot using ...
# 176647  we claim:1. a method of distinguishing individual plants within a row of plants extending from a ground, comprising:   • illuminating two contiguous plants within the row at an angle between the ground and a normal vector to the ground with a light;   • collecting an image of the two plants with...
# 177420  1. a burger press comprising: a base forming a lower perimeter and having sidewalls extending upwardly from the lower perimeter; a lifter having a lifter perimeter sized and shaped to removably fit snugly within the lower perimeter of the base, the lifter further having a lifter handle comprisin...
# 177683  1. a system for capturing personal ball game data of a player and in particular personal tennis match data of a tennis player comprising: a voice receiving device comprising a microphone adapted to record words spoken by said player or tennis player, respectively, during a tennis match, a dedica...
# 177793  1. a moving robot comprising: a travelling unit configured to move a main body; an image acquisition unit configured to acquire an image around the main body; a sensor unit including at least one sensor configured to sense an obstacle during moving; a storage unit configured to store information...
# 177821  1. a method for automatically adjusting a bedding system for a sleeper who is sleeping on the bedding system, the method comprising: measuring, by a pressure mapping engine, a two-dimensional pressure image of the sleeper on the bedding system while the sleeper is sleeping on the bedding system;...
# 177926  1. a seat comprising: a seat main body; at least one 3-axis acceleration sensor arranged in the seat main body; and an estimation device that estimates a posture of a seated person on the seat main body, the estimation device comprising: a storage that stores a learning model built by machine le...
# 180460  we claim:1. a method of managing livestock health in real-time, the method comprising obtaining real-time livestock sensor data from at least one sensor located on or around one or more livestock, the data comprising at least one of livestock weight, livestock activity level, livestock ammonia l...
# 182396  1. a method for a game for a plurality of players, the method comprising the steps of:  (a) selecting a referent from a predetermined set of referents;  (b) determining correspondences between each of the players and the referent;  (c) assigning scores to each player based, at least in part, upo...
# 185266  we claim:1. an oven system, comprising: a cooking body defining a cooking cavity, the cooking body comprising a top and a bottom; an optical sensor mounted proximal to the top, wherein the optical sensor is directed toward the cooking cavity; a detection module configured to automatically detect...
# 189846  1. a garment comprising a seamless wearable structure, wherein said structure has at least one tubular portion and at least three body-part openings.2. 2-5. (canceled)6. the garment of claim 1, being said single seamless wearable structure.7. the garment of claim 1, wherein said structure compri...
# 191569  what is claimed is:1. a vaporizer device, comprising:a controller configured to at least:generate a first key for establishing a wireless communication link with a computing device;cause an optical signal corresponding to the first key to be outputted;receive, from the computing device, a second...
# 191721  1. an electric home appliance comprising: a sensing unit (130, 230) for sensing whether a human body is within a predetermined range; an input unit (140, 240) for allowing a user's input, the input unit (140, 240) being configured to be protruded or retreated based on a result sensed by the sens...
# 192272  1. an electronic device comprising: a housing; a user interface; at least one camera disposed on the housing; at least one driver connected to or disposed on the housing to move the housing; a wireless communication circuit located within the housing; a memory; and a processor operatively connec...
# 192431  we claim:1. a method for determining the preferred mechanical properties of a golf club for a golfer being fitted based upon a swing type determined for the golfer, the method comprising: measuring a set of performance parameters while the golfer being fitted makes a plurality of golf swings wit...
# 195508  1. a system for identifying golf equipment, the system comprising: one or more performance tracking devices, wherein the one or more performance tracking devices include at least one of an optical sensor system or a radar sensor system for tracking at least one of a golf club swing or a golf bal...
# 195520  1. a processing system for a straddle vehicle, the processing system comprising: an input section which receives information relating to a reaction of a rider of the straddle vehicle; a processor section which learns a reaction trend of the rider based on the information relating to the rider's ...
# 195521  what is claimed:1. an interchangeable footwear system, comprising: a plurality of interchangeable uppers; a plurality of interchangeable heels; and a quick-release device for selectively engaging a heel of the plurality of interchangeable heels with an upper of the plurality of interchangeable u...
# 196207  1. a robot cleaner (200) comprising: a traveling unit (280) configured to move a main body; a cleaning unit (245) configured to execute cleaning; a camera (230) configured to capture an image including foreign substances; a communication unit (222) configured to exchange data with a mobile termi...
# 196556  1, a method of monitoring at least one person in an event, comprising:pro viding at least one sensor,measuring data using the at least one sensor, wherein the measured data includes data representati ve of a motion of at least one part of the person's body;the method further comprising, by a pro...
# 196649  1. a tri-layer orthotic system comprising: a base layer having a distal toe end and a proximal heel end; a mid-layer having a distal toe portion, a mid-portion and a proximal heel portion, said distal toe portion of the mid-layer operably coupled to the distal toe end of the base layer to form a...
# 198364  1. an upper saddle of a weapon storage rack for securing a barrel of a firearm comprising: an upper saddle body with an about u-shaped opening adapted to accept the barrel of the firearm; and a pair of snap locks disposed in or on said upper saddle, said pair of snap locks including a left snap ...
# 199061  1. an autonomous lawn mower blade sharpening and task robot configured to drive under at least one of a lawn mower and a lawn mower deck, the robot comprising: a. at least one camera; b. at least one sensor; c. at least one task arm; and d. at least one task tip.2. the autonomous lawn mower blad...
# 199718  we claim:1. an object detection system, comprising: a communications unit accessible by a user, the communications unit having a user interface, a storage medium, and a communication element; and an unmanned aircraft comprising: a non-transitory computer readable medium configured to store infor...
# 199799  we claim:1. an object detection system, comprising: a communications unit accessible by a user, the communications unit having a user interface, a storage medium, and a communication element; and an unmanned aircraft comprising: a non-transitory computer-readable medium configured to store infor...
# 201532  1. a grip for installation on a shaft, the grip comprising: a main body comprising a shaft cavity extending from an open first end to a second end, wherein the shaft cavity is configured to receive the shaft therein; an end cap attached to the second end of the main body, wherein the end cap com...
# 201715  1. a watch comprising: an analog watch face; a first watch band portion having a first end and a second end, wherein the first end of the first watch band portion is coupled with the analog watch face; a second watch band portion having a first end and a second end, when the first end of the sec...
# 206173  1. an apparatus for measuring or analysing a golf swing; the apparatus includes a processing means and a detection means; the detection means is operable to detect ground-reaction forces, and includes a standing surface and sensor means;  characterised in that  a) the apparatus includes an artif...
# 207444  what is claimed is:1. a vaporizer device comprising:a body having a first end, a second end, and a power source between the first end and the second end;a first cartridge receptacle at the first end of the body and configured to receive a first cartridge, the first cartridge being configured to ...
# 207937  1. a method of cattle reproduction management for an open heifer or cow comprising: receiving information transmitted by a tag disposed on the open heifer or cow; determining if the open heifer or cow is in heat based at least in part on the information received; providing an alert if the open h...
# 208832  1. an electronic apparatus utilisable by a user to perform computer-aided rehabilitation exercises based on video games, comprising: a data processing module; a memory module operatively connected to the data processing module and configured to memorise the video games; a display module of the v...
# 209104  1. a grounds maintenance system comprising: a robot tractor comprising; a robot body; a drive system including one or more motorized drive wheels to propel the robot body; a control system coupled to the drive system, the control system configurable to store a mow plan that specifies a set of pa...
# 209967  1. a watch comprising: an analog watch face; a first watch band portion having a first end and a second end, wherein the first end of the first watch band portion is coupled with the analog watch face; a second watch band portion having a first end and a second end, when the first end of the sec...
# 209972  1. a mobile robot comprising: a travel drive unit configured to move a main body; an image acquisition unit configured to acquire a plurality of images by continuously photographing surroundings of the main body; a storage configured to store the plurality of continuous images acquired by the im...
# 210758  1. a transgenic chicken, wherein the transgenic chicken comprises a genome comprising a modified endogenous immunoglobulin heavy chain (igh) locus that: (a) lacks the entire contiguous endogenous chicken v-d-j region; and (b) comprises, in operable linkage: (i) an immunoglobulin heavy chain gene...
# 214088  1. a slide rail mechanism, comprising: a slide rail having a front portion and a rear portion; a resilient member located between the front portion and the rear portion of the slide rail, wherein the resilient member includes a first portion and a second portion, and the first portion is fixed w...
# 215703  1. a work vehicle comprising: a vehicle body mounting an engine; a traveling mechanism including a transmission and driven by a rotational power from the engine; an implement for effecting a ground work in association with traveling of the vehicle body; a load ratio calculation section for calcu...
# 216900  what is claimed is:1. a vaporizer device comprising:a heating element configured to heat a vaporizable material to form a vapor; an outlet configured to deliver the vapor to a user for inhalation;one or more sensors configured to detect one or more air quality parameter levels of the vapor, wher...

# %% [markdown]
# ##### skin (da provare combinazioni)

# %%
keyword = keywords_cosmetics[3]
keyword
# Out:
# 'skin'

# %%
df_candidate = df[(df[keyword] > 0)
                  & (df.ipc_classes.str.count("G06")==0) #Escludo "COMPUTING; CALCULATING; COUNTING"
                  & (df.ipc_classes.str.count("G01")==0) #Escludo "MEASURING; TESTING"
                  & (df.ipc_classes.str.count("A61")==0) #MEDICAL OR VETERINARY SCIENCE; HYGIENE
                  & (df.ipc_classes.str.count("G09")==0) #EDUCATION; CRYPTOGRAPHY; DISPLAY; ADVERTISING; SEALS
                  & (df.ipc_classes.str.count("(^| )A")>0)
                 ].query("title not in @df_selected")

df_candidate[["title", "ipc_classes","abstract", "claims"]]
# Out:
#                                                                                                             title  \
# 538                                                              ligands for odor receptors and olfactory neurons
# 2533                                                   rowing exercise machines having a configurable rowing feel
# 4603                                                                    creating music by concatenative synthesis
# 11876                                                                                personally powered appliance
# 12941                                                                   devices for prevention of pressure ulcers
# 15513                                                               computer-implemented question and answer game
# 17315                                                                                       shoes for ball sports
# 19787   automated artificial intelligence (ai) control mode for playing specific tasks during gaming applications
# 26692                                                                                 in vitro avian food product
# 41788                                                                            personal care device with camera
# 68175                                                                                       inspection of poultry
# 73630                                                            harvester with intelligent hybrid control system
# 79616                                                                                       shoes for ball sports
# 80403                                                                   creating music by concatenative synthesis
# 98335                               methods and systems for microbiome characterization, monitoring and treatment
# 98584                                                                   devices for prevention of pressure ulcers
# 109847                                                              method and apparatus for breeding virtual pet
# 117905  automated artificial intelligence (ai) control mode for playing specific tasks during gaming applications
# 119076                                      methods and systems for food preparation in a robotic cooking kitchen
# 125538                                                           harvester with intelligent hybrid control system
# 130026                                                                                 plush toy audio controller
# 135371                                              contextual and presence sensing to operate electronic devices
# 135419                     smoking cessation devices, methods of use and methods of conducting business therewith
# 137526                                                                  methods for controlling leaf-cutting ants
# 145112               system, apparatus and method of item location, list creation, routing, imaging and detection
# 154214                                                dynamic technique for fitting pressure-suits to individuals
# 155987                              method and apparatus for displaying virtual pet, terminal, and storage medium
# 161690                                      integrated distributed classification, prediction and response system
# 182396                                                              method and system for a similarity-based game
# 188527                                                 rowing exercise machines having a configurable rowing feel
# 209191                                                                 apparatus and methods for multimedia games
# 213064                                                                                      shoes for ball sports
# 213343                                                                  methods for controlling leaf-cutting ants
#
#                                                               ipc_classes  \
# 538                                        A01M1/10, A01N33/00, A23L27/10
# 2533    A63B21/00, A63B21/005, A63B21/22, A63B22/00, A63B24/00, A63B71/06
# 4603                              A63H5/00, G04B13/00, G10H7/00, H03G5/00
# 11876                 A43B3/00, G08B21/02, H01L41/113, H04B1/38, H04Q9/00
# 12941                                                A47C27/00, A47C27/08
# 15513                                                            A63F9/24
# 17315                                                  A43B3/00, A43B5/02
# 19787                       A63F13/422, A63F13/45, A63F13/5375, A63F13/67
# 26692                                                A23L33/00, C12N5/077
# 41788      A46B13/00, A46B15/00, A46B5/00, A46B9/02, H04N5/225, H04N5/232
# 68175                                                            A22B5/00
# 73630                                                          A01D41/127
# 79616                                                  A43B3/00, A43B5/02
# 80403                             A63H5/00, G04B13/00, G10H7/00, H03G5/00
# 98335                            A01N63/00, C12N1/20, C12Q1/68, C40B40/12
# 98584                                                A47C27/00, A47C27/08
# 109847                                              A63F13/58, A63F13/825
# 117905                      A63F13/422, A63F13/45, A63F13/5375, A63F13/67
# 119076                                               A47J27/62, G05B19/42
# 125538                                                         A01D41/127
# 130026                          A63H3/28, G10L13/07, G10L15/18, G10L17/24
# 135371                                     A63F13/20, F24F11/00, G05B1/01
# 135419                                                          A24F47/00
# 137526                                               A01N25/00, A01N63/04
# 145112                                                 A47F9/04, G07G1/00
# 154214                                     A62B17/00, B64D10/00, B64G6/00
# 155987                                             A63F13/537, A63F13/825
# 161690                                                          A24F47/00
# 182396                                                          A63F13/00
# 188527  A63B21/00, A63B21/005, A63B21/22, A63B22/00, A63B24/00, A63B71/06
# 209191                         A63F13/60, A63F13/71, A63F13/79, A63F13/95
# 213064                                                 A43B3/00, A43B5/02
# 213343                                               A01N25/00, A01N63/04
#
#                                                                                                                                                                                                                                                                                                            abstract  \
# 538                                                                               the disclosure provides compounds useful as insect repellents and compositions comprising such repellents. the disclosure further provides insect traps and method for identifying ligands and cognates for biological molecules.
# 2533    among other things, a rowing exercise machine includes a movable inertial element, an eddy current brake coupled to the movable inertial element, a rowing grip coupled to the movable inertial element, and control circuitry coupled to the eddy current brake to cause a resistance to motion of the ...
# 4603    automated creation of new music by listening is disclosed. a method to create new music may comprise listening to a plurality of music, learning from the plurality of music, and performing concatenative synthesis based on the listening and the learning to create the new music. the method may be ...
# 11876   systems and methods are disclosed for powering a processor and a wireless transceiver in a sole having a sole plate and one or more spring elements disposed in a forefoot area of the sole plate, each of said spring elements including a piezoelectric generator coupled thereto, wherein each of the...
# 12941   a support surface, such as an underpad, for preventing pressure sores in a patient is a multi-layer textile assembly having a skin contact layer formed from a fabric of synthetic filament yarns woven to provide air permeability and moisture vapor permeability and having a thickness of less than ...
# 15513   a computer-implemented question and answer game based on using opinion polls that have already been carried out on a representative sample of people. results of the opinion polls and predefined questions are stored in a knowledge base associated with the system, which is typically implemented on...
# 17315   described are shoes for ball sports including an upper (101) having an outer surface. an actuator (104,81) is configured to change at least one surface property of a portion of the outer surface of the upper (101), and a sensor is configured to be sensitive to movements of the shoe. a processing...
# 19787   a method for gaming. the method includes assigning a default game play profile to a user, wherein the default game play profile includes a default game play style that simulates human game play, and wherein the default game play profile is configured to control game play for the user based on th...
# 26692                                                      provided herein are food products made in vitro from avian fibroblast cells and methods for harvesting the avian fibroblast cells. particularly, an in vitro produced chicken product is produced. also provided herein are methods of their production.
# 41788   a personal care system having a treatment device for applying a treatment to the skin or hair of a user is provided. the treatment device has a camera for taking an image of the skin. the system may include or be in communication with an application programming interface (api) that can process t...
# 68175   the invention relates to a system and method for inspection of slaughtered poultry carcasses on a processing line. in particular,the invention relates to a system and method for inspection of slaughtered poultry where abnormalities close to the gump and groin area of the poultry can be detected ...
# 73630   a control system for a harvester or similar implement includes a supervisory controller, a set of low-level controllers and a neuro-fuzzy inference system. the supervisory controller employs human expert knowledge and fuzzy logic. the controller monitors the quality of the harvesting process, su...
# 79616   described are shoes for ball sports including an upper (101) having an outer surface. an actuator (104,81) is configured to change at least one surface property of a portion of the outer surface of the upper (101), and a sensor is configured to be sensitive to movements of the shoe. a processing...
# 80403   automated creation of new music by listening is disclosed. a method to create new music may comprise listening to a plurality of music, learning from the plurality of music, and performing concatenative synthesis based on the listening and the learning to create the new music. the method may be ...
# 98335   the present disclosure provides methods for profiling a microbiome and therapeutic compositions for treatment. additionally, the methods, systems, compositions and kits provided herein are directed to assessing or predicting health status in a subject. some of the embodiments include generating ...
# 98584   a support surface, such as an underpad, for preventing pressure sores in a patient is a multi-layer textile assembly having a skin contact layer formed from a fabric of synthetic filament yarns woven to provide air permeability and moisture vapor permeability and having a thickness of less than ...
# 109847  a method for breeding a virtual pet is provided, including: displaying a mating market interface, the mating market interface including virtual pets in a mating state; selecting a paternal virtual pet from the virtual pets in the mating state via the mating market interface according to a first ...
# 117905  a method for gaming. the method includes assigning a default game play profile to a user, wherein the default game play profile includes a default game play style that simulates human game play, and wherein the default game play profile is configured to control game play for the user based on th...
# 119076  the present disclosure is directed to methods, computer program products, and computer systems for instructing a robot to prepare a food dish by replacing the human chef's movements and actions. monitoring a human chef is carried out in an instrumented application-specific setting, a standardize...
# 125538  a control system for a harvester or similar implement includes a supervisory controller, a set of low-level controllers and a neuro-fuzzy inference system. the supervisory controller employs human expert knowledge and fuzzy logic. the controller monitors the quality of the harvesting process, su...
# 130026  a master device uses a slave device to connect to the internet to provide intelligent and dynamic responses. the master device receives input from a user. the master device processes the input and generates a command that is to be transmitted to the slave device via a sound wave. the sound wave ...
# 135371  a monitoring system comprises a module having at least one sensor which could be an electric-field sensor within a housing. the device may be durable or disposable. a receiver may be provided to obtain and display data from the module. the module may also display the output data. the output data...
# 135419  the present invention provides several smoking and tobacco use cessation devices and methods which entirely eliminate the requirement of ignition and burning of substances which emit harmful substances and vapors while simultaneously providing therapeutically efficacious amounts of nicotine and/...
# 137526  kits for biological control of leaf-cutting ants are disclosed. the kits comprise at least two granulated bait formulations, each formulation containing a) a biologic control agent for the ants, and b) one masking substance for the control agent and/or one attractant, wherein the control agent i...
# 145112  a system for enabling in store routing of a user generated shopping list using existing store cameras and artificial intelligence and machine learning is provided. the system uses a pixelbuffer comparison of items imaged in real time to compared to a database of machine learned images. the syste...
# 154214  a method utilizing continual sensor-based data to design and adjust pressure-suits to fit an individual. the invention capabilities include cognizance of the dynamic workings of the body in a changing real environment. for example, the stresses and accelerations experienced by the body during no...
# 155987  a method for displaying a virtual pet is provided. the method includes: determining a target virtual pet to-be-displayed in an application program; obtaining first information of the target virtual pet from a server, the first information being stored on a blockchain system and corresponding to ...
# 161690  a computer-implemented method of determining the efficacy of a substance that is vaporized and inhaled by a user includes receiving a cartridge within a housing of a vapor inhalation device. the cartridge stores a substance therein. the housing has an opening at a first end thereof. a characteri...
# 182396  in one embodiment, the invention is a method and system for a biometric similarity based game. in one embodiment, photographs of the game players are compared to a celebrity's photograph and the player whose photograph is most similar to that of the celebrity is deemed to be the winner. in anoth...
# 188527  among other things, a rowing exercise machine includes a movable inertial element, an eddy current brake coupled to the movable inertial element, a rowing grip coupled to the movable inertial element, and control circuitry coupled to the eddy current brake to cause a resistance to motion of the ...
# 209191                                                                           systems and methods for time-segmented multimedia game playing and authoring to create promotional videos and games, for creating games that provide brand advertising, and for gathering player data and analytics are described.
# 213064  described are shoes for ball sports including an upper having an outer surface. an actuator is configured to change at least one surface property of a portion of the outer surface of the upper, and a sensor is configured to be sensitive to movements of the shoe. a processing unit is connected to...
# 213343  kits for biological control of leaf-cutting ants are disclosed. the kits comprise at least two granulated bait formulations, each formulation containing a) a biologic control agent for the ants, and b) one masking substance for the control agent and/or one attractant, wherein the control agent i...
#
#                                                                                                                                                                                                                                                                                                              claims
# 538     1-41. (canceled)42. a composition, comprising one or more compounds selected from table 9, table 10, and any combination thereof, in a trap, a cream, a lotion, a spray, a dust, a vapor emitter, a candle, an oil, a wicked apparatus, a fan, a vaporizer, a perfume, a cologne, a fragrance, a deodora...
# 2533    1. a rowing exercise machine comprising a movable inertial element, an eddy current brake coupled to the movable inertial element, a rowing grip coupled to the movable inertial element, and control circuitry coupled to the eddy current brake to cause a resistance to motion of the rowing grip dur...
# 4603    it is claimed:1. a method to create new music comprising: listening to a plurality of music learning from the plurality of music performing concatenative synthesis based on the listening and the learning to create the new music.2. the method of claim 1 wherein the music comprises at least one of...
# 11876   1. an apparatus, comprising: a processor; a wireless transceiver coupled to the processor; a power supply coupled to the processor and wireless transceiver located proximal to a sole, said sole including: a sole plate; and one or more leaf spring elements extending at an angle from the sole plat...
# 12941   1. a support surface for preventing pressure ulcers in a patient, the support surface comprising a multi-layer composite fabric comprising: a skin contact layer comprising a woven fabric of synthetic filament yarns woven to provide air permeability and moisture vapor permeability and having a th...
# 15513   1. a method of allocating a prize to at least one individual using a computer system having at least one host computer terminal for presenting and collecting -data, a question engine for sending a battery of successive predefined questions to the individual, and a knowledge base storing a predet...
# 17315   1. a shoe for ball sports, comprising: an upper having an outer surface; an actuator configured to change at least one surface property of a portion of the outer surface of the upper; a sensor configured to be sensitive to movements of the shoe; and a processing unit connected to the actuator an...
# 19787   1. a method for gaming, comprising: assigning a default game play profile to a user, wherein the default game play profile comprises a default game play style that simulates human game play, wherein the default game play profile is configured to control game play for the user based on the defaul...
# 26692   1. a method of producing an avian fibroblast cell food product in-vitro, the method comprising the steps of:a. culturing a population of avian fibroblast cells in vitro in a growth medium capable of maintaining the avian fibroblast cells;b. recovering the avian fibroblast cells; andc. formulatin...
# 41788   1. a personal care device comprising: a handle portion; a head portion disposed at an end of the handle portion, the head portion including a platform; a treatment head extending away from the platform along a first direction of a longitudinal axis of the head portion; and a lens module position...
# 68175   1. a system for inspection of slaughtered poultry carcasses on a processing line, comprising :i) means for conveying (1) the poultry (2)ii) one or more image recording device(s) (3) configured for recording at least one digital image of the poultry (2) in the form of image data, where- the one o...
# 73630   1. a control system for controlling an agricultural harvesting implement operable in varying operating conditions and having a plurality of adjustable output devices including two or more of the following output devices affecting harvesting implement cleaning and separation operations: a rotor w...
# 79616   1. a shoe (100) for ball sports, comprising: an upper (101) having an outer surface (102); an actuator (104) configured to change at least one surface property of a portion of the outer surface (102) of the upper (101); a sensor (105) configured to be sensitive to movements of the shoe (100), wh...
# 80403   1. a method performed by a computing device to create new music, the method comprising: the computing device listening to a plurality of music including receiving through an audio interface live or recorded music or reading a music file from a storage medium, the listening including creating an ...
# 98335   what is claimed is:1. a method of classifying a microbe, comprising:obtaining a nucleic acid sequence of a 16s or 23s ribosomal subunit contained within a single read length of a first microbe; andcomparing said nucleic acid sequence of a first microbe to a reference; andidentifying the first mi...
# 98584   1. a support surface for preventing pressure ulcers in a patient, the support surface comprising a multi-layer composite fabric comprising: a skin contact layer comprising a woven fabric of synthetic filament yarns woven to provide air permeability and moisture vapor permeability and having a th...
# 109847  1. a method for breeding a virtual pet, performed by a terminal, the terminal being provided with virtual pets, and at least one pet image of each of the virtual pets being generated based on a genetic rule, the method comprising: displaying a mating market interface, the mating market interface...
# 117905  1. a method for gaming, comprising: assigning a default game play profile to a user, wherein the default game play profile comprises a default game play style that simulates human game play, wherein the default game play profile is generated based on a first plurality of game plays of a pluralit...
# 119076  what is claimed and desired to be secured by letters patent of the united states is:1. a computer-implemented method operating on robotic apparatus, comprising:an electronic description of one or more food dishes, including the recipes for making each food dish from ingredients by a chef;for eac...
# 125538  we claim:1. a control system for controlling an agricultural implement operable in varying operating conditions and having a plurality of adjustable output devices affecting implement operation, the control system comprising: a plurality of actuators connected to the output devices; feedback dev...
# 130026  1. a computer system comprising: one or more processors; and one or more computer-readable hardware storage devices having stored thereon computer-executable instructions that are executable by the one or more processors to cause the computer system to: detect user input comprising a command tha...
# 135371  1. 1-3. (canceled)4. a system for controlling the operation of an electronic device comprising: a. an electronic device; b. a first sensor adapted to generate data indicative of the electric field proximate to said electronic device; c. a wearable sensor device comprising a second adapted to gen...
# 135419  1. an orally deployable tobacco smoking cessation means adapted for use in a fitting relationship with a tobacco smoking device, and comprising a substance effective to act upon and/or activate nicotine receptors in a user thereof.2. the deployable means of claim 1 wherein said substance is pres...
# 137526  1. 1-42. (canceled)43. a method for controlling leaf-cutting ants characterized in that it comprises serially supplying at least two, preferably three bait formulations, each formulation comprising a controlling agent for the ants which is the same in all formulations, and one attractant and/or ...
# 145112  1. a kiosk for checking out at a store, the kiosk comprising:a main body having a first camera and a second camera both mounted thereto, the first camera and a second camera both in communication with a processor;the first camera configured to detect and authenticate a user; and the second camer...
# 154214  1. a computer method comprising the steps of: i) mounting pressure and acceleration sensors in a body-enclosing device; ii) transmitting data produced by said sensors during actual operation of said body-enclosing device worn by a specific individual for subsequent analysis by a computer; and ii...
# 155987  1. a method performed in a platform for maintaining a type of virtual pets, comprising: generating a plurality of initial gene sequences associated with the type of virtual pets; generating a plurality of zeroth generation virtual pets corresponding to the plurality of initial gene sequences; ge...
# 161690  what is claimed is:1. an iterative feedback system, comprising:a receptacle configured to receive therein a quantity of a tangible substance in liquid or solid form, the tangible substance having a set of substance characteristics; a vaporizing element configured to convert at least a portion of...
# 182396  1. a method for a game for a plurality of players, the method comprising the steps of:  (a) selecting a referent from a predetermined set of referents;  (b) determining correspondences between each of the players and the referent;  (c) assigning scores to each player based, at least in part, upo...
# 188527  1. two or more rowing exercise machines, each of the rowing exercise machines comprising a movable inertial element, an eddy current brake coupled to the movable inertial element, a rowing grip coupled to the movable inertial element, and control circuitry coupled to the eddy current brake and c...
# 209191  1. a device for generating a multimedia game comprising: a receiver configured to receive an identifier for multimedia content for the multimedia game; a segment selector configured to: determine a content source of the multimedia content based on the identifier, retrieve the multimedia content ...
# 213064  that which is claimed is:1. a shoe for ball sports, comprising: an upper having an outer surface; an actuator configured to change at least one surface property of a portion of the outer surface of the upper; a sensor configured to be sensitive to movements of the shoe; and a processing unit con...
# 213343  1. a kit for the biological control of leaf-cutting ants, comprising at least two granulated bait formulations, each bait formulation comprising: a) a biological control agent for the ants, and b) a substance or substances selected from one masking substance for the biological control agent, one...

# %%
df_selected = pd.concat([df_selected, df[df.title == "personal care device with camera"]])
len(df_selected)
# Out:
# 45

# %% [markdown]
# ##### skin (da provare combinazioni)

# %%
keyword = keywords_cosmetics[4]
keyword
# Out:
# 'nail'

# %%
df_candidate = df[(df[keyword] > 0)
                  & (df.ipc_classes.str.count("G06")==0) #Escludo "COMPUTING; CALCULATING; COUNTING"
                  & (df.ipc_classes.str.count("G01")==0) #Escludo "MEASURING; TESTING"
                  & (df.ipc_classes.str.count("A61")==0) #MEDICAL OR VETERINARY SCIENCE; HYGIENE
                  & (df.ipc_classes.str.count("G16")==0)#NFORMATION AND COMMUNICATION TECHNOLOGY [ICT] SPECIALLY ADAPTED FOR SPECIFIC APPLICATION FIELDS
                  & (df.ipc_classes.str.count("G08")==0)#SIGNALLING
                  & (df.ipc_classes.str.count("G09")==0)#EDUCATION; CRYPTOGRAPHY; DISPLAY; ADVERTISING; SEALS
                  & (df.ipc_classes.str.count("H04")==0)#LECTRIC COMMUNICATION TECHNIQUE
                 ].query("title not in @df_selected")

df_candidate[["title", "ipc_classes","abstract", "claims"]]
# Out:
#                                                                                                                                       title  \
# 10744                                                        improved microlayer membranes, mproved battery separators, and related methods
# 14944                                   power center assembly having electrical connection-protection and optional detachable surface mount
# 20938                                                                                   automatic nail polish application system and method
# 22515                                                                          system and methods for patient data and treatment management
# 27088                                                                                            interchangeable footwear system and method
# 40165                                                       improved microlayer membranes, improved battery separators, and related methods
# 68480                                                       improved microlayer membranes, improved battery separators, and related methods
# 69896                                                               method for simulating the rendering of a make-up product on a body area
# 83721                                   power center assembly having electrical connection-protection and optional detachable surface mount
# 87900                                                                                         identification of cell differentiation states
# 100331                                                       improved microlayer membranes, mproved battery separators, and related methods
# 118272                                                          identification of cell differentiation states based on methylation patterns
# 131466                                                                                    unmanned aerial vehicle rooftop inspection system
# 133251                                                                                    profiled rail with plug for fastening to formwork
# 158644                                                              method for simulating the rendering of a make-up product on a body area
# 166541                                                                                           interchangeable footwear system and method
# 194093  multi-sensor suite and interactive software platform for real-time visualization and analysis of distributed environment conditions
# 194742                                                                              therapy selection for psoriasis and psoriatic arthritis
# 195521                                                                                           interchangeable footwear system and method
#
#                                                                       ipc_classes  \
# 10744   B29C48/00, B29C48/08, B29C48/21, B32B27/08, B32B27/32, H01M2/14, H01M2/16
# 14944                       H01R13/516, H01R13/66, H01R13/70, H01R25/00, H02G3/18
# 20938                       A45D29/00, A45D29/11, A45D29/12, A45D29/14, A45D34/04
# 22515
# 27088                                                         A43B21/36, A43B3/24
# 40165              B29C47/06, B32B27/00, H01M10/052, H01M2/14, H01M2/16, H01M2/18
# 68480              B29C47/06, B32B27/00, H01M10/052, H01M2/14, H01M2/16, H01M2/18
# 69896                                                                   A45D44/00
# 83721                       H01R13/516, H01R13/66, H01R13/70, H01R25/00, H02G3/18
# 87900                                                                    C12Q1/68
# 100331                                                      H01M10/0525, H01M2/16
# 118272                                                                   C12Q1/68
# 131466                                    B64C39/02, G05D1/00, G05D1/04, G05D1/10
# 133251                                  E04B1/41, E04G15/04, E04G17/00, E04G21/18
# 158644                                                                  A45D44/00
# 166541                                                        A43B21/36, A43B3/24
# 194093                                                                  G05B23/02
# 194742                                                                   C12Q1/68
# 195521                                                                  A43B21/36
#
#                                                                                                                                                                                                                                                                                                            abstract  \
# 10744   described herein is a multilayer microporous film or membrane that may exhibit improved properties, including improved dielectric break down and strength, compared to prior monolayer or tri-layer microporous membranes of the same thickness. the preferred multilayer microporous membrane comprises...
# 14944   a power center assembly having a hooded member for protecting an electrical connection between a peripheral device plug and its respective outlet and a mount member for detachably mounting the power center to a surface. in particular, a power center assembly is provided having a member for prote...
# 20938   the present disclosure relates to a robotic apparatus and methods for automatic nail polish application on natural or artificial finger or toe nails. the robot uses artificial intelligence (al) to identify and paints the nails. the robot uses depth sensors and computer vision to plan the movemen...
# 22515   described are systems and methods for the analysis of information, particularly information obtained from the mass spectroscopic (proteomic) analysis of biological samples and associated patient and clinical information. the systems and methods of the invention may be used for a variety of purpo...
# 27088   a footwear system (s) and corresponding methods (m1) and (m2) for providing a plethora of footwear fashion options via a plurality of interchangeable components, the interchangeability of which being facilitated by structurally stable quick-coupling and quick-decoupling techniques. the system (s...
# 40165   described herein is a multilayer microporous film or membrane that may exhibit improved properties, including improved dielectric break down and strength, compared to prior monolayer or tri-layer microporous membranes of the same thickness. the preferred multilayer microporous membrane comprises...
# 68480   described herein is a multilayer microporous film or membrane that may exhibit improved properties, including improved dielectric break down and strength, compared to prior monolayer or tri-layer microporous membranes of the same thickness. the preferred multilayer microporous membrane comprises...
# 69896   the invention proposes a method for simulating a rendering of a makeup product on a body area is disclosed comprising: - acquiring an image of the body area without makeup of a subject, - determining first color parameters of the pixels of the image corresponding to the body area without makeup,...
# 83721   a power center assembly having a hooded member for protecting an electrical connection between a peripheral device plug and its respective outlet and a mount member for detachably mounting the power center to a surface. in particular, a power center assembly is provided having a member for prote...
# 87900   the present invention provides a novel method for the systematic identification of differentially methylated cpg dinucleotides positions within genomic dna sequences for use as reliable markers to detect and characterize different stages of development or differentiation of cells corresponding t...
# 100331  described herein is a multilayer microporous film or membrane that may exhibit improved properties, including improved dielectric break down and strength, compared to prior monolayer or tri-layer microporous membranes of the same thickness. the preferred multilayer microporous membrane comprises...
# 118272  the present invention provides a novel method for the systematic identification of differentially methylated cpg dinucleotides positions within genomic dna sequences for use as reliable markers to detect and characterize different stages of development or differentiation of cells corresponding t...
# 131466  methods, systems, and apparatus, including computer programs encoded on computer storage media, for an unmanned aerial system inspection system. one of the methods is performed by a uav and includes receiving, by the uav, flight information describing a job to perform an inspection of a rooftop....
# 133251  the present invention relates to a profiled rail (2) for fastening to a formwork (5) for at least partially embedding in concrete. the profiled rail (2) is formed in a substantially c-shaped manner along a profiled rail longitudinal axis, wherein a plurality of holes (24) are formed in the rail ...
# 158644  the inventionproposes a method for simulating a rendering of a makeup product on a body area is disclosed comprising:∘ acquiring an image of the body area without makeup of a subject,∘ determining first color parameters of the pixels of the image corresponding to the body area without makeup,∘ i...
# 166541  a footwear system (s) and corresponding methods (m1) and (m2) for providing a plethora of footwear fashion options via a plurality of interchangeable components, the interchangeability of which being facilitated by structurally stable quick-coupling and quick-decoupling techniques. the system (s...
# 194093  an industrial iot system is provided that has adaptable, re-configurable, connected and integrated suite of smart, synchronized sensors and video/thermal cameras for continuous monitoring, access and control from anywhere in an industrial environment. a path sensor comprises a multi-sensor devic...
# 194742  the present invention provides methods for selecting an individual with psoriasis (ps) or psoriatic arthritis (psa) who should receive or who is likely to respond to a treatment with an anti-tumor necrosis factor alpha (anti-tnfα) therapy. in addition, provided herein are methods for selecting a...
# 195521  a footwear system (s) and corresponding methods (m1) and (m2) for providing a plethora of footwear fashion options via a plurality of interchangeable components, the interchangeability of which being facilitated by structurally stable quick-coupling and quick- decoupling techniques. the system (...
#
#                                                                                                                                                                                                                                                                                                              claims
# 10744   1. a battery separator for a lithium battery comprising: at least one microporous separator membrane or sub-membrane comprising a plurality of porous or microporous polymer microlayers or nanolayers, wherein at least one of the individual microlayers or nanolayers comprises a different or distin...
# 14944   1. a power center assembly, comprising: a power strip,  said power strip having a housing member and at least one outlet for powering at least one peripheral device,  said housing member having a bottom surface; and  mechanical means for preventing inadvertent mechanical and electrical disconnec...
# 20938   1. a system for automatically polishing a nail of a user including:an end-effector havinga cartridge receiving unit,a cartridge including nail polish, anda nozzle;a sensor, to generate target signals from a target location;a nail determination unit, receiving said target signals, to automaticall...
# 22515   what is-1cealmeo fs:11. a system, comprising: a system input to receive a quantity of proteomic data obtained from mass spectrometric analysis of a biological sample; a metadata repository to store a quantity of metadata that includes the quantity of proteomic data; a rules database to store at ...
# 27088   1. an interchangeable footwear system, comprising: a plurality of interchangeable uppers; a plurality of interchangeable heels; and a quick-release device comprising a rigid slide reversibly fastenable to the plurality of interchangeable uppers and reversibly fastenable to the plurality of inter...
# 40165   claims . a battery separator for a lithium battery comprising:at least one microporous separator membrane or sub-membrane comprising a plurality of porous or microporous polymer microlayers or nanolayers, wherein at least one of the individual microlayers or nanolayers comprises a different or d...
# 68480   8/089885 amended claims pct/us2017/061277 received by the international bureau on 30 july 2018 (30.07.2018)1 . a battery separator for a lithium battery comprising:at least one microporous separator membrane or sub-membrane comprising a plurality of porous or microporous polymer microlayers or n...
# 69896   1. a method (200) for simulating a rendering of a makeup product on a body area, the method being performed by a processor (1 1 ), and comprising :o acquiring (210) an image of the body area without makeup of a subject, o determining (230) first color parameters of the pixels of the image corres...
# 83721   1. a power center assembly, comprising: a. a power strip, said power strip having a housing member and at least one outlet for powering at least one peripheral device, said housing member having a bottom surface; and b. mechanical means for preventing inadvertent mechanical and electrical discon...
# 87900   1. a method for detecting and characterizing different developmental stages or differentiation of cells, comprising:  a) obtaining a set of at least two biological samples in each case having genomic dna, wherein the biological samples correspond to at least two sample classes that are distingui...
# 100331  1. a battery separator for a lithium battery comprising: at least one microporous separator membrane or sub-membrane comprising a plurality of porous or microporous polymer microlayers or nanolayers, wherein at least one of the individual microlayers or nanolayers comprises a different or distin...
# 118272  claims we claim1. a method for detecting and characterizing different developmental stages or differentiation of cells, comprising: a) obtaining a set of at least two biological samples in each case having genomic dna, wherein the biological samples correspond to at least two sample classes that...
# 131466  1. a computerized method performed by an unmanned aerial vehicle (uav) system comprising one or more processors, the method comprising: in initial steps: receiving, by an unmanned aerial vehicle (uav), flight information describing a job to perform an inspection of a rooftop, the flight informat...
# 133251  1. a profiled rail for fastening to formwork for at least partially embedding in concrete, wherein a) the profiled rail is formed in a substantially c-shaped manner along a profiled rail longitudinal axis by having a rail back with two opposing flanks which protrude at an angle laterally therefr...
# 158644  1. a method (200) for simulating a rendering of a makeup product on a body area, the method being performed by a processor (11), and comprising : ∘ acquiring (210) an image of the body area without makeup of a subject, ∘ determining (230) first color parameters of the pixels of the image corresp...
# 166541  1. an interchangeable footwear system, comprising: a plurality of interchangeable uppers; a plurality of interchangeable heels; and a quick-release device for selectively engaging a heel of the plurality of interchangeable heels with an upper of the plurality of interchangeable uppers.2. a syste...
# 194093  1. a path sensor for detecting conditions of a designated moving portion of a conveyor, the conveyor portion being energized via brushes that contact a power rail, the path sensor comprising: a controller; and a sensor connected to the controller and configured to detect a condition of the brush...
# 194742  what is claimed is: 1. a method for selecting an individual with psoriasis (ps) to receive an anti-tumor necrosis factor a (anti-tnfa) therapy, the method comprising:(a) detecting the presence of a single nucleotide polymorphism (snp) in a pde3a-slc01c1 locus in a sample obtained from the indivi...
# 195521  what is claimed:1. an interchangeable footwear system, comprising: a plurality of interchangeable uppers; a plurality of interchangeable heels; and a quick-release device for selectively engaging a heel of the plurality of interchangeable heels with an upper of the plurality of interchangeable u...

# %%
df_selected = pd.concat([df_selected, df[df.title == "automatic nail polish application system and method"]]) 
len(df_selected)
# Out:
# 46

# %% [markdown]
# ##### fingernail

# %%
keyword = keywords_cosmetics[5]
keyword
# Out:
# 'fingernail'

# %%
df_candidate = df[(df[keyword] > 0)
                 ].query("title not in @df_selected")


df_candidate[["title", "ipc_classes","abstract", "claims"]] #Contiene solo metodi relativi al miglioramento dei dispositivi touch
# Out:
#                                                                                                                                                                                                                                                                title  \
# 10595                                                                                                                                                           method for improving accuracy of touch screen event analysis by use of spatiotemporal touch patterns
# 23540                                                                                                                                                           method for improving accuracy of touch screen event analysis by use of spatiotemporal touch patterns
# 25707                                                                                                                                                                          image processing using a convolutional neural network to track a plurality of objects
# 35612                                                                                                                                                                                                      system and method for detecting imperfections in a screen
# 45418                                                                                                                                                                          image processing using a convolutional neural network to track a plurality of objects
# 52891                                                                                                                                                                                                  systems and methods for interactive virtual makeup experience
# 53008                                                                                                                                                                                    augmented reality systems and methods for fingernail detection and tracking
# 53755                                                                                                                                                                                                        phenotypic integrated social search database and method
# 54334                                                                                                                                                                                 method and apparatus for classifying touch events on a touch sensitive surface
# 54376                                                                                                                                            online food and beverage search method based on food to biomarker optimization algorithms in a node ranked database
# 54943                                                                                                                                                                                                       systems and methods for quantitative diagnosis of anemia
# 55636                                                                                                                                                                                                                                  wearable multiplatform sensor
# 64429                                                                                                                                                                                 method and apparatus for classifying touch events on a touch sensitive surface
# 65794                                                                                                                                                                                                      system and method for detecting imperfections in a screen
# 68436                                                                                                                                                                                 method and apparatus for classifying touch events on a touch sensitive surface
# 82634                                                                                                                                                           systems, apparatuses and methods for controlling prosthetic devices by gestures and other modalities
# 89726                                                                                                                                                           method for improving accuracy of touch screen event analysis by use of spatiotemporal touch patterns
# 94533                                                                                                                                                                                                        phenotypic integrated social search database and method
# 99356                                                                                                                                                                                 method and apparatus for classifying touch events on a touch sensitive surface
# 101646                                                                                                                                                                        methods and systems for predicting and/or tracking changes in external body conditions
# 104229                                                                                                                                                              sensor network for measuring physiological parameters of mammal subject and applications of same
# 108442                                                                                                                        methods and apparatus for security enhanced portable data store and processor for allowing secure and selective access to genomic data
# 121546                                                                                                                                                                                 method and system for optimized foods using biomarker data and fitting models
# 124083                                                                                                                                                                                                     system and method for detecting imperfections in a screen
# 126104                                                                                                                                                                                                      systems and methods for quantitative diagnosis of anemia
# 127757                                                                                                                                                                                                                                                  smart mirror
# 130069                                                                                                                                                     method and system for activating different interactive functions using different types of finger contacts
# 141389                                                                                                                                                                                method and apparatus for classifying touch events on a touch sensitive surface
# 149597  methods, apparatuses, and systems for analyzing microorganism strains from complex heterogeneous communities, predicting and identifying functional relationships and interactions thereof, and selecting and synthesizing microbial ensembles based thereon
# 165127                                                                                                                                                     method and system for activating different interactive functions using different types of finger contacts
# 169940                                                                                                                                                          method for improving accuracy of touch screen event analysis by use of spatiotemporal touch patterns
# 198101                                                                                                                                                          systems, apparatuses and methods for controlling prosthetic devices by gestures and other modalities
# 198126                                                                                                                                                                                method and apparatus for classifying touch events on a touch sensitive surface
# 201634                                                                                                                                                                                method and apparatus for classifying touch events on a touch sensitive surface
# 203191                                                                                                                                                                          method and system for predicting and/or tracking changes in external body conditions
# 204764                                                                                                                                                          method for improving accuracy of touch screen event analysis by use of spatiotemporal touch patterns
# 208388                                                                                                                                                                                                       phenotypic integrated social search database and method
# 210856                                                                                                                                                                                     method and apparatus for classifying finger touch events on a touchscreen
# 215818                                                                                                                                                                        methods and systems for predicting and/or tracking changes in external body conditions
#
#                                                                                                                                                                                                                                             ipc_classes  \
# 10595                                                                                                                                                                                                                 G06F3/041, G06F3/0484, G06F3/0488
# 23540                                                                                                                                                                                                                              G06F3/041, G06F3/043
# 25707                                                                                                                                            G06K9/62, G06N3/04, G06N3/08, G06T11/00, G06T11/60, G06T3/40, G06T7/11, G06T7/194, G06T7/246, G06T7/73
# 35612                                                                                                                                                                                                       G01N29/12, G01N29/46, G06F3/041, G06F3/0488
# 45418                                                                                                                                                                                                 G06N3/02, G06N3/08, G06T1/40, G06T7/10, G06T7/194
# 52891                                                                                                                                                              G06F3/0484, G06F3/0488, G06T11/60, G06T7/136, G06T7/33, G06T7/60, G06T7/73, G06T7/90
# 53008                                                                                                                                                                                    G06K9/00, G06Q10/10, G06T19/00, G06T7/00, G06T7/246, H04L29/08
# 53755   A61B3/113, A61B5/00, A61B5/0205, A61B5/021, A61B5/024, A61B5/0488, A61B5/05, A61B5/08, A61B5/145, A61B5/1459, A61B5/1473, A61B5/16, G01N33/53, G06F17/30, G06F19/00, G06F19/18, G06F19/24, G06Q30/02, G06Q30/06, G06Q50/22, G09B19/00, G09B5/12
# 54334                                                                                                                                                                                                                   G06F3/041, G06F3/043, G06F3/044
# 54376                                                                                                                                                                                              G01N33/487, G01N33/49, G06N3/04, G06N3/08, G06Q30/06
# 54943                                                                                                                                                                                                A61B5/02, A61B5/145, G01N21/01, G06T7/11, G06T7/90
# 55636                                                                                                                                                                                                                     A61B5/00, G06F3/01, H02S40/30
# 64429                                                                                                                                                                                                        G06F3/041, G06F3/043, G06F3/044, G06F3/045
# 65794                                                                                                                                                                                                       G01N29/12, G01N29/46, G06F3/041, G06F3/0488
# 68436                                                                                                                                                                                                                   G06F3/041, G06F3/043, G06F3/044
# 82634                                                                                                                                                                                                            A61F2/70, A61F2/72, G06F1/16, G06F3/01
# 89726                                                                                                                                                                                                                              G06F3/041, G06F3/043
# 94533                         A61B3/113, A61B5/00, A61B5/0205, A61B5/021, A61B5/024, A61B5/0488, A61B5/05, A61B5/08, A61B5/145, A61B5/1459, A61B5/1473, A61B5/16, G06F17/30, G06F19/18, G06F19/24, G06Q30/02, G06Q30/06, G06Q50/22, G09B19/00, G09B5/12
# 99356                                                                                                                                                                                                                                         G06F3/041
# 101646                                                                                                                                                                        A45D44/00, A61B5/00, A61B5/103, G06F19/00, G06Q50/00, G06T1/00, G06T11/00
# 104229                                                                                                                                                                                                      A61B5/00, A61B5/024, A61B5/0408, A61B5/1455
# 108442                                                                                                                                                                                                       G06F12/14, G06F19/00, G06F19/18, G06F21/62
# 121546                                                                                                                                                                                                                  G06N20/00, G16H10/60, G16H20/60
# 124083                                                                                                                                                                                                       G01N29/12, G01N29/14, G01N29/46, G06F3/041
# 126104                                                                                                                                                                                               A61B5/02, A61B5/145, G01N21/01, G06T7/11, G06T7/90
# 127757                                                                                                                                                              A61B5/00, A61B5/01, A61B5/0205, A61B5/16, G06T15/20, G06T19/00, G06T19/20, G06T7/00
# 130069                                                                                                                                                                                                                           G06F3/0484, G06F3/0488
# 141389                                                                                                                                                                                                                  G06F3/041, G06F3/043, G06F3/044
# 149597                                                                                                                           A01N63/00, A23K10/16, A23K10/18, A23K50/10, A23K50/30, A23K50/75, A61K35/74, C12Q1/06, C12Q1/68, C12Q1/6874, C12Q1/689
# 165127                                                                                                                                                                                                                           G06F3/0484, G06F3/0488
# 169940                                                                                                                                                                                                                G06F3/041, G06F3/0484, G06F3/0488
# 198101                                                                                                                                                                                                           A61F2/70, A61F2/72, G06F1/16, G06F3/01
# 198126                                                                                                                                                                                                       G06F3/041, G06F3/043, G06F3/044, G06F3/045
# 201634                                                                                                                                                                                                                  G06F3/041, G06F3/043, G06F3/044
# 203191                                                                                                                                                                        A45D44/00, A61B5/00, A61B5/103, G06F19/00, G06Q50/00, G06T1/00, G06T11/00
# 204764                                                                                                                                                                                                                             G06F3/041, G06F3/043
# 208388                                                                                                                                                                                                                             G06F17/30, G06F19/10
# 210856                                                                                                                                                                                         G06F3/041, G06F3/043, G06F3/0482, G06F3/0484, G06F3/0488
# 215818                                                                                                                                                                        A45D44/00, A61B5/00, A61B5/103, G06F19/00, G06Q50/00, G06T1/00, G06T11/00
#
#                                                                                                                                                                                                                                                                                                            abstract  \
# 10595   a method of classifying touch screen events uses known non-random patterns of touch events over short periods of time to increase the accuracy of analyzing such events. the method takes advantage of the fact that after one touch event, certain actions are more likely to follow than others. thus ...
# 23540   a method of classifying touch screen events uses known non-random patterns of touch events over short periods of time to increase the accuracy of analyzing such events. the method takes advantage of the fact that after one touch event, certain actions are more likely to follow than others. thus ...
# 25707   presented is a convolutional neural network (cnn) model for fingernail tracking, and a method design for nail polish rendering. using current software and hardware, the cnn model and method to render nail polish runs in real-time on both ios and web platforms. a use of loss mean pooling (lmp) co...
# 35612   a method and system for detecting imperfections on a surface of a touchscreen of an electrical device, comprising: swiping a test object, such as a fingertip, a fingernail or a pin, along at least a portion of the touchscreen; producing, by the touchscreen, an electric signal indicative of the t...
# 45418   presented is a convolutional neural network (cnn) model for fingernail tracking, and a method design for nail polish rendering. using current software and hardware, the cnn model and method to render nail polish runs in real-time on both ios and web platforms. a use of loss mean pooling (lmp) co...
# 52891   a computing device for providing a virtual fingernail cosmetic experience generates an initial pattern located at a first position on a user interface displaying a digital image, the digital image further displaying a target object. the computing device obtains user input for relocating the init...
# 53008   a user may be directed to the nail application (e.g., a mobile application that provides the various augmented reality and booking features discussed herein) via interactions with a social media site. for example, a user may browse facebook and see a friend's post or advertisement regarding a na...
# 53755   a method for generating correlations between human biological phenotype and human behavioral and/or emotional phenotype, and optionally to temporal location, comprising the steps of correlating data on biological phenotype with survey-based data on behavioral and/or emotional phenotype. the data...
# 54334   an apparatus classifies touch events. the apparatus includes a touch sensitive surface configured to generate a touch event when an object touches the touch sensitive surface. the touch event entails a mechanical vibration upon contact with the surface. the apparatus includes a touch event detec...
# 54376   a computer implemented method for use in conjunction with a computing device, system, network, and cloud with touch screen two dimension display or augmented/mixed reality three dimension display comprising: obtaining, analyzing and detecting user blood, saliva, hair, urine, stool, fingernail, h...
# 54943   a smartphone-based hemoglobin (hgb) assessment application quantitatively analyzes pallor in patient-sourced photos using image analysis algorithms to enable a noninvasive, accurate quantitative smartphone app for detecting anemia. a user takes a photo of his/her fingernail beds using the app an...
# 55636   systems, computer-implemented methods and/or computer program products that facilitate wearable multiplatform sensing are provided. in one embodiment, a computer-implemented method comprises: measuring, by a system operatively coupled to a processor, wirelessly on a nail plate, physiological dat...
# 64429   an apparatus classifies touch events. the apparatus includes a touch sensitive surface configured to generate a touch event when an object touches the touch sensitive surface. the touch event entails a mechanical vibration upon contact with the surface. the apparatus includes a touch event detec...
# 65794   a method and system for detecting imperfections on a surface of a touchscreen of an electrical device, comprising: swiping a test object, such as a fingertip, a fingernail or a pin, along at least a portion of the touchscreen; producing, by the touchscreen, an electric signal indicative of the t...
# 68436   an apparatus classifies touch events. the apparatus includes a touch sensitive surface configured to generate a touch event when an object touches the touch sensitive surface. the touch event entails a mechanical vibration upon contact with the surface. the apparatus includes a touch event detec...
# 82634             systems and methods for manual gesture recognition to control prosthetic devices. low encumbrance systems utilizing glove-based recognition to control prosthetic devices. prosthetic control systems and methods are also provided utilizing elements for application on the user's fingernails.
# 89726   a method of classifying touch screen events uses known non-random patterns of touch events over short periods of time to increase the accuracy of analyzing such events. the method takes advantage of the fact that after one touch event, certain actions are more likely to follow than others. thus ...
# 94533   a method for generating correlations between human biological phenotype and human behavioral and/or emotional phenotype, and optionally to temporal location, comprising the steps of correlating data on biological phenotype with survey-based data on behavioral and/or emotional phenotype. the data...
# 99356   an apparatus classifies touch events. the apparatus includes a touch sensitive surface configured to generate a touch event when an object touches the touch sensitive surface. the touch event entails a mechanical vibration upon contact with the surface. the apparatus includes a touch event detec...
# 101646  the present invention includes a method for predicting evolution of at least one condition of an external body portion of a subject. the method may include receiving first data, receiving second data, generating a forecasted or expected evolution of the at least one condition of the external bod...
# 104229  a sensor network for measuring physiological parameters of a mammal subject includes a plurality of spatially separated sensor systems that is time-synchronized to each other. each of the plurality of spatially separated sensor systems is attached to a respective position of the mammal subject a...
# 108442  in some embodiments, a device includes a memory and a processor. the memory is operatively coupled to the processor and configured to store encrypted personal data. the processor is configured to receive query and a personal identifier from a user. based on the query, the processor further ident...
# 121546  a computer implemented method for use in conjunction with a computing device, system, network, and cloud with touch screen two dimension display or augmented/mixed reality three dimension display comprising: obtaining, analyzing and detecting user blood, saliva, hair, urine, stool, fingernail, h...
# 124083  a method and system for detecting imperfections on a surface of a touchscreen of an electrical device, comprising: swiping a test object, such as a fingertip, a fingernail or a pin, along at least a portion of the touchscreen; producing, by the touchscreen, an electric signal indicative of the t...
# 126104  a smartphone-based hemoglobin (hgb) assessment application quantitatively analyzes pallor in patient-sourced photos using image analysis algorithms to enable a noninvasive, accurate quantitative smartphone app for detecting anemia. a user takes a photo of his/her fingernail beds using the app an...
# 127757  a mirror system includes a visual display disposed to convey information and images during an active period; and the visual display disposed to provide a reflected image during an inactive period; a learning machine receiving data from one or more cameras; and a processor coupled to the visual d...
# 130069  a method activates different interactive functions based on a classification of vibro-acoustic signals resulting from touch events with finger parts of a user. a primary function is trigger when an interactive element on a touch screen is touched with a finger tip of the user. an auxiliary funct...
# 141389  an apparatus classifies touch events. the apparatus includes a touch sensitive surface configured to generate a touch event when an object touches the touch sensitive surface. the touch event entails a mechanical vibration upon contact with the surface. the apparatus includes a touch event detec...
# 149597  methods, apparatuses, and systems for screening, analyzing and selecting microorganisms from complex heterogeneous communities, predicting and identifying functional relationships and interactions thereof, and synthesizing microbial ensembles based thereon are disclosed. methods for identifying ...
# 165127  a method activates different interactive functions based on a classification of vibro-acoustic signals resulting from touch events with finger parts of a user. a primary function is trigger when an interactive element on a touch screen is touched with a finger tip of the user. an auxiliary funct...
# 169940  a method of classifying touch screen events uses known non-random patterns of touch events over short periods of time to increase the accuracy of analyzing such events. the method takes advantage of the fact that after one touch event, certain actions are more likely to follow than others. thus ...
# 198101            systems and methods for manual gesture recognition to control prosthetic devices. low encumbrance systems utilizing glove-based recognition to control prosthetic devices. prosthetic control systems and methods are also provided utilizing elements for application on the user's fingernails.
# 198126  an apparatus classifies touch events. the apparatus includes a touch sensitive surface configured to generate a touch event when an object touches the touch sensitive surface. the touch event entails a mechanical vibration upon contact with the surface. the apparatus includes a touch event detec...
# 201634  an apparatus classifies touch events. the apparatus includes a touch sensitive surface configured to generate a touch event when an object touches the touch sensitive surface. the touch event entails a mechanical vibration upon contact with the surface. the apparatus includes a touch event detec...
# 203191  the present invention includes a method for predicting evolution of at least one condition of an external body portion of a subject. the method may include receiving first data, receiving second data, generating a forecasted or expected evolution of the at least one condition of the external bod...
# 204764  a method of classifying touch screen events uses known non-random patterns of touch events over short periods of time to increase the accuracy of analyzing such events. the method takes advantage of the fact that after one touch event, certain actions are more likely to follow than others. thus ...
# 208388  a method for generating correlations between human biological phenotype and human behavioral and/or emotional phenotype, and optionally to temporal location, comprising the steps of correlating data on biological phenotype with survey-based data on behavioral and/or emotional phenotype. the data...
# 210856  a system for classifying touch events includes a touch screen configured to display an interactive element, one or more vibro-acoustic sensors coupled to the touch screen, a touch event detector configured to monitor the one or more vibro-acoustic sensors and to save vibro-acoustic signals sense...
# 215818  the present invention includes a method for predicting evolution of at least one condition of an external body portion of a subject. the method may include receiving first data, receiving second data, generating a forecasted or expected evolution of the at least one condition of the external bod...
#
#                                                                                                                                                                                                                                                                                                              claims
# 10595   1. a method of analyzing touch screen events based on characterization of features derived from each touch event, the method comprising: detecting a sequence of touch events on a touch sensitive surface (100); generating vibro-acoustic waveform signals using at least one sensor (110) associated ...
# 23540   1. a method of analyzing touch screen events based on characterization of features derived from each touch event, the method comprising: detecting touch events on a touch sensitive surface; generating vibro-acoustic waveform signals using at least one sensor associated with the touch events; con...
# 25707   we claim:1. a computing device comprising a processor and a storage device coupled thereto, the storage device storing a cnn and instructions, which when executed by the processor, configure the computing device to: process an image comprising a plurality of objects with the cnn, the cnn configu...
# 35612   1. a method of detecting imperfections on a surface of a touchscreen of an electrical device, comprising: swiping a test object along at least a portion of the touchscreen; producing, by the touchscreen, an electric signal indicative of the test object's contact with the touchscreen; receiving a...
# 45418   w e claim:1. a computing device comprising a processor and a storage device coupled thereto, the storage device storing a cnn and instructions, which when executed by the processor, configure the computing device to: process an image comprising a plurality of objects with the cnn, the cnn config...
# 52891   at least the following is claimed:1. a method implemented in a computing device having a processor, memory, and a display, the method for providing a virtual fingernail cosmetic experience, comprising: generating an initial pattern, the initial pattern being superimposed at a first position on a...
# 53008   1. a system comprising: one or more client applications executable by respective communication devices, each communication device comprising one or more processors in communication with an image capture device, the one or more processors configured with processor-executable instructions included...
# 53755   1. a method for generating correlations between human biological phenotype and human behavioral and/or emotional phenotype, comprising the steps of: collecting survey-based data on behavioral and/or emotional phenotype from answers to behavioral and/or emotional questions from an individual or f...
# 54334   it is claimed:1. an apparatus for classifying touch events, the apparatus comprising: a touch sensitive surface configured to generate a touch event when an object or finger touches the touch sensitive surface, wherein the touch event entails a mechanical vibration generated upon contact with th...
# 54376   1. a computer implemented method of scoring a plurality of linked food or beverage ingredient combinations comprising: (a) receiving a biomarker subset or superset of a blood, saliva, hair, urine, stool, fingernail, height, weight, skin or biomarker sample from a user; (b) inputting a dataset of...
# 54943   what is claimed is:1 . a system for analyzing an image for estimating hemoglobin levels, the system comprising at least one processor configured to:receive an image of one or more fingernail beds of a user from a camera with a flash functionality activated;receive an indication of one or more re...
# 55636   1. a system, comprising: a memory that stores computer executable components; a processor, operably coupled to the memory, and that executes computer executable components stored in the memory, wherein the computer executable components comprise: one or more sensors that measure physiological da...
# 64429   it is claimed:1. an apparatus for classifying touch events, the apparatus comprising: a touch sensitive surface configured to generate a touch event when an object or finger touches the touch sensitive surface, wherein the touch event entails a mechanical vibration generated upon contact with th...
# 65794   1. a method of detecting imperfections on a surface of a touchscreen of an electrical device, comprising: swiping a test object along at least a portion of the touchscreen; producing, by the touchscreen, an electric signal indicative of the test object's contact with the touchscreen; receiving a...
# 68436   it is claimed:1. an apparatus for classifying touch events, the apparatus comprising: a touch sensitive surface configured to generate a touch event when an object or finger touches the touch sensitive surface, wherein the touch event entails a mechanical vibration generated upon contact with th...
# 82634   1. a system, comprising: a signal element configured for disposal on a first finger of a user; and a detection element configured for disposal on a second finger of a user, and configured to detect a signal generated by the signal element, wherein the signal indicates that a gesture has been per...
# 89726   1. a system for analyzing touch events based on characterization of features derived from the touch events, the system comprising: a touch sensitive surface for receiving touch events thereon; at least one sensor for generating vibro-acoustic waveform signals associated with the touch events; a ...
# 94533   1. 1.-21. (canceled)22. a database comprising information identifying a plurality of human subjects, data on biological phenotype of the plurality of subjects, survey-based data on behavioral and/or emotional phenotype of the plurality of subjects, and correlations between the data on biological...
# 99356   1. an apparatus for classifying touch events, the apparatus comprising:   a touch sensitive surface configured to generate a touch event when an object or finger touches the touch sensitive surface, wherein the touch event entails a mechanical vibration generated upon contact with the surface;  ...
# 101646  1. a method for predicting evolution of at least one condition of an external body portion of a subject, the method comprising: receiving first data, wherein the first data is representative of at least one condition of an external body portion of a subject in a first time frame;  receiving seco...
# 104229  what is claimed is:1. a sensor network for measuring physiological parameters of a mammal subject,comprising:a plurality of spatially separated sensor systems that is time-synchronized to each other, wherein each of the plurality of spatially separated sensor systems is attached to a respective ...
# 108442  1. an apparatus, comprising: a memory configured to store encrypted personal data; and a processor operatively coupled to the memory, the processor configured to receive a query and a personal identifier from a user, the processor configured to identify a portion of the encrypted personal data a...
# 121546  1. a method, comprising:receiving biomarker data corresponding to a user;receiving nutritional data corresponding to a plurality of food ingredients;determining one or more optimized foods for the user based on the biomarker data, the nutritional data, and one or more machine learning fitting mo...
# 124083  1. a method of detecting imperfections on a surface of a touchscreen of an electrical device, comprising: swiping a test object along at least a portion of the touchscreen; producing, by the touchscreen, an electric signal indicative of the test object's contact with the touchscreen; receiving a...
# 126104  what is claimed is:1 . a system for analyzing an image for estimating hemoglobin levels, the system comprising at least one processor configured to:receive an image of one or more fingernail beds of a user from a camera with a flash functionality activated;receive an indication of one or more re...
# 127757  1. a mirror system, comprising: a visual display disposed to convey information and images during an active period, wherein the visual display is disposed to provide a reflected image during an inactive period; a high definition video camera and capturing images of the user and one or more items...
# 130069  1. a method for activating different interactive functions, the method comprising: triggering a first function related to an interactive element on a touch screen when a user interacts with the interactive element using a first finger part of a plurality of finger parts of the user, wherein the ...
# 141389  1. an apparatus for classifying touch events, the apparatus comprising: a segmentation unit configured to sample at least one mechanical vibration signal associated with a touch event on a surface to create a digital representation of the at least one mechanical vibration signal; a conversion un...
# 149597  1. 1-87. (canceled)88. a method of forming an active microorganism bioensemble configured to alter a property in a target biological environment, comprising: obtaining at least two sample sets sharing at least one common environmental parameter and having at least one different environmental par...
# 165127  1. a method for activating different interactive functions, the method comprising: triggering a primary function related to an interactive element on a touch screen when a user interacts with the interactive element using any one of finger parts of the user; and launching an auxiliary function r...
# 169940  what is claimed is:1. a method of analyzing touch screen events based on characterization of features derived from each touch event, the method comprising:detecting touch events on a touch sensitive surface;generating vibro-acoustic waveform signals using at least one sensor associated with the ...
# 198101  1. a system, comprising: a signal element configured to generate a signal, wherein the signal element comprises an led; a fingernail mount configured to secure the signal element on a fingernail of a finger of a user such that the signal element is facing the fingernail; and a detection element ...
# 198126  it is claimed:1. an apparatus for classifying mechanical vibrations in a rigid surface caused by a finger or by a passive object coming into contact with the rigid surface, the apparatus comprising: a sampler that receives electrical signals indicative of the mechanical vibrations in the rigid s...
# 201634  1. a method for classifying touch events, the method comprising: sampling at least one mechanical vibration signal associated with a touch event on a surface to create a digital representation of the at least one mechanical vibration signal; converting the digital representation into an electric...
# 203191  a method for predicting evolution of at least one condition of an external body portion of a subject, the method comprising: receiving first data, wherein the first data is representative of the at least one condition; receiving second data, reflective of how the at least one external body condi...
# 204764  1. a method of analyzing touch events based on characterization of features derived from the touch events, the method comprising: detecting the touch events, including an initial touch event from an initial hand part and a subsequent touch event, on a touch sensitive surface; generating vibro-ac...
# 208388  1. a method for generating correlations between human biological phenotype and human behavioral and/or emotional phenotype, comprising the steps of:correlating data on biological phenotype collected from an individual with surveybased data on behavioral and/or emotional phenotype.2. the method o...
# 210856  1. a system for classifying finger touch events, the system comprising: a touch screen configured to display an interactive element; one or more vibro acoustic sensors coupled to the touch screen; a touch event detector configured to monitor the one or more vibro acoustic sensors and to save vib...
# 215818  1. a method for predicting evolution of at least one condition of an external body portion of a subject, the method comprising: receiving first data, wherein the first data is representative of at least one condition of an external body portion of a subject in a first time frame; receiving secon...

# %% [markdown]
# ##### cleans(e|ing)

# %%
keyword = keywords_cosmetics[6]
keyword
# Out:
# 'cleans(e|ing)'

# %%
df_candidate = df[(df[keyword] > 0)
                  & (df.ipc_classes.str.count("G06")==0) #Escludo "COMPUTING; CALCULATING; COUNTING"
                  & (df.ipc_classes.str.count("G01")==0) #Escludo "MEASURING; TESTING"
                  & (df.ipc_classes.str.count("A61")==0) #MEDICAL OR VETERINARY SCIENCE; HYGIENE
                  & (df.ipc_classes.str.count("G16")==0)#NFORMATION AND COMMUNICATION TECHNOLOGY [ICT] SPECIALLY ADAPTED FOR SPECIFIC APPLICATION FIELDS
                  & (df.ipc_classes.str.count("G08")==0)#SIGNALLING
                  & (df.ipc_classes.str.count("G09")==0)#EDUCATION; CRYPTOGRAPHY; DISPLAY; ADVERTISING; SEALS
                  & (df.ipc_classes.str.count("H04")==0)#LECTRIC COMMUNICATION TECHNIQUE
                 ].query("title not in @df_selected")

df_candidate[["title", "ipc_classes","abstract", "claims"]]
# Out:
#                                                                                  title  \
# 136883  electric power grid supply and load prediction using cleansed time series data
# 142312                                                             back-cleansing unit
# 155783                   system and method for virtual energy assessment of facilities
# 169618                                  power meter based monitoring of elevator usage
# 181560                                  power meter based monitoring of elevator usage
# 182424              apparatus and method for improved development of oil and gas wells
# 201409                                        apparatus for inhibiting fines carryover
# 204150  electric power grid supply and load prediction using cleansed time series data
# 207713                          water spray fume cleansing with demand-based operation
# 216985                                                      asset condition monitoring
#
#                                                                                           ipc_classes  \
# 136883                                                                 G05B15/02, H02J13/00, H02J3/00
# 142312                                              A46B13/04, A47K5/12, A47K7/02, A47K7/03, A47K7/04
# 155783                                                                            G05B13/02, G05F1/66
# 169618                                                                                       B66B5/00
# 181560                                                                                       B66B5/00
# 182424                                                                           E21B41/00, E21B44/00
# 201409                                                                B01D24/04, B01D24/46, B01D41/02
# 204150                                                                 G05B15/02, H02J13/00, H02J3/00
# 207713  A62C2/06, A62C3/00, A62C37/08, A62C37/11, A62C37/48, B01D5/00, B05B12/12, B05B7/26, F24C15/20
# 216985                                                                                      G05B23/02
#
#                                                                                                                                                                                                                                                                                                            abstract  \
# 136883  an apparatus includes a processor to: assign each value of each set of values of an initial supply meter data and of an initial load meter data to one of multiple buckets based on weather conditions and/or time and date; for each bucket, generate upper and lower bounds of power provision and pow...
# 142312  an automatic back-cleansing apparatus for fixing to a vertical bath or shower surface includes a main housing section having a rotating head receiving section with gear teeth for engaging rotating heads on a rotating disk section adjacent the main housing section. the rotating disk section inclu...
# 155783  embodiments of the invention provide methods and systems to analyze energy consumption and support demand management of a portfolio of facilities. some embodiments of the invention include a computer implemented method for collecting and cleansing street addresses, time series energy consumption...
# 169618  the invention refers to a system comprising an elevator monitoring device (300) for monitoring at least one elevator (200) operatively coupled to at least one motor (240) which is operatively connected to at least one power meter (260), wherein the elevator monitoring device (300) is configured ...
# 181560  the invention refers to a system comprising an elevator monitoring device (300) for monitoring at least one elevator (200) operatively coupled to at least one motor (240) which is operatively connected to at least one power meter (260), wherein the elevator monitoring device (300) is configured ...
# 182424  a system, device and method are described for controlling development of an oil or gas well. data from the well is analysed to provide control signals for the well with the additional feature of cleaning the data in conjunction with the analysis. data is cleaned using knowledge based techniques,...
# 201409  apparatus for inhibiting fines carryover in the form of a settlement tank comprising: a filter which divides the tank into upper and lower portions; a fluid inlet in the lower portion for admitting into the tank a fluid with entrained solids; and a fluid outlet in the upper portion through which...
# 204150  an apparatus includes a processor to: assign each value of each set of values of an initial supply meter data and of an initial load meter data to one of multiple buckets based on weather conditions and/or time and date; for each bucket, generate upper and lower bounds of power provision and pow...
# 207713  a system and method is provided for demand-based control of a cold water spray system of an exhaust ventilation system. embodiments include determining a demand load of a cooking appliance that generates cooking effluent in a vicinity of an exhaust hood, and determining a temperature of water in...
# 216985  this invention concerns a machine fault diagnostic system. sensors are provided for sensing an operational parameter of the machine over time in use and outputting corresponding sensor signals (18). a machine operation diagnosis tool (10) is arranged to receive the sensor signals and has a data ...
#
#                                                                                                                                                                                                                                                                                                              claims
# 136883  1. an apparatus comprising a processor and a storage to store instructions that, when executed by the processor, cause the processor to perform operations comprising: retrieve initial supply meter data from the storage, wherein: the initial supply meter data comprises, for each supply meter of m...
# 142312  1. an automatic back-cleansing apparatus for fixation on a vertical surface, the apparatus comprising: a main housing section; a rotating head receiving section on the main housing section; wall mounting means on the main housing section; and a power producing means, wherein the rotating head re...
# 155783  1. a computer-implemented system for remotely assessing energy performance of a plurality of facilities, the system comprising: a processor; a non-transitory computer-readable storage medium in data communication with the processor, the non-transitory computer-readable storage medium including s...
# 169618  1. a system (100) comprising an elevator monitoring device (300) for monitoring at least one elevator (200) operatively coupled to at least one motor (240) which is operatively connected to at least one power meter (260), wherein the elevator monitoring device (300) is configured to receive, fro...
# 181560  patent claims1. a system (100) comprising an elevator monitoring device (300) for monitoring at least one elevator (200) operatively coupled to at least one motor (240) which is operatively connected to at least one power meter (260), wherein the elevator monitoring device (300) is configured to...
# 182424  1. a system for controlling the development of an oil or gas well comprising: a data capture means for receiving well data; a data analysis means for analysing said well data, the data analysis means being responsive to a data cleaning means for cleaning said well data ; and a control means for ...
# 201409  1. a method of refilling a filter in a tank with filter media, in which the tank comprises: a filter which divides the tank into upper and lower portions, where the filter comprises: filter media supported on a permeable wall, the wall including a filter media outlet which is normally closed;   ...
# 204150  1. an apparatus comprising a processor and a storage to store instructions that, when executed by the processor, cause the processor to perform operations comprising: retrieve initial supply meter data from the storage, wherein: the initial supply meter data comprises, for each supply meter of m...
# 207713  1. a method of controlling a cold water spray system in an exhaust ventilation system (102), the exhaust ventilation system including an exhaust hood (106) and the cold water spray system, the cold water spray system including a plurality of cold water spray nozzles (108), the method comprising:...
# 216985  1. a machine fault diagnostic system, the system comprising: a sensor for sensing an operational parameter of the machine over time in use and outputting a corresponding sensor signal; a diagnosis tool arranged to receive said sensor signal, said tool comprising a data store comprising operation...

# %% [markdown]
# ##### manicur(e|ing)

# %%
keyword = keywords_cosmetics[7]
keyword
# Out:
# 'manicur(e|ing)'

# %%
df_candidate = df[(df[keyword] > 0)].query("title not in @df_selected")

df_candidate[["title", "ipc_classes","abstract", "claims"]]
# Out:
#                                                      title  \
# 20938  automatic nail polish application system and method
#
#                                                  ipc_classes  \
# 20938  A45D29/00, A45D29/11, A45D29/12, A45D29/14, A45D34/04
#
#                                                                                                                                                                                                                                                                                                           abstract  \
# 20938  the present disclosure relates to a robotic apparatus and methods for automatic nail polish application on natural or artificial finger or toe nails. the robot uses artificial intelligence (al) to identify and paints the nails. the robot uses depth sensors and computer vision to plan the movemen...
#
#                                                                                                                                                                                                                                                                                                             claims
# 20938  1. a system for automatically polishing a nail of a user including:an end-effector havinga cartridge receiving unit,a cartridge including nail polish, anda nozzle;a sensor, to generate target signals from a target location;a nail determination unit, receiving said target signals, to automaticall...

# %%
df_selected = pd.concat([df_selected, df_candidate])

len(df_selected)
# Out:
# 47

# %% [markdown]
# ##### pedicur(e|ing)

# %%
keyword = keywords_cosmetics[8]
keyword
# Out:
# 'pedicur(e|ing)'

# %%
df_candidate = df[(df[keyword] > 0)].query("title not in @df_selected")

df_candidate[["title", "ipc_classes","abstract", "claims"]]
# Out:
# Empty DataFrame
# Columns: [title, ipc_classes, abstract, claims]
# Index: []

# %% [markdown]
# ##### nail(s| |-)*polish

# %%
keyword = keywords_cosmetics[11]
keyword
# Out:
# 'nail(s| |-)*polish'

# %%
df_candidate = df[(df[keyword] > 0)
                  & (df.ipc_classes.str.count("G06")==0)
                 ].query("title not in @df_selected")

df_candidate[["title", "ipc_classes","abstract", "claims"]]
# Out:
#                                                                           title  \
# 20938                       automatic nail polish application system and method
# 69896   method for simulating the rendering of a make-up product on a body area
# 158644  method for simulating the rendering of a make-up product on a body area
#
#                                                   ipc_classes  \
# 20938   A45D29/00, A45D29/11, A45D29/12, A45D29/14, A45D34/04
# 69896                                               A45D44/00
# 158644                                              A45D44/00
#
#                                                                                                                                                                                                                                                                                                            abstract  \
# 20938   the present disclosure relates to a robotic apparatus and methods for automatic nail polish application on natural or artificial finger or toe nails. the robot uses artificial intelligence (al) to identify and paints the nails. the robot uses depth sensors and computer vision to plan the movemen...
# 69896   the invention proposes a method for simulating a rendering of a makeup product on a body area is disclosed comprising: - acquiring an image of the body area without makeup of a subject, - determining first color parameters of the pixels of the image corresponding to the body area without makeup,...
# 158644  the inventionproposes a method for simulating a rendering of a makeup product on a body area is disclosed comprising:∘ acquiring an image of the body area without makeup of a subject,∘ determining first color parameters of the pixels of the image corresponding to the body area without makeup,∘ i...
#
#                                                                                                                                                                                                                                                                                                              claims
# 20938   1. a system for automatically polishing a nail of a user including:an end-effector havinga cartridge receiving unit,a cartridge including nail polish, anda nozzle;a sensor, to generate target signals from a target location;a nail determination unit, receiving said target signals, to automaticall...
# 69896   1. a method (200) for simulating a rendering of a makeup product on a body area, the method being performed by a processor (1 1 ), and comprising :o acquiring (210) an image of the body area without makeup of a subject, o determining (230) first color parameters of the pixels of the image corres...
# 158644  1. a method (200) for simulating a rendering of a makeup product on a body area, the method being performed by a processor (11), and comprising : ∘ acquiring (210) an image of the body area without makeup of a subject, ∘ determining (230) first color parameters of the pixels of the image corresp...

# %%
df_selected = pd.concat([df_selected, df[df.title == "automatic nail polish application system and method"]])
len(df_selected)
# Out:
# 48

# %% [markdown]
# ##### 'lip(s)?'

# %%
keyword = keywords_cosmetics[12]
keyword
# Out:
# ' lip(s)?'

# %%
df_candidate = df[(df[keyword] > 10)
                  & (df.ipc_classes.str.count("G06")==0)
                  & (df.ipc_classes.str.count("G(01|11|10|09)")==0)
                  & (df.ipc_classes.str.count("C12Q")==0)
                  & (df.ipc_classes.str.count("C62")==0)
                  & (df.ipc_classes.str.count("B60")==0)
                 ].query("title not in @df_selected")

df_candidate[["title", "ipc_classes","abstract", "claims"]]
# Out:
#                                                                                                           title  \
# 460                                                                     intubation delivery systems and methods
# 10916                  establishing packet data network connectivity for local internet protocol access traffic
# 12187                                                                             alphavirus neoantigen vectors
# 15782                                                                  ingestible device and associated methods
# 36358                                         novel tumor-specific antigens for ovarian cancer and uses thereof
# 39847                  establishing packet data network connectivity for local internet protocol access traffic
# 46175                            methods of treating liver disorders or lipid disorders with a thr-beta agonist
# 61057                                                            method and composition for removing waxy soils
# 91132                                        novel microorganisms producing a thermostable lipase and their use
# 91290                                                             systems and methods for inferring cell status
# 102659                                        devices, systems, and methods for tumor visualization and removal
# 107724                                                                                   rotavirus mrna vaccine
# 112784                                             systems for controlling a drying cycle in a drying apparatus
# 113096                                                                            alphavirus neoantigen vectors
# 119887  reagents and methods with wnt agonists and bioactive lipids for generating and expanding cardiomyocytes
# 122292                                                                   drug delivery methods and compositions
# 145457                 establishing packet data network connectivity for local internet protocol access traffic
# 151046                 establishing packet data network connectivity for local internet protocol access traffic
# 160973                                             systems for controlling a drying cycle in a drying apparatus
# 169421                                         apparatus, devices and methods for in vivo imaging and diagnosis
# 176622                                       novel microorganisms producing a thermostable lipase and their use
# 185888                                      resin film manufacturing device and resin film manufacturing method
# 191483                                   visual presentation of gingival line generated based on 3d tooth model
# 195797                                            compositions and methods for assessing cardiovascular disease
# 199880                                                 exosome mimicking nanovesicles making and biological use
# 201811                           methods of treating liver disorders or lipid disorders with a thr-beta agonist
# 207539                                             systems for controlling a drying cycle in a drying apparatus
# 207966                                  generating a virtual depiction of an orthodontic treatment of a patient
#
#                                                                                                                                                                                                                                                                                                         ipc_classes  \
# 460                                                                                                                                                                                                                                                                       A61B1/00, A61B1/267, A61M16/00, A61M16/04
# 10916                                                                                                                                                                                                                                                                                           H04L29/12, H04W8/08
# 12187                                                                                                                                                                                                                                              A61K39/00, A61K39/12, A61P31/12, C07K14/47, C07K14/74, C12N15/86
# 15782                                                                                                                                                                                                                                                                     A61B5/00, A61B5/06, A61B5/145, A61B5/1455
# 36358                                                                                                                                                                  A61K35/12, A61K35/17, A61K39/00, A61K9/127, A61P35/00, A61P37/04, C07K14/47, C07K14/725, C07K14/82, C07K7/06, C12N15/12, C12N5/078, C12N5/10
# 39847                                                                                                                                                                                                                                                                     H04W48/00, H04W76/02, H04W8/08, H04W84/04
# 46175                                                                                                                                                                                                                                                                                 A61K31/53, A61P1/16, A61P3/06
# 61057                                                                                                                                                                                                                                                  C11D11/00, C11D17/04, C11D3/18, C11D3/43, C11D7/24, C11D7/26
# 91132                                                                                                                                                                                                                                                                                            C12N9/14, C12R1/01
# 91290                                                                                                                                                                                                                                                                                                     G16B25/10
# 102659                                                                                                                                                                                                                                                         A61B5/00, A61B90/00, A61B90/30, A61K41/00, A61K49/00
# 107724                                                                                                                                                                                                                                             A61K38/00, A61K39/00, A61K39/12, A61K39/15, A61P31/14, C12N15/62
# 112784                                                            B01D15/00, B01D17/02, B01J20/26, B01J20/28, C10G33/02, C11D11/00, C11D3/16, C11D3/39, C11D3/395, C11D3/40, C11D3/43, C11D7/24, C11D7/26, C11D7/32, C11D7/50, D06F43/08, D06F58/28, D06L1/10, D06L1/12, D06M13/00, D06M23/06, F26B21/14, F26B25/00
# 113096                                                                                                                                                                                                                                                       A61K35/76, A61K39/12, C07K14/18, C07K14/705, C12N15/86
# 119887                                                                                                                                                                                                                                                                                         A61K35/34, C12N5/077
# 122292                                                                                                                                                                                                                                                                               A61K47/69, A61K9/51, A61P35/00
# 145457                                                                                                                                                                                                                                                                                          H04L29/12, H04W8/08
# 151046                                                                                                                                                                                                                                                                                          H04L29/12, H04W8/08
# 160973  B01D15/00, B01D17/02, B01J20/26, B01J20/28, C10G33/02, C11D11/00, C11D3/16, C11D3/20, C11D3/30, C11D3/37, C11D3/39, C11D3/395, C11D3/40, C11D3/43, C11D3/50, C11D7/02, C11D7/24, C11D7/26, C11D7/32, C11D7/50, D06F58/28, D06L1/02, D06L1/04, D06L1/10, D06L1/12, D06L3/02, D06M13/00, D06M23/06, F26B21/14
# 169421                                                                                                                                                                                                                                                                                                     A61B5/00
# 176622                                                                                                                                                                                                                                                                                           C12N9/14, C12R1/01
# 185888                                                                                                                                                                                                                                                                  B29C48/08, B29C48/31, B29C48/355, B29C48/92
# 191483                                                                                                                                                                                                                                                                                           A61C7/00, A61C9/00
# 195797                                                                                                                                                                                                                                                                      A61K48/00, C12N5/07, C12N5/16, C12R1/91
# 199880                                                                                                                                                                                                                                                   A61K31/7088, A61K31/7105, A61K31/713, A61K35/28, A61K9/127
# 201811                                                                                                                                                                                                                                                                                A61K31/53, A61P1/16, A61P3/06
# 207539  B01D15/00, B01D17/02, B01J20/26, B01J20/28, C10G33/02, C11D11/00, C11D3/16, C11D3/20, C11D3/30, C11D3/37, C11D3/39, C11D3/395, C11D3/40, C11D3/43, C11D3/50, C11D7/02, C11D7/24, C11D7/26, C11D7/32, C11D7/50, D06F58/28, D06L1/02, D06L1/04, D06L1/10, D06L1/12, D06L3/02, D06M13/00, D06M23/06, F26B21/14
# 207966                                                                                                                                                                                                                                                                                                     A61C7/00
#
#                                                                                                                                                                                                                                                                                                            abstract  \
# 460     various methods and systems for delivery of an ett for intubation are provided. in one example, an ett delivery system comprises a rail system, where the rail system comprises at least one rail. in some examples the rail system engages with an ett and at least partially defines an ett delivery p...
# 10916   providing for establishment of local internet protocol access (lipa) for cellular communication is provided herein. according to particular aspects of the subject disclosure, provided are mechanisms to identify a request to establish a packet network connection as a request for a lipa context. o...
# 12187                                                            disclosed herein are alphavirus vectors that include neoantigen-encoding nucleic acid sequences derived from a tumor of a subject. also disclosed are nucleotides, cells, and methods associated with the vectors including their use as vaccines.
# 15782                                                an ingestible device is disclosed which can produce spectral data of one or more analytes, as well as associated methods for characterizing the gastrointestinal tract of a subject which contains such analytes. related kits and systems are also disclosed.
# 36358   ovarian cancer, notably high-grade serous ovarian cancer (hgsc), the principal cause of death from gynecological malignancies in the world, has not significantly benefited from recent progress in cancer immunotherapy. while hgsc infiltration by lymphocytes correlates with superior survival, the ...
# 39847   a method of terminating packet connectivity for local internet protocol access, lipa, traffic involving a wireless communication, comprising: receiving a message that indicates an access terminal is establishing a wireless connection with a base station; determining that an existing lipa packet ...
# 46175   the present invention provides a method for treating a liver disorder or lipid disorder in a subject in need thereof with 2-(3,5-dichloro-4-((5-isopropyl-6-oxo-1,6-dihydropyridazin-3- yl)oxy)phenyl)-3,5-dioxo-2,3,4,5-tetrahydro-1,2,4-triazine-6-carbonitrile, a stereoisomer, a salt thereof, or a ...
# 61057   the invention generally pertains to a method and composition for removing waxy soils. the invention also pertains to a method and composition for removing lip cosmetic soils such as lipsticks, chapsticks(tm), and the like. the invention further pertains to a method and composition for removing l...
# 91132   the present invention relates to the isolation of thermostable lipase producing bacteria, optimizing thermostable lipase production. yet other objective of the present invention provides expressing lipase gene encoding thermostable lipase and characterizing purified recombinant thermostable lipa...
# 91290   systems and methods for inferring a status of a cell population are provided. described techniques allow deconvolving a first clonal population comprising a first plurality of cells of a species, wherein nucleic acid sequence reads from each cell in the first plurality of cells are obtained. the...
# 102659  a method of assessing surgical margins is disclosed. the method includes, subsequent to administration of a compound configured to induce emissions of between about 600 nm and about 660 nm in cancerous tissue cells, positioning a distal end of a handheld, white light and fluorescence-based imagi...
# 107724  the invention is directed to a coding rna for a rotavirus vaccine. the coding rna comprises at least one coding region encoding at least one antigenic peptide or protein of a rotavirus, in particular vps* of a rotavirus, or immunogenic fragment or immunogenic variant thereof. the present inventi...
# 112784  the present invention relates to systems for controlling a drying cycle in a drying apparatus by monitoring the lipophilic fluid vapor concentration. the systems utilize a gas sensor capable of sensing the concentration of lipophilic fluid vapor in the drying apparatus drum or a combination of s...
# 113096                                                           disclosed herein are alphavirus vectors that include neoantigen-encoding nucleic acid sequences derived from a tumor of a subject. also disclosed are nucleotides, cells, and methods associated with the vectors including their use as vaccines.
# 119887  methods for expanding beating cardiomyocytes, comprising treating the beating cardiomyocytes with one or more wnt agonists, one or more bioactive lipids or a combination of one or more wnt agonists and one or more bioactive lipids. methods for differentiating stem cells, including ips cells, int...
# 122292                                                                        the present application provides liposomal compositions containing anti-cancer agents and tumor-targeting lipopeptides. the present application also provides nanodiamond complexes and particles as carriers for anti-cancer agents.
# 145457  a method of wireless communication, comprising: identifying a request for a packet data network connection, a pdn connection, as being a request for local internet protocol access, lipa, traffic; generating a lipa access point name, a lipa apn; and wirelessly transmitting the lipa apn and the re...
# 151046                                                                                                                                                                                                                                                                                                          NaN
# 160973  the present invention relates to systems for controlling a drying cycle in a drying apparatus by monitoring the lipophilic fluid vapor concentration. the systems utilize a gas sensor capable of sensing the concentration of lipophilic fluid vapor in the drying apparatus drum or a combination of s...
# 169421  exemplary method and apparatus for diagnosing or characterizing an inflammation within an anatomical structure can be provided. for example, using at least one source arrangement, it is possible to provide at least one first electro-magnetic radiation to the anatomical structure at at least one ...
# 176622  the present invention relates to the isolation of thermostable lipase producing bacteria, optimizing thermostable lipase production. yet other objective of the present invention provides expressing lipase gene encoding thermostable lipase and characterizing purified recombinant thermostable lipa...
# 185888  in a resin film manufacturing device according to an embodiment, a current state and a reward for a previously selected action are determined for each heat bolt based on a control error calculated from a thickness distribution of a resin film acquired from a thickness sensor. then, control condi...
# 191483  systems and methods of simulating dental treatments are disclosed. a method may include capturing a first 2d image of a patient's face, including the patient's teeth, building a parametric 3d model of the patient's teeth and gingiva based on the first 2d image, developing a simulated outcome of ...
# 195797  some aspects of this disclosure relate to the characterization of lipoproteins (e.g., vldl, ldl, and/or hdl) based on their content of lipoprotein-associated proteins (e.g., apolipoproteins) for the determination of cardiovascular disease risk. some aspects of this disclosure relate to methods f...
# 199880  this disclosure provides an exosome mimicking nanovesicle (emn) comprising cell-derived plasma membrane or lipid rafts and substantially devoid of native exosomes. the emns can be derived from a differentiated cell or a stem cell. they are useful to carry a variety of cargo, e.g., a secretome, o...
# 201811  the present invention provides a method for treating a liver disorder or lipid disorder in a subject in need thereof with 2-(3,5-dichloro-4-((5-isopropyl-6-oxo-1,6-dihydropyridazin-3-yl)oxy)phenyl)-3,5-dioxo-2,3,4,5-tetrahydro-1,2,4-triazine-6-carbonitrile, a stereoisomer, a salt thereof, or a m...
# 207539  the present invention relates to systems for controlling a drying cycle in a drying apparatus by monitoring the lipophilic fluid vapor concentration. the systems utilize a gas sensor capable of sensing the concentration of lipophilic fluid vapor in the drying apparatus drum or a combination of s...
# 207966  a computer-implemented method for generating a virtual depiction of an orthodontic treatment of a patient is disclosed herein. the computer-implemented method may involve gathering a three-dimensional (3d) model modeling the patients dentition at a specific treatment stage of an orthodontic trea...
#
#                                                                                                                                                                                                                                                                                                              claims
# 460     1. an ett delivery system, comprising: a rail system comprising at least one rail, where the rail system engages with an ett and at least partially defines an ett delivery path; a delivery mechanism operatively linked with the rail system to deliver the ett along the ett delivery path; and a bla...
# 10916   what is claimed is:1. a method of wireless communication for establishing packet connectivity for local internet protocol access (lipa) traffic, comprising: receiving an electronic message comprising a request for a packet data network connection (a pdn connection); determining whether the reque...
# 12187   1. a composition for delivery of a neoantigen expression system, comprising: the neoantigen expression system, wherein the neoantigen expression system comprises one or more vectors, the one or more vectors comprising: (a) an rna alphavirus backbone, wherein the rna alphavirus backbone comprises...
# 15782   what is claimed is:1 . a device, comprising:a spectrometer configured to generate spectral data of a sample within the gastrointestinal (gl) tract of a subject in vivo,wherein the device is an ingestible device, and the spectral data comprises information useful to determine analyte information ...
# 36358   1. a tumor antigen peptide comprising one of the amino acid sequences set forth in seq id nos: 1 -103.2. the tumor antigen peptide of claim 1 , comprising one of the amino acid sequences set forth in seq id nos: 19-103.3. the tumor antigen peptide of claim 1 or 2, wherein said tumor antigen pept...
# 39847   1. a method of terminating packet connectivity for local internet protocol access, lipa, traffic involving a wireless communication, comprising: receiving a message that indicates an access terminal is establishing a wireless connection with a base station; determining that an existing lipa pack...
# 46175   1. a method of treating a liver disorder or lipid disorder in a subject in need thereof, the method comprising:(a) administering a first dose of 2-(3,5-dichloro-4-((5-isopropyl-6-oxo-l,6- dihydropyridazin-3-yl)oxy)phenyl)-3,5-dioxo-2,3,4,5-tetrahydro-l,2,4-triazine-6-carbonitrile ("compound a") ...
# 61057   1. (canceled)2. (canceled)3. (canceled)4. (canceled)5. a method of removing a lip cosmetic soil from drinkware comprising:  a. providing drinkware having a lip cosmetic soil;  b. placing the drinkware in a pretreating apparatus having a pretreating composition;  c. applying a pretreating composi...
# 91132   biologically pure cultures of geobacillus sp. strain arm and aneurinibacillus thermoaerophilus strain afna isolated from soil; wherein a) geobacillus sp strain arm is deposited under the accession number dsm 21496 at deutschesammlung von mikroorganismen und zellkulturen (dsmz) and ncimb 41583 at...
# 91290   1. a method of deconvolving a first clonal population comprising a first plurality of cells of a species, the method comprising:at a computer system having one or more processors, and memory storing one or more programs for execution by the one or more processors:(a) obtaining a set of nucleic a...
# 102659  we claim:1. a method of assessing surgical margins, comprising: subsequent to administration of a compound configured to induce porphyrins in cancerous tissue cells, positioning a distal end of a handheld, white light and fluorescence-based imaging device adjacent to a surgical margin; with the ...
# 107724  1. a coding rna for a rotavirus vaccine comprisinga) at least one heterologous 5' untranslated region (5'-utr) and/or at least one heterologous 3' untranslated region (3'-utr); andb) at least one coding sequence operably linked to said 3'-utr and/or 5'-utr encoding at least one antigenic protein...
# 112784  1. a system for controlling a drying cycle in a drying apparatus characterized by a lipophilic fluid vapor, and a gas sensor capable of sensing the concentration of the lipophilic fluid vapor present in said drying apparatus and transmitting a signal representative of the lipophilic fluid vapor ...
# 113096  what is claimed is:1. a composition for delivery of a neoantigen expression system, comprising:the neoantigen expression system, wherein the neoantigen expression system comprises one or more vectors, the one or more vectors comprising:(a) an rna alphavirus backbone, wherein the rna alphavirus b...
# 119887  1. a method for expanding beating cardiomyocytes, the method comprising treating the beating cardiomyocytes with a wnt agonist, a bioactive lipid and/or a combination of the wnt agonist and bioactive lipid.2. the method of claim 1, wherein the beating cardiomyocytes are human cardiomyocytes.3. (...
# 122292  what is claimed is: 1. a polypeptide, or a pharmaceutically acceptable salt thereof, comprising an amino acid sequence:kclspprypc (seq id no: 1).2. the polypeptide of claim 1, comprising an–s–s– bridge between cysteine (c) residues in the amino acid sequence seq id no: 1.3. a lipopeptide of form...
# 145457  1. a method of wireless communication, comprising: identifying a request for a packet data network connection, a pdn connection, as being a request for local internet protocol access, lipa, traffic; generating a lipa access point name, a lipa apn; and wirelessly transmitting the lipa apn and the...
# 151046  1. a method of wireless communication performed in a mobility entity for establishing packet connectivity for local internet protocol access, lipa, traffic, comprising: receiving (902) an electronic message comprising a request for a packet data network connection, a pdn connection; determining ...
# 160973  1. a system for controlling a drying cycle in a drying apparatus comprising a lipophilic fluid vapor, and a gas sensor capable of sensing the concentration of lipophilic fluid vapor present in said drying apparatus and transmitting a signal representative of the lipophilic fluid vapor concentrat...
# 169421  1. a method for diagnosing or characterizing an inflammation within an anatomical structure, comprising:providing at least one first electro-magnetic radiation to the anatomical structure at at least one first wavelength in vivo;detecting at least one second electro-magnetic radiation at at leas...
# 176622  1. a biologically pure culture of geobacillus sp. strain arm; wherein the geobacillus sp strain arm is deposited under the accession ncimb 41583 at the national collection of industrial, marine and food bacteria (ncimb), uk.2. the biologically pure cultures according to claim 1, wherein the geob...
# 185888  1. a resin film manufacturing device comprising: a die including a plurality of pairs of heat bolts arranged along a long side of a pair of lips and heaters for heating the heat bolts, and capable of adjusting a lip gap for each of the heat bolts; a cooling roll that cools a film-like molten res...
# 191483  what is claimed is:1. a computer-implemented method of simulating orthodontic treatment, the computerimplemented method comprising:capturing a first 2d image, the first 2d image comprising a representation of a patient's face and a patient's teeth;identifying one or more shapes associated with a...
# 195797  1. a method of generating an index for assessing risk of a subject having or developing a cardiovascular disease wherein the index is selected from the group consisting of vldl-ldl atherogenicity index, hdl protection index, global lipoprotein index, and any combination thereof, the method compr...
# 199880  1. an exosome mimicking nanovesicle (emn) comprising a shell encapsulating a cargo, wherein the shell comprises a plasma membrane and wherein the emn is substantially devoid of native exosomes.2. the emn of claim 1, wherein the emn comprises a lipid raft.3. the emn of claim 1 or 2, wherein the s...
# 201811  1. a method of treating a liver disorder or lipid disorder in a subject in need thereof, the method comprising: (a) administering a first dose of 2-(3,5-dichloro-4-((5-isopropyl-6-oxo-1,6-dihydropyridazin-3-yl)oxy)phenyl)-3,5-dioxo-2,3,4,5-tetrahydro-1,2,4-triazine-6-carbonitrile ("compound a") ...
# 207539  1. a system for controlling a drying cycle in a drying apparatus comprising: a first means for sensing the concentration of a lipophilic fluid vapor present in the drying apparatus;  at least one second means for sensing a condition in the drying apparatus; and  a signal processor operatively co...
# 207966  what is claimed is:1. a computerim lemented method of generating a virtual depiction of an orthodontic treatment of a patient, the computerimplemented method comprising:gathering a three-dimensional model of the patient's dentition, the three-dimensional model comprising a virtual representation...

# %%
df_selected = pd.concat([df_selected, df[df.title == "method and composition for removing waxy soils"]])
len(df_selected)
# Out:
# 49

# %% [markdown]
# ##### 'lip( |-)?stic( |k)+'

# %%
keyword = keywords_cosmetics[13]
keyword
# Out:
# 'lip( |-)?stic( |k)+'

# %%
df_candidate = df[(df[keyword] > 0)
                 ].query("title not in @df_selected")

df_candidate[["title", "ipc_classes","abstract", "claims"]]
# Out:
#                                                                                                                                                                                                     title  \
# 4126                                                                                                                         wearable computing device featuring machine-learning-based smoking detection
# 8521                                                                                                                                            use of artificial intelligence in providing beauty advice
# 9218                                                                              system and method for augmented reality using conditional cycle-consistent generative image-to-image translation models
# 12217                                                                                                                                                                   shop-in-shop website construction
# 52213   systems and methods for virtual facial makeup removal and simulation, fast facial detection and landmark tracking, reduction in input video lag and shaking, and a method for recommending makeup
# 59157                                                                                                                                                           makeup identification using deep learning
# 61057                                                                                                                                                      method and composition for removing waxy soils
# 69896                                                                                                                             method for simulating the rendering of a make-up product on a body area
# 95446                                                                                                                                            method for providing a customized product recommendation
# 95786                                                                                                                        wearable computing device featuring machine-learning-based smoking detection
# 103842                                                                                                          method and system for image and video analysis, enhancement and display for communication
# 116454                                                                                                                                              body image templates with pre-applied beauty products
# 130055                                                                                                         composition comprising mannose oligosaccharide and process for making same and use thereof
# 132382                                                                                                                                                                shop-in-a-shop website construction
# 139942                                                                                                                                          use of artificial intelligence in providing beauty advice
# 155869                                                                                                                                           method for providing a customized product recommendation
# 158644                                                                                                                            method for simulating the rendering of a make-up product on a body area
# 163843                                                                                                                                 identification and presentation of analogous beauty case histories
# 164669    systems and methods for virtual facial makeup removal and simulation, fast facial detection and landmark tracking, reduction in input video lag and shaking, and method for recommending makeup
# 174189                                                                                                                                                          makeup identification using deep learning
# 188965                                                                                                                                                                shop-in-a-shop website construction
# 193803                                                                                                                                                apparatus and method for helping alzheimer patients
# 194374                                                                                                                                                                          advice information system
# 195416                                                                            system and method for augmented reality using conditional cycle-consistent generative image-to-image translation models
# 208936                                                                                                                         virtual facial makeup removal, fast facial detection and landmark tracking
# 209019    systems and methods for virtual facial makeup removal and simulation, fast facial detection and landmark tracking, reduction in input video lag and shaking, and method for recommending makeup
# 209315                                                                                                                                                             determining age ranges of skin samples
# 210373                                                                                                                                               simulation of an aesthetic feature on a facial image
# 210786                                                                                                                                                     smart mirror system and methods of use thereof
#
#                                                                                                                      ipc_classes  \
# 4126                                                                                              G06F3/01, G06F3/0346, G06K9/00
# 8521                            A45D44/00, A61B5/103, G06F15/00, G06F15/18, G06F17/30, G06F19/00, G06F7/00, G06Q30/06, G06T11/00
# 9218                                                                          G06F3/01, G06N20/00, G06N3/04, G06N3/08, G06T19/00
# 12217                                                                                                       G06F17/30, G06Q30/06
# 52213                                                                        A45D44/00, G06K9/00, G06T1/00, G06T17/20, G06T19/20
# 59157                                                                                    G06K9/00, G06N3/02, G06T11/00, G06T7/00
# 61057                                                               C11D11/00, C11D17/04, C11D3/18, C11D3/43, C11D7/24, C11D7/26
# 69896                                                                                                                  A45D44/00
# 95446                                                                                                       G06F17/30, G06Q30/06
# 95786                                                                                             G06F3/01, G06F3/0346, G06K9/00
# 103842                                                                                                        G06K9/00, G06K9/62
# 116454                                                                                A45D44/00, A61B5/103, G06F19/00, G06T11/00
# 130055  A23K20/163, A23K50/30, A23K50/60, A23K50/75, A23L33/00, A23L33/125, A61K31/702, A61K8/60, A61Q1/00, A61Q11/00, A61Q19/00
# 132382                                                                                                      G06F17/30, G06Q30/06
# 139942                          A45D44/00, A61B5/103, G06F15/00, G06F15/18, G06F17/30, G06F19/00, G06F7/00, G06Q30/06, G06T11/00
# 155869                                                                                                      G06F17/30, G06Q30/02
# 158644                                                                                                                 A45D44/00
# 163843                                                                                A45D44/00, A61B5/103, G06F19/00, G06T11/00
# 164669                                                            A45D44/00, G06K9/00, G06T1/00, G06T11/60, G06T17/20, G06T19/20
# 174189                                                                                   G06K9/00, G06N3/02, G06T11/00, G06T7/00
# 188965                                                                                                      G06F17/30, G06Q30/06
# 193803                     G06F3/01, G06F3/147, G06K19/07, G06K7/10, G06K9/00, G06K9/78, G09B29/10, G09B5/00, G09B5/02, G09B5/04
# 194374                                                                                                      A45D44/00, G06T19/00
# 195416                                                                                  A45D97/00, G06N20/00, G06T1/00, G06T9/00
# 208936                                                   G06T11/60, G06T15/80, G06T5/40, G06T7/40, G06T7/44, G06T7/50, G06T7/507
# 209019                                                            A45D44/00, G06K9/00, G06T1/00, G06T11/60, G06T17/20, G06T19/20
# 209315                                      A61K31/56, A61K38/16, A61K38/43, A61K8/18, A61Q17/04, C12Q1/68, C40B30/04, C40B40/06
# 210373                                                                                A45D44/00, A61B5/103, G06F19/00, G06T11/00
# 210786                                                                                   A45D44/00, A47G1/02, G06F3/01, G06T7/70
#
#                                                                                                                                                                                                                                                                                                            abstract  \
# 4126    the present disclosure provides a wearable computing device. the wearable computing device includes one or more sensors that output sensor data. the wearable computing device includes a machine-learned smoking gesture detection model trained to detect a smoking gesture based on the sensor data. ...
# 8521    the invention may involve using an artificial intelligence engine to provide beauty advice. beauty advice may include a recommendation for a product. the recommended product may be complementary to a second product. the second product may be a user-selected product. a notification of the recomme...
# 9218    systems and methods relate to a network model to apply an effect to an image such as an augmented reality effect (e.g. makeup, hair, nail, etc.). the network model uses a conditional cycle-consistent generative image-to-image translation model to translate images from a first domain space where ...
# 12217   systems, methods, and products may employ a module for use in constructing the first and second websites, such that, using the same module, the first and second websites may incorporate common information while each incorporating information unique to each website. in this way, a brand owner mig...
# 52213   the present disclosure provides systems and methods for virtual facial makeup simulation through virtual makeup removal and virtual makeup add-ons, virtual end effects and simulated textures. in one aspect, the present disclosure provides a method for virtually removing facial makeup, the method...
# 59157   makeup identification using deep learning in a digital medium environment is described. initially, a user input is received to provide a digital image depicting a face which has a desired makeup characteristic. a discriminative neural network is trained to identify and describe makeup characteri...
# 61057   the invention generally pertains to a method and composition for removing waxy soils. the invention also pertains to a method and composition for removing lip cosmetic soils such as lipsticks, chapsticks(tm), and the like. the invention further pertains to a method and composition for removing l...
# 69896   the invention proposes a method for simulating a rendering of a makeup product on a body area is disclosed comprising: - acquiring an image of the body area without makeup of a subject, - determining first color parameters of the pixels of the image corresponding to the body area without makeup,...
# 95446   included is a method for providing a customized product recommendation to a user. images of people are collected from a database. a neural network is used to evaluate the images to identify a consumer trend. information is collected from the user to determine if the user's style or desired style...
# 95786   the present disclosure provides a wearable computing device. the wearable computing device includes one or more sensors that output sensor data. the wearable computing device includes a machine-learned smoking gesture detection model trained to detect a smoking gesture based on the sensor data. ...
# 103842  there is described a system and a method for generating a metatag indicative of an attribute of a person represented in an image, the method comprising: performing a computer-based analysis of the image; identifying a feature related to the attribute of the person in the image using results from...
# 116454  disclosed methods and systems relate to enabling a beauty analysis. one of the methods involves facilitating display, on a display device, of a plurality of templates, wherein at least some of the templates are representative of a portion of a face having a simulation of use of a beauty product....
# 130055                                                    the present invention relates to a composition comprising mannose oligosaccharide and a process for making such. the present invention further relates to a composition comprising mannose oligosaccharide for use in the treatment of a human or animal.
# 132382  systems, methods, and products may employ a module for use in constructing the first and second websites, such that, using the same module, the first and second websites may incorporate common information while each incorporating information unique to each website. in this way, a brand owner mig...
# 139942  the invention may involve using an artificial intelligence engine to provide beauty advice. beauty advice may include a recommendation for a product. the recommended product may be complementary to a second product. the second product may be a user-selected product. a notification of the recomme...
# 155869  included is a method for providing a customized product recommendation to a user. images of people are collected from a database. a neural network is used to evaluate the images to identify a consumer trend. information is collected from the user to determine if the user's style or desired style...
# 158644  the inventionproposes a method for simulating a rendering of a makeup product on a body area is disclosed comprising:∘ acquiring an image of the body area without makeup of a subject,∘ determining first color parameters of the pixels of the image corresponding to the body area without makeup,∘ i...
# 163843  methods and systems are provided for assisting a subject in selecting a beauty product. in accordance with an embodiment, a method may include maintaining a plurality of sets of time-lapse body images for a plurality of individuals. in addition, an identity of at least one beauty product used by...
# 164669  the present disclosure provides systems and methods for virtual facial makeup simulation through virtual makeup removal and virtual makeup add-ons, virtual end effects and simulated textures. in one aspect, the present disclosure provides a method for virtually removing facial makeup, the method...
# 174189  makeup identification using deep learning in a digital medium environment is described. initially, a user input is received to provide a digital image depicting a face which has a desired makeup characteristic. a discriminative neural network is trained to identify and describe makeup characteri...
# 188965  systems, methods, and products may employ a module for use in constructing the first and second websites, such that, using the same module, the first and second websites may incorporate common information while each incorporating information unique to each website. in this way, a brand owner mig...
# 193803  the present disclosure relates to an apparatus and a method for helping alzheimer patients to locate their belonging by allowing the patients to attach to the belonging with a label which can be identified and located by a label identifier in a room. as a result, the patients are now able quickl...
# 194374                                                  this invention relates to the makeup advice information system which can be used for easily assessing image data and subsequent supplying information about the makeup method or makeup product suitable for a human in need of such advice or information.
# 195416  systems and methods relate to a network model to apply an effect to an image such as an augmented reality effect (e.g. makeup, hair, nail, etc.). the network model uses a conditional cycle-consistent generative image-to-image translation model to translate images from a first domain space where ...
# 208936  virtual facial makeup simulation is provided through makeup removal, makeup add-ons, end effects and simulated textures. for virtually removing facial makeup, a facial image of a user with makeups being applied thereto is provided, locating facial landmarks from facial image regions, decomposing...
# 209019  the present disclosure provides systems and methods for virtual facial makeup simulation through virtual makeup removal and virtual makeup add-ons, virtual end effects and simulated textures. in one aspect, the present disclosure provides a method for virtually removing facial makeup, the method...
# 209315  the present invention provides methods for characterizing a skin sample of a subject as belonging to an age range by analyzing nucleic acid or protein molecules obtained from the subject. the methods include analyzing expression or mutations in epidermal samples, of one or more skin markers. the...
# 210373  disclosed methods and systems enable simulated use of an aesthetic feature on a simulated facial image. one of the methods involves enabling an individual to construct a simulated facial image using a facial construction computer program, wherein the facial construction computer program permits ...
# 210786  a system comprises a frame, a mirror coupled to the frame, an electronic display device coupled to the frame, a camera coupled to the frame, one or more processors, and one or more memory devices. the one or more processors are configured to execute instructions that are stored in the one or mor...
#
#                                                                                                                                                                                                                                                                                                              claims
# 4126    1. a wearable computing device, the wearable computing device comprising: one or more sensors that output sensor data; a machine-learned smoking gesture detection model trained to detect a smoking gesture based on the sensor data; one or more processors; and one or more non-transitory computer-r...
# 8521    1. a method of providing beauty advice, the method comprising: receiving user-specific information; accessing a data structure containing information reflecting relationships between categories of user-specific information and beauty advice; comparing, using an artificial intelligence engine, th...
# 9218    what we claim is:1. a computing device to translate an image from a first domain space to a second continuous domain space according to an effect to be applied to the image, the computing device comprising: a storage unit storing a conditional cycle-consistent generative image-to-image translati...
# 12217   1. a method for facilitating modular construction of at least portions of first and second websites configured to offer for sale at least one common product, the method comprising: defining at least one module for containing a first set of information for incorporation into a first website, an a...
# 52213   1. a method for virtually removing facial makeup, comprising: providing a facial image of a user with makeup applied thereto; locating facial landmarks from the facial image of the user, the facial landmarks including at least a first region and a second region different from the first region; d...
# 59157   1. in a digital medium environment to present images received in connection with an image search that have desired makeup characteristics, a method implemented by at least one computing device, the method comprising: receiving, by the at least one computing device, an input digital image depicti...
# 61057   1. (canceled)2. (canceled)3. (canceled)4. (canceled)5. a method of removing a lip cosmetic soil from drinkware comprising:  a. providing drinkware having a lip cosmetic soil;  b. placing the drinkware in a pretreating apparatus having a pretreating composition;  c. applying a pretreating composi...
# 69896   1. a method (200) for simulating a rendering of a makeup product on a body area, the method being performed by a processor (1 1 ), and comprising :o acquiring (210) an image of the body area without makeup of a subject, o determining (230) first color parameters of the pixels of the image corres...
# 95446   1. a method for providing a customized product recommendation to a user comprising the steps of: a. collecting a plurality of images of a plurality of people from a database; b. using a neural network in evaluating the images to identify a consumer trend; c. collecting information from the user ...
# 95786   1. a wearable computing device, the wearable computing device comprising: one or more sensors that output sensor data; a machine-learned smoking gesture detection model trained to detect a smoking gesture based on the sensor data; one or more processors; and one or more non-transitory computer-r...
# 103842  1. a method for generating metatags indicative of an attribute of a person represented in an image, said method comprising: performing a computer-based analysis of the image; identifying individual facial features of the person in the image using facial feature detection analysis to determine st...
# 116454  1. a method of enabling a beauty analysis, the method comprising: facilitating display, on a display device, of a plurality of templates, wherein at least some of the templates are representative of a portion of a face having a simulation of use of a beauty product; enabling selection of at leas...
# 130055  1. a mannose oligosaccharide composition, characterized in that the composition is soluble in water.2. the composition of claim 1 characterized in that it comprises less than 0.1 wt % db of beta-glucan.3. the composition of claim 1 characterized in that a mannose oligosaccharide content that is ...
# 132382  1. a method for facilitating modular construction of at least portions of first and second websites configured to offer for sale at least one common product, the method comprising: defining at least one module for containing a first set of information for incorporation into a first website, an a...
# 139942  1. a method of providing beauty advice, the method comprising: receiving user-specific information; accessing a data structure containing information reflecting relationships between categories of user-specific information and beauty advice, the information reflecting relationships derived from ...
# 155869  1. a method for providing a customized product recommendation to a user comprising the steps of: a. collecting a plurality of images of a plurality of people from a database; b. using a neural network in evaluating the images to identify a consumer trend; c. collecting information from the user ...
# 158644  1. a method (200) for simulating a rendering of a makeup product on a body area, the method being performed by a processor (11), and comprising : ∘ acquiring (210) an image of the body area without makeup of a subject, ∘ determining (230) first color parameters of the pixels of the image corresp...
# 163843  1. a method of assisting a subject in selecting at least one beauty product, the method comprising: maintaining a plurality of sets of time-lapse body images for a plurality of individuals; associating with each of the plurality of sets of time-lapse body images an identity of at least one beaut...
# 164669  1. 1-26. (canceled)27. a method for generating an output effect on an input image having a face, comprising: (a) providing a facial image of a user with facial landmarks; (b) locating the facial landmarks from the facial image of the user, wherein the facial landmarks include a first region, and...
# 174189  1. in a digital medium environment to present images received in connection with an image search that have desired makeup characteristics, a method implemented by at least one computing device, the method comprising: receiving, by the at least one computing device, an input digital image depicti...
# 188965  1. a method for facilitating modular construction of at least portions of first and second websites configured to offer for sale at least one common product, the method comprising: defining at least one module for containing a first set of information for incorporation into a first website, an a...
# 193803  1. an apparatus for helping a person locating a belonging in a room, comprising: an input device configured for receiving an input related to the belonging from the person and turning the input into an input signal; an identifier configured for identifying the presence and location of the belong...
# 194374  1. a makeup advice system which comprises:  a) an image data reception means for receiving image data transmitted by a remote located user, e.g. via network, such as an electronic network;  b) an imaging means for visually displaying the image data;  c) an image assessing means for determining a...
# 195416  what we claim is:1. a computing device to translate an image from a first domain space to a second continuous domain space according to an effect to be applied to the image, the computing device comprising: a storage unit storing a conditional cycle -consistent generative image-to-image translat...
# 208936  we claim:1. a method for virtually removing facial makeup, comprising:providing a facial image of a user with makeup applied thereto; locating facial landmarks from the facial image of the user, the facial landmarks including at least a first region and a second region different from the first r...
# 209019  1. 1-55. (canceled)56. a method for fast facial detection and landmark tracking, comprising: capturing an input image using a two dimensional camera; creating an image pyramid using differently scaled images; applying histogram of gradient features with sliding windows and a supported vector mac...
# 209315  1. a method for determining the age range of a skin sample of a subject comprising analyzing nucleic acid from one or more genes listed in table 1, table 2, table 3, or any combination thereof, in a sample of the skin from the subject, thereby determining the age range of the skin of the subject...
# 210373  1. a method of enabling simulated use of an aesthetic feature on a simulated facial image, the method comprising: enabling an individual to construct a simulated facial image using a facial construction computer program, the facial construction computer program permitting the individual to selec...
# 210786  what is claimed is:1. a system comprising:a frame;a mirror coupled to the frame;an electronic display device coupled to the frame such that the electronic display device is positioned adjacent to at least a portion of the mirror; a camera coupled to the frame, the camera having a field of view; ...

# %% [markdown]
# ##### blush

# %%
keyword = keywords_cosmetics[14]
keyword
# Out:
# 'blush'

# %%
df_candidate = df[(df[keyword] > 0)
                 ].query("title not in @df_selected")

df_candidate[["title", "ipc_classes","abstract", "claims"]]
# Out:
#                                                                                                                                                                                                 title  \
# 8454    video surveillance data analysis algorithms, with local and network-shared communications for facial, physical condition, and intoxication recognition, fuzzy logic intelligent camera system
# 8521                                                                                                                                        use of artificial intelligence in providing beauty advice
# 10396                                                                                                                               detecting fever and intoxication from video images and a baseline
# 12217                                                                                                                                                               shop-in-shop website construction
# 23099                                                                                            method and system for managing feature reading and scoring in ultrasound and/or optoacoustice images
# 23613                                                                                                         methods and systems for characterizing tissue of a subject utilizing a machine learning
# 30061                                                                                                                                                                                       ar system
# 42075                                                                                                                                                            dogwood tree named 'appalachian joy'
# 43441                                                                                            method and system for managing feature reading and scoring in ultrasound and/or optoacoustice images
# 44388                                                                                                                                       identifying facial expressions in acquired digital images
# 46338                                                                                                                                             systems and methods for computer assisted operation
# 47920                                                                             methods and systems to determine cancer molecular subtypes based on ultrasound and/or optoacoustic (oa/us) features
# 50307                                                                                                                                       identifying facial expressions in acquired digital images
# 59112                                                                                                                                  system and method for diagnostic vector classification support
# 59157                                                                                                                                                       makeup identification using deep learning
# 66134                                                                                    computed tomography perfusion (ctp) method and apparatus using blood flow for discriminating types of cancer
# 69603                                                                                                                                                                                       ar system
# 77274                                                                                                                                                           device for obtaining perfusion images
# 81791                                                                                                                                                         systems and methods for fitting product
# 92586                                                                                                                                       identifying facial expressions in acquired digital images
# 95446                                                                                                                                        method for providing a customized product recommendation
# 98105                                                                                                                                       identifying facial expressions in acquired digital images
# 100542                                                                                                                                                          device for obtaining perfusion images
# 110753                                                                                                                                                        systems and methods for fitting product
# 116454                                                                                                                                          body image templates with pre-applied beauty products
# 118528                                                                                                                                      identifying facial expressions in acquired digital images
# 118693                                                                                                                                                        systems and methods for fitting product
# 127914                                                                                                                                 system and method for diagnostic vector classification support
# 129519                                                                                                                                                        systems and methods for fitting product
# 131816                                                                                                                                 system and method for diagnostic vector classification support
# 132382                                                                                                                                                            shop-in-a-shop website construction
# 139244                                                                                                                                      identifying facial expressions in acquired digital images
# 139942                                                                                                                                      use of artificial intelligence in providing beauty advice
# 148567                                                                           methods and systems to determine cancer molecular subtypes based on ultrasound and-or optoacoustic ( oa/us) features
# 152107                                                                                                                                 system and method for diagnostic vector classification support
# 155869                                                                                                                                       method for providing a customized product recommendation
# 161836                                                                                                                                      identifying facial expressions in acquired digital images
# 163843                                                                                                                             identification and presentation of analogous beauty case histories
# 174189                                                                                                                                                      makeup identification using deep learning
# 179856                                                                                                                                      identifying facial expressions in acquired digital images
# 183289                                                                                   computed tomography perfusion (ctp) method and apparatus using blood flow for discriminating types of cancer
# 186148                                                                                                                                 system and method for diagnostic vector classification support
# 188965                                                                                                                                                            shop-in-a-shop website construction
# 194374                                                                                                                                                                      advice information system
# 207320                                                                           methods and systems to determine cancer molecular subtypes based on ultrasound and-or optoacoustic ( oa/us) features
# 208977                                                                                                                                                        systems and methods for fitting product
# 210373                                                                                                                                           simulation of an aesthetic feature on a facial image
#
#                                                                                                                                                  ipc_classes  \
# 8454                                                                                                                                               G06F15/18
# 8521                                                        A45D44/00, A61B5/103, G06F15/00, G06F15/18, G06F17/30, G06F19/00, G06F7/00, G06Q30/06, G06T11/00
# 10396                                                                                                       A61B5/00, A61B5/01, A61B5/16, G01J5/02, G01J5/12
# 12217                                                                                                                                   G06F17/30, G06Q30/06
# 23099                                                                                                                           A61B5/00, A61B8/00, A61B8/08
# 23613                                                                                          A61B5/00, A61B5/026, A61B5/0275, G06K9/62, G06K9/66, G06T7/00
# 30061   A61B5/00, A61B5/0205, A61B5/103, A61B5/107, A61B5/11, A61B5/16, G01G19/44, G06Q30/06, G06T11/00, G06T17/00, G06T19/00, G06T19/20, G06T3/00, G06T7/20
# 42075                                                                                                                                               A01H5/00
# 43441                                                                                           A61B5/00, A61B8/00, A61B8/08, G06T7/00, G16H50/20, G16H50/30
# 44388                                                                                                               A61B1/04, G06K9/00, H04N5/228, H04N5/262
# 46338                 A61B5/00, A61B5/107, A61B5/11, G06F3/01, G06K9/00, G06K9/46, G06K9/62, G06T11/00, G06T15/00, G06T17/00, G06T19/00, G06T19/20, G06T3/00
# 47920                                                              A61B6/00, A61B6/03, A61B8/08, G06T7/00, G06T7/13, G06T7/246, G06T7/40, G06T7/62, G06T7/77
# 50307                                                                                                                                               G06K9/00
# 59112                                                                                                                                     A61B6/00, G06T7/00
# 59157                                                                                                                G06K9/00, G06N3/02, G06T11/00, G06T7/00
# 66134                                                                                                       A61B6/00, A61B6/03, G06K9/20, G06K9/62, G06T7/00
# 69603   A61B5/00, A61B5/0205, A61B5/103, A61B5/107, A61B5/11, A61B5/16, G01G19/44, G06Q30/06, G06T11/00, G06T17/00, G06T19/00, G06T19/20, G06T3/00, G06T7/20
# 77274                                                                                                                                               A61B6/00
# 81791           A43B13/04, A43B13/18, A43B17/02, A43B17/14, A43B3/00, B29C67/00, B33Y10/00, B33Y30/00, B33Y50/02, B33Y80/00, G06T15/20, G06T17/10, G06T17/20
# 92586                                                                                                                                               G06K9/00
# 95446                                                                                                                                   G06F17/30, G06Q30/06
# 98105                                                                                                                G06K9/00, G06K9/52, G06T7/40, H04N5/232
# 100542                                                                                                                                              A61B6/00
# 110753                                                                                       A43B13/04, A43B13/18, A43B17/02, A43B17/14, A43B3/00, G06T17/10
# 116454                                                                                                            A45D44/00, A61B5/103, G06F19/00, G06T11/00
# 118528                                                                                                               G06K9/00, G06K9/52, G06T7/40, H04N5/232
# 118693  A61B5/00, A61B5/0205, A61B5/103, A61B5/107, A61B5/11, A61B5/16, G01G19/44, G06Q30/06, G06T11/00, G06T17/00, G06T19/00, G06T19/20, G06T3/00, G06T7/20
# 127914                                                                                                                A61B5/00, A61B8/08, G06K9/00, G06T7/00
# 129519          A43B13/04, A43B13/18, A43B17/02, A43B17/14, A43B3/00, B29C67/00, B33Y10/00, B33Y30/00, B33Y50/02, B33Y80/00, G06T15/20, G06T17/10, G06T17/20
# 131816                                                                                                      A61B5/00, A61B8/08, G06K9/46, G06K9/62, G06T7/00
# 132382                                                                                                                                  G06F17/30, G06Q30/06
# 139244                                                                                                               G06K9/00, G06K9/52, G06T7/40, H04N5/232
# 139942                                                      A45D44/00, A61B5/103, G06F15/00, G06F15/18, G06F17/30, G06F19/00, G06F7/00, G06Q30/06, G06T11/00
# 148567                                                                                                                                              A61B8/08
# 152107                                                                                                                A61B5/00, A61B8/08, G06K9/00, G06T7/00
# 155869                                                                                                                                  G06F17/30, G06Q30/02
# 161836                                                                                                              A61B1/04, G06K9/00, H04N5/228, H04N5/262
# 163843                                                                                                            A45D44/00, A61B5/103, G06F19/00, G06T11/00
# 174189                                                                                                               G06K9/00, G06N3/02, G06T11/00, G06T7/00
# 179856                                                                                                               G06K9/00, G06K9/52, G06T7/40, H04N5/232
# 183289                                                                                                      A61B6/00, A61B6/03, G06K9/20, G06K9/62, G06T7/00
# 186148                                                                                                      A61B5/00, A61B8/08, G06K9/46, G06K9/62, G06T7/00
# 188965                                                                                                                                  G06F17/30, G06Q30/06
# 194374                                                                                                                                  A45D44/00, G06T19/00
# 207320                                                                                                                                              A61B8/08
# 208977  A61B5/00, A61B5/0205, A61B5/103, A61B5/107, A61B5/11, A61B5/16, G01G19/44, G06Q30/06, G06T11/00, G06T17/00, G06T19/00, G06T19/20, G06T3/00, G06T7/20
# 210373                                                                                                            A45D44/00, A61B5/103, G06F19/00, G06T11/00
#
#                                                                                                                                                                                                                                                                                                            abstract  \
# 8454    this invention relates to intelligent video surveillance fuzzy logic neural networks, camera systems with local and network-shared communications for facial, physical condition and intoxication recognition. the device we reveal helps reduce underage drinking by detecting and refusing entrance or...
# 8521    the invention may involve using an artificial intelligence engine to provide beauty advice. beauty advice may include a recommendation for a product. the recommended product may be complementary to a second product. the second product may be a user-selected product. a notification of the recomme...
# 10396   described herein are embodiments of systems and methods that utilize images of a user's face to detect fever and intoxication. one embodiment of a system to detect fever includes first and second inward-facing head-mounted cameras that are located less than 5 cm from a user's face, are sensitive...
# 12217   systems, methods, and products may employ a module for use in constructing the first and second websites, such that, using the same module, the first and second websites may incorporate common information while each incorporating information unique to each website. in this way, a brand owner mig...
# 23099   systems, methods and computer program products are provided for reading and scoring ultrasound and/or optoacoustic (us/oa) images that include at least one of oa images or us images acquired in connection with an examination for a region of interest (roi). the system displays a first image that ...
# 23613   methods and systems for characterizing tissue of a subject include acquiring and receiving data for a plurality of time series of fluorescence images, identifying one or more attributes of the data relevant to a clinical characterization of the tissue, and categorizing the data into clusters bas...
# 30061   systems and methods are disclosed method for rendering reality for an object by performing motion tracking and area learning of an environment; selecting a pattern or color from a plurality of product variations; blending the pattern or color of the object and the environment; and displaying the...
# 42075   a new distinct cultivar of dogwood, cornus florida l., named 'appalachian joy', is provided. this cultivar is characterized by resistance to powdery mildew, which is superior to most other cultivars of flowering dogwood and similar to 'karen's appalachian blush' (u.s. plant pat. no. 13,165 p2), ...
# 43441   systems, methods and computer program products are provided for reading and scoring ultrasound and/or optoacoustic (us/o a) images that include at least one of oa images or us images acquired in connection with an examination for a region of interest (roi). the system displays a first image that...
# 44388   a face is detected and identified within an acquired digital image. one or more features of the face is/are extracted from the digital image, including two independent eyes or subsets of features of each of the two eyes, or lips or partial lips or one or more other mouth features and one or both...
# 46338   systems and methods are disclosed method for rendering reality for an object by performing motion tracking and area learning of an environment; selecting a pattern or color from a plurality of product variations; blending the pattern or color of the object and the environment; and displaying the...
# 47920   methods, devices and systems are provided that utilize one or more processors in connection with, receiving oa/us feature scores in connection with oa/us images collected from a patient examination for a volume of interest. the methods, devices and systems apply the oa/us feature scores to a fea...
# 50307   a face is detected and identified within an acquired digital image. one or more features of the face is/are extracted from the digital image, including two independent eyes or subsets of features of each of the two eyes, or lips or partial lips or one or more other mouth features and one or both...
# 59112   the diagnostic vector classification support system and method disclosed herein may both reduce the time and effort required to train radiologists to interpret medical images, and provide a decision support system for trained radiologists who, regardless of training, have the potential to miss r...
# 59157   makeup identification using deep learning in a digital medium environment is described. initially, a user input is received to provide a digital image depicting a face which has a desired makeup characteristic. a discriminative neural network is trained to identify and describe makeup characteri...
# 66134   computed tomography perfusion (ctp) is used in a method to identify cancerous lesions having genetic mutations and treat them accordingly. also, ctp values are used to distinguish primary versus metastatic lesions. for example, pulmonary blood flow is identified as one biomarker for egfr and kra...
# 69603   systems and methods are disclosed method for rendering reality for an object by performing motion tracking and area learning of an environment; selecting a pattern or color from a plurality of product variations; blending the pattern or color of the object and the environment; and displaying the...
# 77274   a system and method for obtaining perfusion images is disclosed. the system and method includes hardware and software for determining physiological characteristics of a patient and determining imaging parameter values for an imaging modality based on the patient's physiological characteristics. ...
# 81791   systems and methods are disclosed for fitting a subject by generating one or more 3d deformable models for an anatomical portion; capturing images of a user anatomical portion and a reference object using a mobile camera; generating an updated model of the user anatomical portion by selecting a ...
# 92586   a face is detected and identified within an acquired digital image. one or more features of the face is/are extracted from the digital image, including two independent eyes or subsets of features of each of the two eyes, or lips or partial lips or one or more other mouth features and one or both...
# 95446   included is a method for providing a customized product recommendation to a user. images of people are collected from a database. a neural network is used to evaluate the images to identify a consumer trend. information is collected from the user to determine if the user's style or desired style...
# 98105   a face is detected and identified within an acquired digital image. one or more features of the face is/are extracted from the digital image, including two independent eyes or subsets of features of each of the two eyes, or lips or partial lips or one or more other mouth features and one or both...
# 100542  a system and method for obtaining perfusion images is disclosed. the system and method includes hardware and software for determining physiological characteristics of a patient and determining imaging parameter values for an imaging modality based on the patient's physiological characteristics. ...
# 110753  systems and methods are disclosed for fitting by selecting one or more 3d models from a product database; capturing images of a user view of a location and a reference frame using a mobile device with a wide view image sensor and an infrared sensor, both dedicated to 3d sensing, wherein the wide...
# 116454  disclosed methods and systems relate to enabling a beauty analysis. one of the methods involves facilitating display, on a display device, of a plurality of templates, wherein at least some of the templates are representative of a portion of a face having a simulation of use of a beauty product....
# 118528  a face is detected and identified within an acquired digital image. one or more features of the face is/are extracted from the digital image, including two independent eyes or subsets of features of each of the two eyes, or lips or partial lips or one or more other mouth features and one or both...
# 118693  systems and methods are disclosed method for rendering reality for an object by performing motion tracking and area learning of an environment; selecting a pattern or color from a plurality of product variations; blending the pattern or color of the object and the environment; and displaying the...
# 127914  the diagnostic vector classification support system and method disclosed herein may both reduce the time and effort required to train radiologists to interpret medical images, and provide a decision support system for trained radiologists who, regardless of training, have the potential to miss r...
# 129519  systems and methods are disclosed for fitting a subject by generating one or more 3d deformable models for an anatomical portion; capturing images of a user anatomical portion and a reference object using a mobile camera; generating an updated model of the user anatomical portion by selecting a ...
# 131816  the diagnostic vector classification support system and method disclosed herein may both reduce the time and effort required to train radiologists to interpret medical images, and provide a decision support system for trained radiologists who, regardless of training, have the potential to miss r...
# 132382  systems, methods, and products may employ a module for use in constructing the first and second websites, such that, using the same module, the first and second websites may incorporate common information while each incorporating information unique to each website. in this way, a brand owner mig...
# 139244  a face is detected and identified within an acquired digital image. one or more features of the face is/are extracted from the digital image, including two independent eyes or subsets of features of each of the two eyes, or lips or partial lips or one or more other mouth features and one or both...
# 139942  the invention may involve using an artificial intelligence engine to provide beauty advice. beauty advice may include a recommendation for a product. the recommended product may be complementary to a second product. the second product may be a user-selected product. a notification of the recomme...
# 148567  methods, devices and systems are provided that utilize one or more processors in connection with, receiving oa/us feature scores in connection with oa/us images collected from a patient examination for a volume of interest. the methods, devices and systems apply the oa/us feature scores to a fea...
# 152107  the diagnostic vector classification support system and method disclosed herein may both reduce the time and effort required to train radiologists to interpret medical images, and provide a decision support system for trained radiologists who, regardless of training, have the potential to miss r...
# 155869  included is a method for providing a customized product recommendation to a user. images of people are collected from a database. a neural network is used to evaluate the images to identify a consumer trend. information is collected from the user to determine if the user's style or desired style...
# 161836  a face is detected and identified within an acquired digital image. one or more features of the face is/are extracted from the digital image, including two independent eyes or subsets of features of each of the two eyes, or lips or partial lips or one or more other mouth features and one or both...
# 163843  methods and systems are provided for assisting a subject in selecting a beauty product. in accordance with an embodiment, a method may include maintaining a plurality of sets of time-lapse body images for a plurality of individuals. in addition, an identity of at least one beauty product used by...
# 174189  makeup identification using deep learning in a digital medium environment is described. initially, a user input is received to provide a digital image depicting a face which has a desired makeup characteristic. a discriminative neural network is trained to identify and describe makeup characteri...
# 179856  a face is detected and identified within an acquired digital image. one or more features of the face is/are extracted from the digital image, including two independent eyes or subsets of features of each of the two eyes, or lips or partial lips or one or more other mouth features and one or both...
# 183289  computed tomography perfusion (ctp) is used in a method to identify cancerous lesions having genetic mutations and treat them accordingly. also, ctp values are used to distinguish primary versus metastatic lesions. for example, pulmonary blood flow is identified as one biomarker for egfr and kra...
# 186148  the diagnostic vector classification support system and method disclosed herein may both reduce the time and effort required to train radiologists to interpret medical images, and provide a decision support system for trained radiologists who, regardless of training, have the potential to miss r...
# 188965  systems, methods, and products may employ a module for use in constructing the first and second websites, such that, using the same module, the first and second websites may incorporate common information while each incorporating information unique to each website. in this way, a brand owner mig...
# 194374                                                  this invention relates to the makeup advice information system which can be used for easily assessing image data and subsequent supplying information about the makeup method or makeup product suitable for a human in need of such advice or information.
# 207320  methods, devices and systems are provided that utilize one or more processors in connection with, receiving oa/us feature scores in connection with oa/us images collected from a patient examination for a volume of interest. the methods, devices and systems apply the oa/us feature scores to a fea...
# 208977  systems and methods are disclosed method for rendering reality for an object by performing motion tracking and area learning of an environment; selecting a pattern or color from a plurality of product variations; blending the pattern or color of the object and the environment; and displaying the...
# 210373  disclosed methods and systems enable simulated use of an aesthetic feature on a simulated facial image. one of the methods involves enabling an individual to construct a simulated facial image using a facial construction computer program, wherein the facial construction computer program permits ...
#
#                                                                                                                                                                                                                                                                                                              claims
# 8454    1. a fuzzy logic data analysis algorithmic system comprising: a) a local controller, hardware, software, firmware and fuzzy logic including wireless or wired communications interface for communicating with a central controller facility; b) a camera audio and video recording device connected to s...
# 8521    1. a method of providing beauty advice, the method comprising: receiving user-specific information; accessing a data structure containing information reflecting relationships between categories of user-specific information and beauty advice; comparing, using an artificial intelligence engine, th...
# 10396   we claim:1. a system configured to detect fever, comprising: first and second inward-facing head-mounted cameras (cam1&2), located less than 5 cm from a user's face, sensitive to wavelengths below 1050 nanometer, and configured to capture images of respective first and second regions on the user...
# 12217   1. a method for facilitating modular construction of at least portions of first and second websites configured to offer for sale at least one common product, the method comprising: defining at least one module for containing a first set of information for incorporation into a first website, an a...
# 23099   1. a system for managing image reading of at least one of ultrasound (us) images or optoacoustic (oa) images (us/oa images), comprising: a display; a graphical user interface (gui): memory configured to store programmable instructions; one or more processors configured to execute the programmabl...
# 23613   1. a method for characterizing tissue of a subject, the method comprising, at a computer system having one or more processors and a display: receiving data for a plurality of time series of fluorescence images of the tissue of the subject, the time series of fluorescence images being or having b...
# 30061   1. a method for rendering reality for an object, comprising: using a mobile device with an accelerometer and a camera, performing motion tracking and area learning of an environment of the object with accelerometer and camera data in the mobile device; selecting a pattern or color from a plurali...
# 42075                                                                                                                                                                                          1. a new and distinct cultivar of dogwood, cornus florida l., named 'appalachian joy', as illustrated and described.
# 43441   1. a system for analyzing at least one of ultrasound (us) images or optoacoustic (oa) images (us/oa images), comprising: a display configured to display at least a first image from at least one of oa images or us images acquired in connection with an examination for a region of interest (roi), t...
# 44388   1. a method of recognizing a facial expression or an identity of a face, or both, comprising: using a processor; acquiring a digital image; detecting and identifying a face within the digital image: separately extracting one or more features of the face within the digital image, including two in...
# 46338   1. a method for rendering reality, comprising: performing tracking and area learning of an environment by motion-tracking visual features of the environment using concurrent odometry and mapping (com) including feature points and planes to estimate a pose of the camera relative to the environmen...
# 47920   1. a method, comprising: utilizing one or more processors in connection with, receiving oa/us feature scores in connection with oa/us images collected from a patient examination for a volume of interest; applying the oa/us feature scores to a feature score to molecular subtype (fsms) model; dete...
# 50307   1. a method of initiating one or more further actions based on recognizing a facial expression and an identity of a face within a digital image, comprising: using a processor; acquiring a digital image; detecting a face within the digital image; applying a facial model to the face to identify th...
# 59112   1. a method for providing support in grading of one or more features of an optoacoustic image of a volume of tissue, wherein the volume of tissue comprises a tumor having a hypoechoic central nidus, the method comprising:obtaining an ultrasound image of the volume of tissue, the ultrasound image...
# 59157   1. in a digital medium environment to present images received in connection with an image search that have desired makeup characteristics, a method implemented by at least one computing device, the method comprising: receiving, by the at least one computing device, an input digital image depicti...
# 66134   1. a method of using computed tomography perfusion to determine a treatment of a pulmonary lesion, the method comprising: obtaining a computed tomography perfusion (ctp) image representing blood flow in a region of a lung that includes the pulmonary lesion; identifying, using the ctp image, a re...
# 69603   1. a method for rendering reality for an object, comprising: performing motion tracking and area learning of an environment; selecting a pattern or color from a plurality of product variations; blending the pattern or color of the object and the environment; and displaying the color on the objec...
# 77274   1. a system for obtaining perfusion images comprising: a first processor operative to determine a physiological characteristic of a patient; a second processor operative to receive the determined physiological characteristic of the patient, and further operative to determine an imaging parameter...
# 81791   1. a method for fitting a subject, comprising: pre-generating one or more 3d models for an anatomical portion; capturing images of a user anatomical portion using a mobile camera; performing dimension determination with motion tracking, area learning and depth sensing of the anatomical portion; ...
# 92586   1. a method of recognizing a facial expression or an identity of a face, or both, comprising: using a processor; acquiring a digital image; detecting and identifying a face within the digital image; separately extracting one or more features of the face within the digital image, including two in...
# 95446   1. a method for providing a customized product recommendation to a user comprising the steps of: a. collecting a plurality of images of a plurality of people from a database; b. using a neural network in evaluating the images to identify a consumer trend; c. collecting information from the user ...
# 98105   1. a method for mirroring a user facial expression in a three-dimensional (3d) in-game avatar in real-time, the method comprising: generating a 3d in-game avatar and displaying the 3d in-game avatar within a game display of a game; capturing an image of a user as the user participates in the gam...
# 100542  1. a system for obtaining perfusion images, the system comprising: a first processor configured to determine a physiological characteristic of a patient; a second processor configured to receive the determined physiological characteristic of the patient, and further configured to determine an im...
# 110753  1. a method, comprising: capturing images of an object relative to a reference frame using a mobile camera with a wide-angle lens and an infrared sensor; generating in advance of image capturing, one or more 3d models for the object; generating an updated model of the object by selecting a close...
# 116454  1. a method of enabling a beauty analysis, the method comprising: facilitating display, on a display device, of a plurality of templates, wherein at least some of the templates are representative of a portion of a face having a simulation of use of a beauty product; enabling selection of at leas...
# 118528  1. a method for mirroring a user facial expression in a three-dimensional (3d) in-game avatar in real-time, the method comprising: generating a 3d in-game avatar and displaying the 3d in-game avatar within a game display of a game by performing: capturing an image of a user as the user participa...
# 118693  1. a method for rendering reality for an object, comprising: using a mobile device with an accelerometer and a camera, performing motion tracking and learning in an environment of the object with accelerometer and camera data in the mobile device; selecting a pattern or color from a plurality of...
# 127914  1. a method for providing support in grading of one or more features of an optoacoustic image of a volume of tissue, wherein the volume of tissue comprises a tumor having a hypoechoic central nidus, the method comprising: obtaining an ultrasound image of the volume of tissue, the ultrasound imag...
# 129519  1. a method for fitting a subject, comprising: selecting one or more pre-generated 3d models for an anatomical portion; capturing images of a user anatomical portion and a reference frame using a mobile camera; generating an updated model of the user anatomical portion by selecting a closest pre...
# 131816  1. a method for providing support in classifying a lesion using an optoacoustic image of a volume of tissue, wherein the volume of tissue comprises a tumor having a central nidus, the method comprising: obtaining an ultrasound image of the volume of tissue, the ultrasound image presenting at lea...
# 132382  1. a method for facilitating modular construction of at least portions of first and second websites configured to offer for sale at least one common product, the method comprising: defining at least one module for containing a first set of information for incorporation into a first website, an a...
# 139244  1. a method for mirroring a user facial expression in an in-game avatar within a game display during a game, the method comprising: capturing a user facial expression in a digital image of a user's face as the user participates in the game; based on content of the image, determining the user fac...
# 139942  1. a method of providing beauty advice, the method comprising: receiving user-specific information; accessing a data structure containing information reflecting relationships between categories of user-specific information and beauty advice, the information reflecting relationships derived from ...
# 148567  in the claims:1 a method, comprising: utilizing one or more processors in connection with, receiving oa/us feature scores in connection with oa/us images collected from a patient examination for a volume of interest; applying the oa/us feature scores to a feature score to molecular subtype (fsms...
# 152107  1. a method for providing support in grading of one or more features of an optoacoustic image of a volume of tissue, wherein the volume of tissue comprises a tumor having a hypoechoic central nidus, the method comprising: obtaining an ultrasound image of the volume of tissue, the ultrasound imag...
# 155869  1. a method for providing a customized product recommendation to a user comprising the steps of: a. collecting a plurality of images of a plurality of people from a database; b. using a neural network in evaluating the images to identify a consumer trend; c. collecting information from the user ...
# 161836  1. a method of recognizing a facial expression, comprising: using a processor; acquiring a sequence of digital images; detecting a facial region within a first digital image; applying a facial model, comprising both shape and texture components, to said facial region to obtain a first detailed m...
# 163843  1. a method of assisting a subject in selecting at least one beauty product, the method comprising: maintaining a plurality of sets of time-lapse body images for a plurality of individuals; associating with each of the plurality of sets of time-lapse body images an identity of at least one beaut...
# 174189  1. in a digital medium environment to present images received in connection with an image search that have desired makeup characteristics, a method implemented by at least one computing device, the method comprising: receiving, by the at least one computing device, an input digital image depicti...
# 179856  1. a method for mirroring a user facial expression in a three-dimensional (3d) in-game avatar in real-time, the method comprising: generating a 3d in-game avatar and displaying the 3d in-game avatar within a game display of a game; capturing an image of a user as the user participates in the gam...
# 183289  1. a method of using computed tomography perfusion to determine a treatment of a pulmonary lesion, the method comprising: obtaining a computed tomography perfusion (ctp) image representing blood flow in a region of a lung that includes the pulmonary lesion; identifying, using the ctp image, a re...
# 186148  1. 1-41. (canceled)42. a method for evaluating a tumor having a central nidus and a peritumoral region adjacent to the central nidus, the method comprising: presenting on a display an optoacoustic image of at least a portion of a volume of tissue comprising the tumor; identifying on the display ...
# 188965  1. a method for facilitating modular construction of at least portions of first and second websites configured to offer for sale at least one common product, the method comprising: defining at least one module for containing a first set of information for incorporation into a first website, an a...
# 194374  1. a makeup advice system which comprises:  a) an image data reception means for receiving image data transmitted by a remote located user, e.g. via network, such as an electronic network;  b) an imaging means for visually displaying the image data;  c) an image assessing means for determining a...
# 207320  in the claims:1 a method, comprising: utilizing one or more processors in connection with, receiving oa/us feature scores in connection with oa/us images collected from a patient examination for a volume of interest; applying the oa/us feature scores to a feature score to molecular subtype (fsms...
# 208977  1. a method for rendering reality for an object, comprising: performing motion tracking and area learning of an environment; selecting a pattern or color from a plurality of product variations; blending the pattern or color of the object and the environment; and displaying the color on the objec...
# 210373  1. a method of enabling simulated use of an aesthetic feature on a simulated facial image, the method comprising: enabling an individual to construct a simulated facial image using a facial construction computer program, the facial construction computer program permitting the individual to selec...

# %% [markdown]
# ##### mascara

# %%
keyword = keywords_cosmetics[15]
keyword
# Out:
# 'mascara'

# %%
df_candidate = df[(df[keyword] > 0)
                 ].query("title not in @df_selected")

df_candidate[["title", "ipc_classes","abstract", "claims"]]
# Out:
#                                                                                                            title  \
# 8521                                                   use of artificial intelligence in providing beauty advice
# 8936                                  automated imaging system for evaluating the curl of a keratinous substrate
# 12217                                                                          shop-in-shop website construction
# 95446                                                   method for providing a customized product recommendation
# 116454                                                     body image templates with pre-applied beauty products
# 132382                                                                       shop-in-a-shop website construction
# 139942                                                 use of artificial intelligence in providing beauty advice
# 155869                                                  method for providing a customized product recommendation
# 163843                                        identification and presentation of analogous beauty case histories
# 186100  automatic method and system for analysing mammography images and method for deep neural network training
# 188965                                                                       shop-in-a-shop website construction
# 194374                                                                                 advice information system
# 210373                                                      simulation of an aesthetic feature on a facial image
#
#                                                                                              ipc_classes  \
# 8521    A45D44/00, A61B5/103, G06F15/00, G06F15/18, G06F17/30, G06F19/00, G06F7/00, G06Q30/06, G06T11/00
# 8936                                                              G06T7/11, G06T7/50, G06T7/73, G06T7/90
# 12217                                                                               G06F17/30, G06Q30/06
# 95446                                                                               G06F17/30, G06Q30/06
# 116454                                                        A45D44/00, A61B5/103, G06F19/00, G06T11/00
# 132382                                                                              G06F17/30, G06Q30/06
# 139942  A45D44/00, A61B5/103, G06F15/00, G06F15/18, G06F17/30, G06F19/00, G06F7/00, G06Q30/06, G06T11/00
# 155869                                                                              G06F17/30, G06Q30/02
# 163843                                                        A45D44/00, A61B5/103, G06F19/00, G06T11/00
# 186100                                                                     G06K9/62, G06T11/00, G06T7/00
# 188965                                                                              G06F17/30, G06Q30/06
# 194374                                                                              A45D44/00, G06T19/00
# 210373                                                        A45D44/00, A61B5/103, G06F19/00, G06T11/00
#
#                                                                                                                                                                                                                                                                                                            abstract  \
# 8521    the invention may involve using an artificial intelligence engine to provide beauty advice. beauty advice may include a recommendation for a product. the recommended product may be complementary to a second product. the second product may be a user-selected product. a notification of the recomme...
# 8936    a system is provided for evaluating a curl of at least one eyelash sample that includes a plurality of fibers, comprising: a platform configured to receive a sample of the eyelash sample; an image capturing device configured to capture profile image of the eyelash ample; and a processing system ...
# 12217   systems, methods, and products may employ a module for use in constructing the first and second websites, such that, using the same module, the first and second websites may incorporate common information while each incorporating information unique to each website. in this way, a brand owner mig...
# 95446   included is a method for providing a customized product recommendation to a user. images of people are collected from a database. a neural network is used to evaluate the images to identify a consumer trend. information is collected from the user to determine if the user's style or desired style...
# 116454  disclosed methods and systems relate to enabling a beauty analysis. one of the methods involves facilitating display, on a display device, of a plurality of templates, wherein at least some of the templates are representative of a portion of a face having a simulation of use of a beauty product....
# 132382  systems, methods, and products may employ a module for use in constructing the first and second websites, such that, using the same module, the first and second websites may incorporate common information while each incorporating information unique to each website. in this way, a brand owner mig...
# 139942  the invention may involve using an artificial intelligence engine to provide beauty advice. beauty advice may include a recommendation for a product. the recommended product may be complementary to a second product. the second product may be a user-selected product. a notification of the recomme...
# 155869  included is a method for providing a customized product recommendation to a user. images of people are collected from a database. a neural network is used to evaluate the images to identify a consumer trend. information is collected from the user to determine if the user's style or desired style...
# 163843  methods and systems are provided for assisting a subject in selecting a beauty product. in accordance with an embodiment, a method may include maintaining a plurality of sets of time-lapse body images for a plurality of individuals. in addition, an identity of at least one beauty product used by...
# 186100  the present invention describes a system and method for analysing mammography images. specifically, the present invention comprises a device for classifying the quality of the position of the breast in the mammography image and a device for classifying the breast density in the mammography image...
# 188965  systems, methods, and products may employ a module for use in constructing the first and second websites, such that, using the same module, the first and second websites may incorporate common information while each incorporating information unique to each website. in this way, a brand owner mig...
# 194374                                                  this invention relates to the makeup advice information system which can be used for easily assessing image data and subsequent supplying information about the makeup method or makeup product suitable for a human in need of such advice or information.
# 210373  disclosed methods and systems enable simulated use of an aesthetic feature on a simulated facial image. one of the methods involves enabling an individual to construct a simulated facial image using a facial construction computer program, wherein the facial construction computer program permits ...
#
#                                                                                                                                                                                                                                                                                                              claims
# 8521    1. a method of providing beauty advice, the method comprising: receiving user-specific information; accessing a data structure containing information reflecting relationships between categories of user-specific information and beauty advice; comparing, using an artificial intelligence engine, th...
# 8936    1. a system for evaluating a curl of at least one eyelash sample that includes a plurality of fibers, comprising: a platform configured to receive a sample of the eyelash sample; an image capturing device configured to capture profile image of the eyelash sample; and a processing system configur...
# 12217   1. a method for facilitating modular construction of at least portions of first and second websites configured to offer for sale at least one common product, the method comprising: defining at least one module for containing a first set of information for incorporation into a first website, an a...
# 95446   1. a method for providing a customized product recommendation to a user comprising the steps of: a. collecting a plurality of images of a plurality of people from a database; b. using a neural network in evaluating the images to identify a consumer trend; c. collecting information from the user ...
# 116454  1. a method of enabling a beauty analysis, the method comprising: facilitating display, on a display device, of a plurality of templates, wherein at least some of the templates are representative of a portion of a face having a simulation of use of a beauty product; enabling selection of at leas...
# 132382  1. a method for facilitating modular construction of at least portions of first and second websites configured to offer for sale at least one common product, the method comprising: defining at least one module for containing a first set of information for incorporation into a first website, an a...
# 139942  1. a method of providing beauty advice, the method comprising: receiving user-specific information; accessing a data structure containing information reflecting relationships between categories of user-specific information and beauty advice, the information reflecting relationships derived from ...
# 155869  1. a method for providing a customized product recommendation to a user comprising the steps of: a. collecting a plurality of images of a plurality of people from a database; b. using a neural network in evaluating the images to identify a consumer trend; c. collecting information from the user ...
# 163843  1. a method of assisting a subject in selecting at least one beauty product, the method comprising: maintaining a plurality of sets of time-lapse body images for a plurality of individuals; associating with each of the plurality of sets of time-lapse body images an identity of at least one beaut...
# 186100  reivindicações1. método automático de análise de imagem de mamografia, implementado em ao menos um sistema de aprendizado profundo previamente treinado, caracterizado por compreender as etapas de:a. predição de qualidade de posicionamento de mama (1 ) na imagem de mamografia; eb. predição de den...
# 188965  1. a method for facilitating modular construction of at least portions of first and second websites configured to offer for sale at least one common product, the method comprising: defining at least one module for containing a first set of information for incorporation into a first website, an a...
# 194374  1. a makeup advice system which comprises:  a) an image data reception means for receiving image data transmitted by a remote located user, e.g. via network, such as an electronic network;  b) an imaging means for visually displaying the image data;  c) an image assessing means for determining a...
# 210373  1. a method of enabling simulated use of an aesthetic feature on a simulated facial image, the method comprising: enabling an individual to construct a simulated facial image using a facial construction computer program, the facial construction computer program permitting the individual to selec...

# %% [markdown]
# ##### make(s| |-)*up

# %%
keyword = keywords_cosmetics[16]
keyword
# Out:
# 'make(s| |-)*up'

# %%
df_candidate = df[(df[keyword] > 0)
                  & (df.ipc_classes.str.count("G06")==0)
                  & (df.ipc_classes.str.count("A01")==0)
                 ].query("title not in @df_selected")

df_candidate[["filename", "title", "ipc_classes","abstract", "claims"]]
# Out:
#                    filename  \
# 1206      US10640392_B2.txt
# 3013       EP3489491_B1.txt
# 3240      US10849406_B2.txt
# 6611    US2020047336_A1.txt
# 14769   US2013226019_A1.txt
# 14858   WO2020209725_A1.txt
# 20815   US2018092574_A1.txt
# 23650   WO2020041688_A1.txt
# 24033   US2021011026_A1.txt
# 24953   WO2019050994_A1.txt
# 25284     US10323502_B2.txt
# 27982   US2019034585_A1.txt
# 32479      WO0177846_A1.txt
# 40462   US2020143005_A1.txt
# 44304     US10648900_B2.txt
# 45960   WO2020185987_A1.txt
# 48341   WO2020227216_A1.txt
# 48469      WO0205529_A1.txt
# 48728      EP3336425_A1.txt
# 48867      EP3499802_A1.txt
# 51975      EP1243807_A2.txt
# 69529   US2020411135_A1.txt
# 69896   WO2020064676_A1.txt
# 72857   WO2019104203_A1.txt
# 77362   US2019279742_A1.txt
# 82047      EP1594008_A2.txt
# 85479      US7305367_B1.txt
# 85563   WO2020251688_A1.txt
# 89870   WO2010045475_A1.txt
# 93414   US2014163409_A1.txt
# 98845   US2020363215_A1.txt
# 100983  US2019050524_A1.txt
# 102606     EP3608501_A1.txt
# 109248  WO2012025815_A1.txt
# 115926  WO2018112351_A1.txt
# 116088     EP3709638_A1.txt
# 120740  US2016053605_A1.txt
# 130055  US2020297019_A1.txt
# 131315  WO2020182991_A1.txt
# 132274    US10897269_B2.txt
# 133578     US7519529_B1.txt
# 135330  US2019119996_A1.txt
# 137808  WO2020182996_A1.txt
# 147253  WO2020202008_A1.txt
# 147996  US2003006770_A1.txt
# 156281  WO2020210690_A1.txt
# 158360     EP3473799_A1.txt
# 158644     EP3628187_A1.txt
# 158680     EP3499802_B1.txt
# 158859     US8992435_B2.txt
# 161173    US10010830_B2.txt
# 164621  US2016051929_A1.txt
# 165727  US2017184486_A1.txt
# 167123  WO2010025356_A2.txt
# 168685  US2017120190_A1.txt
# 169966  WO2020245798_A1.txt
# 172059  US2020224524_A1.txt
# 183942     EP1243807_A3.txt
# 184735    US10695716_B2.txt
# 184897    US10076270_B2.txt
# 186491  US2019178925_A1.txt
# 186505  WO2020131996_A1.txt
# 190133     US6819746_B1.txt
# 192962  US2019065675_A1.txt
# 196933  US2019081638_A1.txt
# 198989  US2020327878_A1.txt
# 199244  WO2015168705_A1.txt
# 199637    US10901403_B2.txt
# 200018  WO2020205778_A1.txt
# 201701    US10847252_B2.txt
# 203511  US2018282180_A1.txt
# 204069     US8131543_B1.txt
# 208357     EP3709637_A1.txt
# 210442  WO2019075112_A1.txt
#
#                                                                                                                                                                                                    title  \
# 1206                                                         water quality management device, water treatment system, water quality management method, and program for optimizing water treatment system
# 3013                                                                                                                                        method and system for controlling the products of combustion
# 3240                                                                                                   system for dispensing at least one makeup product and method for dispensing and evaluating makeup
# 6611                                                                                                                                                     connection analyzed make-up systems and methods
# 14769                                                                                                                                                    system and method for classifying a heart sound
# 14858                                                                                                                                                                       drilling systems and methods
# 20815                                                                                                                           detecting physiological responses while accounting for touching the face
# 23650                                                                                                                                                        visual representations of peptide sequences
# 24033                                                                                                                                             reducing junction epitope presentation for neoantigens
# 24953                                                                                                                                                       neoantigen identification for t-cell therapy
# 25284                                                                                                                  system and console for monitoring and managing tripping operations at a well site
# 27982                                                                                                                                                    neoantigen identification, manufacture, and use
# 32479                                                                                                                                                             expert system for play list generation
# 40462                                                                                                                                      resolving opaqueness of complex machine learning applications
# 44304                                                                                                                              multi-color flow cytometric analysis of samples with low cell numbers
# 45960                                                               systems and methods for importing and analyzing medical, wellness, and/or training data and generating interactive computer displays
# 48341                                                                                                                             dual function domestic hot water preheater and integrated space heater
# 48469                                                                                                                                              expert system for loop qualification of xdsl services
# 48728                                                          water quality management device, water treatment system, water quality management method, and water treatment system optimization program
# 48867                                                                                                                                                                            cable network modelling
# 51975                                                                                                                                                      brake wear detection device for trailer units
# 69529                                                                                                                                                   neoantigen identification with pan-allele models
# 69896                                                                                                                            method for simulating the rendering of a make-up product on a body area
# 72857                                                                                                                                             reducing junction epitope presentation for neoantigens
# 77362                                                                                                                                                           neoantigen identification using hotspots
# 82047                                                                                                                           method and apparatus for submicron ic design using edge fragment tagging
# 85479                                                                                                                                 instantaneous price quotation system for custom manufactured parts
# 85563                                                                                                                                                   selectively enhancing compressed digital content
# 89870                                                                                                                   techniques for predicting hiv viral tropism and classifying amino acid sequences
# 93414                                                                                                       system and method for knowledge verification utilizing biopotentials and physiologic metrics
# 98845                                                                                                                                        map updates based on data captured by an autonomous vehicle
# 100983                                                                                                                 enhanced applications of molecular libraries based on structure/function analysis
# 102606                                                                                                                                                   connection analyzed make-up systems and methods
# 109248                                                                                                                                                 a system and method for classifying a heart sound
# 115926                                                                                                                                             wearable pulse waveform measurement system and method
# 116088                                                                                                           systems, devices, and methods for projecting digital content onto user's facial surface
# 120740                                                                                                                 system and console for monitoring and managing tripping operations at a well site
# 130055                                                                                                        composition comprising mannose oligosaccharide and process for making same and use thereof
# 131315                                                                                                                       system and method for projecting digital content onto user's facial surface
# 132274                                                                                                                                                              hierarchical point cloud compression
# 133578  system and methods for inferring informational goals and preferred level of detail of results in response to questions posed to an automated information-retrieval or question-answering service
# 135330                                                                                                                                                           tool joint finding apparatus and method
# 137808                                                                       systems, devices, and methods for projecting digital content including hair color changes onto a user's head, face, or body
# 147253                                                                                                          devices and methods to improve background equivalent concentrations of elemental species
# 147996                                                                                                                               quantitation and standardization of magnetic resonance measurements
# 156281                                                                                                                              method, apparatus, and system for fire suppression using sound waves
# 158360                                                                                                                                                           tool joint finding apparatus and method
# 158644                                                                                                                           method for simulating the rendering of a make-up product on a body area
# 158680                                                                                                                                                                           cable network modelling
# 158859                                                                                                                                                   system and method for classifying a heart sound
# 161173                                                                                                                                                                biofilter with fuzzy logic control
# 164621                                                                                                                 addition of alkaline materials to biotrickling filter or bio-filter make-up water
# 165727                                                                                                                             multi-color flow cytometric analysis of samples with low cell numbers
# 167123                                                                                                                               system and methods for reducing perceptual device optimization time
# 168685                                                                                                                                                                biofilter with fuzzy logic control
# 169966                                      control and/or identification method in an automatic machine for the production or the packaging of consumer products, in particular of the tobacco industry
# 172059                                                                                                                                                            utilizing vision systems at a wellsite
# 183942                                                                                                                                                     brake wear detection device for trailer units
# 184735                                                                                                                 addition of alkaline materials to biotrickling filter or bio-filter make-up water
# 184897                                                                                                                          detecting physiological responses while accounting for touching the face
# 186491                                                                                                                                                                           cable network modelling
# 186505                                                                                                   determining reservoir fluid properties from downhole fluid analysis data using machine learning
# 190133                                                                                                                                             expert system for loop qualification of xdsl services
# 192962                                                                                                                                                   neoantigen identification, manufacture, and use
# 196933                                                                                                                                                              hierarchical point cloud compression
# 198989                                                                                                                             method, apparatus, and systems for fire suppression using sound waves
# 199244                                                                                                                 system and console for monitoring and managing tripping operations at a well site
# 199637                                                                                                                                  developing linear process models using reactor kinetic equations
# 200018                                                                                                                       compositions and methods for preparing t cell compositions and uses thereof
# 201701                                                                                                                                                   neoantigen identification, manufacture, and use
# 203511                                                       water quality management device, water treatment system, water quality management method, and program for optimizing water treatment system
# 204069                                                                                                                                                                                  speech detection
# 208357                                                                       systems, devices, and methods for projecting digital content including hair color changes onto a user's head, face, or body
# 210442                                                                                                                                                          neoantigen identification using hotspots
#
#                                                                                                                      ipc_classes  \
# 1206                              C02F1/00, C02F1/66, C02F1/68, C02F103/02, C02F5/08, F22D11/00, F22D11/02, F28G13/00, G05B13/02
# 3013                                                                                     F02C7/057, F02C9/00, F02G3/00, F23R3/26
# 3240                                                   A45D40/00, A45D40/26, A45D44/00, B01F13/10, B01F15/02, B01F5/06, G01J3/46
# 6611                                                                                               B25J9/16, G01L5/00, G01N19/08
# 14769                                                                       A61B5/00, A61B5/02, A61B5/0452, A61B5/0456, A61B7/04
# 14858                                                                                                                  E21B44/00
# 20815                                                     A61B5/00, A61B5/01, A61B5/11, A61B5/16, G01J5/00, G02B27/01, H04N5/225
# 23650                                                                                                                  G16B15/20
# 24033                                                                     C40B30/04, G01N33/574, G01N33/68, G16B30/00, G16B40/00
# 24953                                                                                  A61K35/17, A61K39/00, C12Q1/68, G01N33/68
# 25284                                                                      E21B19/00, E21B44/00, E21B45/00, E21B47/00, G05B15/02
# 27982                                                                                                                  A61K39/00
# 32479                                                                                                       G10K15/02, G10K15/04
# 40462
# 44304                                                                                            G01N15/00, G01N15/10, G01N15/14
# 45960                                                                                                                  G16H10/60
# 48341                                                                                               F24D3/08, F24H1/48, F24H1/50
# 48469                                                                                                         H04M3/22, H04M3/30
# 48728                                        C02F1/00, C02F1/66, C02F103/02, C02F5/00, C02F5/08, F22D11/00, F28G13/00, G05B13/02
# 48867                                                                                                       H04L12/24, H04L12/26
# 51975                                                                                                                  F16D66/02
# 69529                                                                                            G16B20/20, G16B30/20, G16B40/00
# 69896                                                                                                                  A45D44/00
# 72857                                                                                C40B30/04, C40B40/10, G01N33/574, G01N33/68
# 77362                                                                                                                  G16B40/00
# 82047                                                                                               G03F1/00, G03F1/36, G03F7/20
# 85479
# 85563                                                                                                     H04N19/117, H04N19/167
# 89870                                                                                                                  G01N33/48
# 93414                                                                       A61B5/00, A61B5/04, A61B5/0478, A61B5/0484, A61B5/16
# 98845                                                                                   G01C21/32, G01S17/89, G05D1/00, G05D1/02
# 100983                                                                                                                 C40B30/04
# 102606                                                                                                                 E21B19/16
# 109248                                                                                                        A61B5/02, A61B7/00
# 115926                                                                                            A61B5/00, A61B5/021, A61B5/024
# 116088                                                                                                                  H04N9/31
# 120740                                                                     E21B19/00, E21B44/00, E21B45/00, E21B47/00, G05B15/02
# 130055  A23K20/163, A23K50/30, A23K50/60, A23K50/75, A23L33/00, A23L33/125, A61K31/702, A61K8/60, A61Q1/00, A61Q11/00, A61Q19/00
# 131315                                                                                                                  H04N9/31
# 132274                                                                    H03M7/30, H04N19/436, H04N19/597, H04N19/60, H04N19/96
# 133578                                                                                                                 G10L15/00
# 135330                                                                                                      E21B19/16, E21B47/12
# 137808                                                                                                                  H04N9/31
# 147253                                                                                  G01N1/00, G01N21/71, H01J49/04, H05H1/26
# 147996                                                                        F23C6/04, F23C7/06, F23C9/00, G01R33/56, G01R33/58
# 156281                                                                                                       A62C2/00, A62C37/36
# 158360                                                                                                                 E21B19/16
# 158644                                                                                                                 A45D44/00
# 158680                                                                                                      H04L12/24, H04L12/26
# 158859                                                                      A61B5/00, A61B5/02, A61B5/0452, A61B5/0456, A61B7/04
# 161173                                              B01D53/34, B01D53/52, B01D53/84, C02F101/10, C02F103/00, C02F3/34, G05B15/02
# 164621                                                B01D53/34, B01D53/52, B01D53/84, B01D53/85, C02F101/10, C02F3/04, C02F3/34
# 165727                                                                                           G01N15/00, G01N15/10, G01N15/14
# 167123                                                                                                       A61B5/12, H04R25/00
# 168685                                              B01D53/34, B01D53/52, B01D53/84, C02F101/10, C02F103/00, C02F3/34, G05B15/02
# 169966                                                                                                                G05B19/418
# 172059                                                                        E21B41/00, E21B44/00, G08B3/10, G08B5/22, H04N7/18
# 183942                                                                                                                 F16D66/02
# 184735                                                B01D53/34, B01D53/52, B01D53/84, B01D53/85, C02F101/10, C02F3/04, C02F3/34
# 184897                                                    A61B5/00, A61B5/01, A61B5/11, A61B5/16, G01J5/00, G02B27/01, H04N5/225
# 186491                                                                                           G01R27/16, G01R27/26, G01R31/02
# 186505                                                            E21B41/00, E21B47/06, E21B49/08, E21B49/10, G01J3/02, G01V8/10
# 190133                                                                                                        H04M3/22, H04M3/30
# 192962                                                                                           A61K35/15, A61K39/00, G16B30/00
# 196933                                                                    H03M7/30, H04N19/436, H04N19/597, H04N19/60, H04N19/96
# 198989                                                                                  A62C3/02, A62C3/08, A62C99/00, G10K11/28
# 199244                                                                                                                 E21B44/00
# 199637                                                                               G05B13/00, G05B19/418, G05B23/00, G05B23/02
# 200018                                                                                           A61K39/00, C07K14/705, C12N5/00
# 201701                                                                                           A61K35/15, A61K39/00, G16B30/00
# 203511                            C02F1/00, C02F1/66, C02F1/68, C02F103/02, C02F5/08, F22D11/00, F22D11/02, F28G13/00, G05B13/02
# 204069                                                                                                                 G10L15/00
# 208357                                                                                                                  H04N9/31
# 210442                                                                                A61K35/13, C12Q1/68, G01N33/50, G01N33/574
#
#                                                                                                                                                                                                                                                                                                            abstract  \
# 1206    a water quality management device is provided with a water quality index value acquisition unit which acquires water quality index values including a makeup water quality index value indicating water quality of makeup water and a circulating water quality index value indicating water quality of ...
# 3013    the present invention relates to methods and systems for controlling a combustion reaction and the products thereof and includes a combustion control system having an oxygen supply stream (104) and a high concentration carbon dioxide stream (102), mixing the streams to form an oxygenation stream...
# 3240    a system for dispensing at least one makeup product, including a cup and a dispenser for filling the cup from the bottom with at least one product, the cup being secured to the dispenser at least while it is being filled with said product. the method for dispensing and evaluating makeup, includi...
# 6611    a method including acquiring measurements representing torque applied to a connection between a first tubular and a second tubular, a rotational position of the first tubular relative to the second tubular, or both, obtaining a plurality of make-up parameters representing conditions under which ...
# 14769   a method and system for electronically classifying a pre-processed heart sound signal of a patient as functional (normal) or pathological is provided. the pre-processed patient heart sound signal is segmentised and features are extracted therefrom (104) to build up a feature vector which is repr...
# 14858   a drilling plant management system (60) comprising a database (61) comprising information of a plurality of equipment items on a drilling rig (10,80) and in a well (86), the information comprising an identification and a location of each of the plurality of equipment items, a controller to recei...
# 20815   described herein are systems and methods for detecting a physiological response based on thermal measurements while accounting for touching the face. in one embodiment, a system includes an inward-facing head-mounted thermal camera (cam) that takes thermal measurements of a region of interest (t...
# 23650   a system for visually representing peptide sequences includes a memory configured to store instructions and a processor to execute the instructions to perform operations. the operations include receiving data representing a peptide sequence. the data includes an index representing a position for...
# 24033   given a set of therapeutic epitopes, a cassette sequence is designed to reduce the likelihood that junction epitopes are presented in the patient. the cassette sequence is designed by taking into account presentation of junction epitopes that span the junction between a pair of therapeutic epito...
# 24953   a method for identifying t-cells that are antigen-specific for at least one neoantigen that is likely to be presented on surfaces of tumor cells of a subject. peptide sequences of tumor neoantigens are obtained by sequencing the tumor cells of the subject. the peptide sequences are input into a ...
# 25284   a well advisor system and console for monitoring and managing tubular tripping operations at a well site. the system may be accessed through one or more workstations, or other computing devices, which may be located at a well site or remotely. the system is in communication with and receives inp...
# 27982   disclosed herein is a system and methods for determining the alleles, neoantigens, and vaccine composition as determined on the basis of an individual's tumor mutations. also disclosed are systems and methods for obtaining high quality sequencing data from a tumor. further, described herein are ...
# 32479   an expert system for delivering audio visual pieces selected from a large library of pieces to customers for playing to audiences and selecting which piece to play when. each customer establishment is divided into zones and each zone is divided into day parts. characteristics of the target audie...
# 40462   computing systems and technical methods that transform data structures and pierce opacity difficulties associated with complex machine learning modules are disclosed. advances include a framework and techniques that include: i) global diagnostics; ii) locally interpretable models lime-sup-r and ...
# 44304   aspects of the present disclosure include methods for processing a biological sample. methods according to certain embodiments include contacting a biological sample having cells with an assay reagent that includes one or more analyte-specific binding members to produce a biological sample assay...
# 45960   the present disclosure relates to systems and methods for importing medical, wellness, and/or training/performance data for a subject. natural language processing (nlp) may be implemented on the imported records to identify and extract keywords. a machine learning (ml) system determine informati...
# 48341                                                                                                         embodiments described herein generally relate to a domestic hot water (dhw) preheater operable to supply domestic hot water to a structure and/or to preheat a cold return of a space heating system.
# 48469   a technique for qualification of loops for new digital subscriber line services (dsl) involves use of an expert system (17), such as a neural network. a database of loop characteristic information (11) and performance data (13) enables the expert system (17) to train or learn how to predict perf...
# 48728   the present invention comprises: a water quality index value acquisition unit (1101a) that acquires water quality index values including a supply water quality index value indicating the quality of supply water, and a circulating water quality index value indicating the quality of the circulatin...
# 48867   the invention generates a model of the composition of the cable segments in a network. different cable compositions have different loss distributions. each cable segment is given a starting cable composition (based on cable records if available), and thus can be represented as a loss distributio...
# 51975   the present invention relates to a brake wear detection device for trailer units (2), comprising an electrical circuit (4), normally closed, that is fed from the tractor unit (1). it connects the entire series of conventional devices for detecting wear and tear in the lining of brake shoes or pa...
# 69529   a method for identifying neoantigens that are likely to be presented by mhc alleles on a surface of tumor cells of a subject. peptide sequences of the tumor neoantigens and of the mhc alleles are obtained by sequencing the tumor cells of the subject. the peptide sequences of the tumor neoantigen...
# 69896   the invention proposes a method for simulating a rendering of a makeup product on a body area is disclosed comprising: - acquiring an image of the body area without makeup of a subject, - determining first color parameters of the pixels of the image corresponding to the body area without makeup,...
# 72857   given a set of therapeutic epitopes, a cassette sequence is designed to reduce the likelihood that junction epitopes are presented in the patient. the cassette sequence is designed by taking into account presentation of junction epitopes that span the junction between a pair of therapeutic epito...
# 77362   a method for identifying neoantigens that are likely to be presented on a surface of tumor cells of a subject. peptide sequences of tumor neoantigens are obtained by sequencing the tumor cells of the subject. the peptide sequence of each of the neoantigens is associated with one or more k-mer bl...
# 82047   the present invention beneficially provides an improved method and apparatus for designing submicron integrated circuits. a tag identifier is provided to an integrated circuit (ic) design. the tag identifier defines a set of properties for edge fragments. edge fragments are tagged if they have t...
# 85479                                                                                                                                                  an automated quotation system is provided for generating firm binding price quotations for custom manufactured parts in either an online or offline context.
# 85563   the present disclosure relates to systems, methods, and computer-readable media to selectively enhance digital image and video content. for example, systems disclosed herein can encode original video content to compress and decompress the original video content. systems described herein can furt...
# 89870   techniques for categorizing a test sequence are disclosed. an exemplary technique includes defining and utilizing position specific score matrices that takes into account dependencies of adjacent positions. an embodiment includes predicting hiv viral tropism with improved specificity and sensiti...
# 93414   a system and method for knowledge verification utilizing biopotentials and physiologic metrics, which includes a computer-based device having stored thereon probe, relevant and gallery image data, and a biopotential amplifier removably connected to a human subject via disposable ag/ag—cl electro...
# 98845   the present technology provides a system that can update aspects of an authoritative map portion stored on an autonomous vehicle using low-resolution data from the at least one sensor of the autonomous vehicle, and therefore avoids the need for dispatching the special purpose mapping vehicle for...
# 100983  methods and applications for relating the structure of a molecule in a library to its function are described. embodiments described herein relate structure to function by considering the covalent structure of the molecule, the components of that structure that are common to many molecules in the...
# 102606  a method including acquiring measurements representing torque applied to a connection between a first tubular and a second tubular, a rotational position of the first tubular relative to the second tubular, or both, obtaining a plurality of make-up parameters representing conditions under which ...
# 109248  a method and system for electronically classifying a pre-processed heart sound signal of a patient as functional (normal) or pathological is provided. the pre-processed patient heart sound signal is segmentised and features are extracted therefrom (104) to build up a feature vector which is repr...
# 115926  a pulse waveform measurement system includes an led light source providing an incident beam having a predetermined wavelength onto a radial or other artery, samples reflected light at a predetermined sample rate, computes, and displays a pulse waveform and various parameters associated therewith...
# 116088  in an embodiment, a makeup application system includes: a projector 22 configured to project digital content including a makeup application tutorial onto the user's facial surface; and a dynamic mapping unit 24; 30 operably coupled to the projector, wherein the dynamic mapping unit is configured...
# 120740  a well advisor system and console for monitoring and managing tubular tripping operations at a well site. the system may be accessed through one or more workstations, or other computing devices, which may be located at a well site or remotely. the system is in communication with and receives inp...
# 130055                                                    the present invention relates to a composition comprising mannose oligosaccharide and a process for making such. the present invention further relates to a composition comprising mannose oligosaccharide for use in the treatment of a human or animal.
# 131315  in an embodiment, a makeup application system includes: a projector (22) configured to project digital content including a makeup application tutorial onto the user's facial surface; and a dynamic mapping unit (24); (30) operably coupled to the projector, wherein the dynamic mapping unit is conf...
# 132274  a system comprises an encoder configured to compress attribute information for a point cloud and/or a decoder configured to decompress compressed attribute information for the point cloud. attribute values for at least one starting point are included in a compressed attribute information file an...
# 133578  a system and method for inferring informational goals and preferred level of details in answers in response to questions posed to computer-based information retrieval or question-answering systems is provided. the system includes a query subsystem that can receive an input query and extrinsic da...
# 135330  an apparatus for identifying a tool joint connection is disclosed comprising a scanning system configured to scan an exterior of a drill string, at least one distance measuring sensor mounted to a movable platform and a computer connected to the scanning system and the at least one distance meas...
# 137808  in an embodiment, a virtual hair coloration system includes: a projector 22 configured to project digital content including a makeup application tutorial onto the user's hair; and a dynamic mapping unit 24; 30 operably coupled to the projector, wherein the dynamic mapping unit is configured to e...
# 147253  methods and systems that can use a gas comprising a nitrogen center that is introduced upstream of a plasma sustained in a torch are described. in some configurations, the gas comprising the nitrogen center can be introduced as a gas upstream of the plasma and through a sample introduction devic...
# 147996  an mri apparatus and method useful for both industrial applications and medical applications is provided. the apparatus and procedures are capable of estimating the value of a continuous property, such as concentration, viscosity or the like by interpolating or extrapolating from a model derived...
# 156281  the present apparatus, method, and system utilize sound waves to suppress fires using metasurface lenses that can work in concert with detectors to amplify and optimize sound pressure level and thereby deprive a fire of needed oxygen. metamaterial is utilized that manipulates the propagation of ...
# 158360  an apparatus for identifying a tool joint connection is disclosed comprising a scanning system configured to scan an exterior of a drill string, at least one distance measuring sensor mounted to a movable platform and a computer connected to the scanning system and the at least one distance meas...
# 158644  the inventionproposes a method for simulating a rendering of a makeup product on a body area is disclosed comprising:∘ acquiring an image of the body area without makeup of a subject,∘ determining first color parameters of the pixels of the image corresponding to the body area without makeup,∘ i...
# 158680  the invention generates a model of the composition of the cable segments in a network. different cable compositions have different loss distributions. each cable segment is given a starting cable composition (based on cable records if available), and thus can be represented as a loss distributio...
# 158859  a method and system for electronically classifying a pre-processed heart sound signal of a patient as functional (normal) or pathological is provided. the pre-processed patient heart sound signal is segmentised and features are extracted therefrom (104) to build up a feature vector which is repr...
# 161173                                               a system for removing undesirable compounds from contaminated air includes a biofilter having a fuzzy logic based controller. a contaminant, such as hydrogen sulfide, is removed from contaminated air by passing the contaminated air through the biofilter.
# 164621  a system for removing undesirable compounds from contaminated air includes a biofilter having an alkaline material introduction system and a fuzzy-logic based controller. a contaminant, such as hydrogen sulfide, is removed from contaminated air by passing the contaminated air through the biofilter.
# 165727  aspects of the present disclosure include methods for processing a biological sample. methods according to certain embodiments include contacting a biological sample having cells with an assay reagent that includes one or more analyte-specific binding members to produce a biological sample assay...
# 167123  a computer-implemented method for generating a test set of test stimuli for testing a subject using a computer system may be used to reduce test time. the method includes selecting one or more features from among a plurality of features, wherein a measurable effect on the subject for each featur...
# 168685                                               a system for removing undesirable compounds from contaminated air includes a biofilter having a fuzzy logic based controller. a contaminant, such as hydrogen sulfide, is removed from contaminated air by passing the contaminated air through the biofilter.
# 169966  control and/or identification method in an automatic machine (1, 21, 46) for the production or the packaging of consumer products, in particular of the tobacco industry; the automatic machine (1, 21, 46) has at least one processing line (5), which is provided with a plurality of operating member...
# 172059  utilizing vision systems at a wellsite, which may include operating a video camera to generate a video signal comprising images of one or more pieces of equipment or components and receiving the video signal by a processing system, which may then process the images to monitor or determine physic...
# 183942  the present invention relates to a brake wear detection device for trailer units (2), comprising an electrical circuit (4), normally closed, that is fed from the tractor unit (1). it connects the entire series of conventional devices for detecting wear and tear in the lining of brake shoes or pa...
# 184735  a system for removing undesirable compounds from contaminated air includes a biofilter having an alkaline material introduction system and a fuzzy-logic based controller. a contaminant, such as hydrogen sulfide, is removed from contaminated air by passing the contaminated air through the biofilter.
# 184897  described herein are systems and methods for detecting a physiological response based on thermal measurements while accounting for touching the face. in one embodiment, a system includes an inward-facing head-mounted thermal camera (cam) that takes thermal measurements of a region of interest (t...
# 186491  the invention generates a model of the composition of the cable segments in a network. different cable compositions have different loss distributions. each cable segment is given a starting cable composition (based on cable records if available), and thus can be represented as a loss distributio...
# 186505  methods for determining in situ the value of a formation fluid parameter using a downhole fluid analysis (dfa) tool. the methods utilize advanced statistical learning tools to build a predictive model to estimate a fluid property given a set of input parameters. in one embodiment the fluid satur...
# 190133  a technique for qualification of loops for new digital subscriber line services (dsl) involves use of an expert system, such as a neural network. a database of loop characteristic information and performance data enables the expert system to train or learn how to predict performance for future l...
# 192962  disclosed herein is a system and methods for determining the alleles, neoantigens, and vaccine composition as determined on the basis of an individual's tumor mutations. also disclosed are systems and methods for obtaining high quality sequencing data from a tumor. further, described herein are ...
# ...
# 72857   1. a method of identifying a cassette sequence for a neoantigen vaccine, comprising: obtaining, for a patient, at least one of exome, transcriptome, or whole genome tumor nucleotide sequencing data from the tumor cells and normal cells of the subject, wherein the nucleotide sequencing data is us...
# 77362   1. a method for identifying one or more neoantigens from one or more tumor cells of a subject that are likely to be presented on a surface of the tumor cells, the method comprising the steps of: obtaining at least one of exome, transcriptome, or whole genome nucleotide sequencing data from the t...
# 82047   a method comprising: providing a first tag identifier to an integrated circuit (ic) design, said first tag identifier to define a first set of at least one property for edge fragments in the ic design; and tagging a first edge fragment with a first tag if the first edge fragment has the at least...
# 85479   1. a method of providing a firm price quotation for a custom manufactured part, comprising: (a) receiving access on a server computer system from a customer computer over a global communication network; (b) uploading from the customer computer to the server computer system a pre-existing compute...
# 85563   1. a method, comprising:decompressing compressed digital video content to generate decompressed digital video content including a plurality of decoded video frames;identifying a decoded video frame from the plurality of decoded video frames; identifying an area of interest for the decoded video ...
# 89870   1. a method for categorizing a test sequence as a first class or a second class, the method comprising: providing a first training set including a plurality of sequences of the first class; providing a second training set including a plurality of sequences of the second class; determining a plur...
# 93414   1. a knowledge verification method, comprising presenting, on a monitor operatively connected to a computer, probe, relevant, and gallery data to a subject in a statistically weighted, pseudo-random sequence through a control program operating on the computer; recording on the computer, a time h...
# 98845   1. a method comprising: receiving data indicating an inconsistency between a stored data describing n feature of a location, and a current data describing the feature of the location, wherein the stored data includes data from a high-resolution sensor system and semantic labels, wherein the curr...
# 100983  1. a method for relating the structure of a molecule in a library to its function by analyzing experimental data from a library comprising one or more chemical structures, the method comprising: (a) obtaining a data set associated with said one or more chemical structures based on a signal deriv...
# 102606  1. a method, comprising: acquiring measurements representing torque applied to a connection between a first tubular and a second tubular, a rotational position of the first tubular relative to the second tubular, or both; obtaining a plurality of make-up parameters representing conditions under ...
# 109248  a method of classifying a pre-processed heart sound signal of a patient, the method being characterised in that the pre-processed patient heart sound signal is electronically compared to a plurality of similarly pre-processed heart sounds corresponding to each of a plurality of pathologies and a...
# 115926  1. a pressure pulse waveform measurement device, comprising:a first light source adapted to transmit incident light to a blood carrying artery at a measurement location;an optical sensor adapted to receive a reflected light in response to the transmitted light from the blood carrying artery; and...
# 116088  1. a makeup application system, comprising: a projector (22) configured to project digital content including a makeup application tutorial onto the user's facial surface; and a dynamic mapping unit (24; 30) operably coupled to the projector, wherein the dynamic mapping unit is configured to esta...
# 120740  1. a system for improving computer-based processing and monitoring of tubular tripping operations at a well site, comprising: a plurality of sensors to sample or detect parameters related to tubular tripping operations at a well site, said plurality of sensors comprising surface sensors or downh...
# 130055  1. a mannose oligosaccharide composition, characterized in that the composition is soluble in water.2. the composition of claim 1 characterized in that it comprises less than 0.1 wt % db of beta-glucan.3. the composition of claim 1 characterized in that a mannose oligosaccharide content that is ...
# 131315  1. a makeup application system, comprising:a projector (22) configured to project digital content including a makeup application tutorial onto the user's facial surface; anda dynamic mapping unit (24; 30) operably coupled to the projector, wherein the dynamic mapping unit is configured to establ...
# 132274  1. a system comprising: one or more sensors configured to capture a plurality of points that make up a point cloud, wherein respective ones of the points comprise spatial information for the point and attribute information for the point; and an encoder configured to: determine a first level of d...
# 133578  1. an automated information retrieval system, comprising: a user interface for receiving a query; an analyzer to process said query based upon at least one attribute related to a user, the analyzer infers one or more informational goals of the user from the query, the one or more informational g...
# 135330  1. a method for identifying a tool joint, comprising: positioning a scanning system adjacent a pipe string, the scanning system having at least one sensor configured to scan the pipe string; scanning the pipe string with the scanning system to obtain scan data; transmitting the scan data to a co...
# 137808  1. a virtual hair coloration system, comprising:a projector (22) configured to project digital content including a makeup application tutorial onto the user's hair; anda dynamic mapping unit (24; 30) operably coupled to the projector, wherein the dynamic mapping unit is configured to establish a...
# 147253  1. a method comprising introducing a gas comprising a nitrogen center upstream of a plasma sustained in a torch, wherein the torch is configured to sustain an inductively coupled plasma using a plasma gas introduced into the torch.2. the method of claim 1, wherein the gas comprising the nitrogen...
# 147996  1. a computer-implemented method for estimating the magnitude of at least a first continuous property of a first sample of a first substance based on nuclear magnetic resonance measurements comprising: obtaining a first plurality of magnetic resonance responses comprising a set of measurements o...
# 156281  1. an apparatus comprising:a speaker configured to emanate sound waves; andat least one metasurface configured to manipulate the sound waves to at least one of increase a decibel (db) level or focus the sound waves at a location for suppression of a fire.2. the apparatus of claim 1, wherein the ...
# 158360  1. a method for identifying a tool joint, comprising: positioning a scanning system adjacent a pipe string, the scanning system having at least one sensor configured to scan the pipe string; scanning the pipe string with the scanning system to obtain scan data; transmitting the scan data to a co...
# 158644  1. a method (200) for simulating a rendering of a makeup product on a body area, the method being performed by a processor (11), and comprising : ∘ acquiring (210) an image of the body area without makeup of a subject, ∘ determining (230) first color parameters of the pixels of the image corresp...
# 158680  1. a method of modelling the composition of cable segments (c1, c2, c3) in a network (100), said network comprising a plurality of circuits (l1, l2) each connected to a respective customer premises (106, 108), each circuit comprising at least one cable segment and at least one cable segment is s...
# 158859  1. a method of classifying a recorded, digitized acoustic heart sound signal of a patient, the method being performed by a processor and comprising the steps of: pre-processing the heart sound signal so as to be parsed into respective heart beat cycles by identifying or predicting locations of i...
# 161173  1. a controller for a biofiltration system, the controller being configured to: receive a first input signal from a measurement device in the biofiltration system corresponding to a first measured value of an input parameter of the biofiltration system; calculate a first error value, the first e...
# 164621  1. a biotrickling filter for the treatment of contaminated air, the biotrickling filter comprising: a vessel; a contaminated air inlet in fluid communication with an internal volume of the vessel; a treated air outlet in fluid communication with the internal volume the vessel; a media bed dispos...
# 165727  1. a method comprising: contacting a biological sample comprising cells with an assay reagent comprising one or more analyte-specific binding members to produce a biological sample assay composition; and introducing the biological sample assay composition into an inlet of a flow cytometer, where...
# 167123  claims 1. a computerimplemented method for generating a test set comprising test stimuli for testing a subject using a computer system comprising logic-based processing circuitry, the method comprising: selecting one or more features from among a plurality of features, wherein a measurable effec...
# 168685  1. 1.-12. (canceled)13. a controller for a biofiltration system, the controller being configured to: receive a first input signal from a measurement device in the biofiltration system corresponding to a first measured value of an input parameter of the biofiltration system; calculate a first err...
# 169966  1. a control and/or identification method in an automatic machine (1, 21, 46) for the production or the packaging of consumer products, in particular of the tobacco industry; wherein the automatic machine (1, 21, 46) comprises at least one processing line (5), which is provided with a plurality ...
# 172059  1. a method comprising: monitoring alignment between a pin end of an upper tubular and a box end of a lower tubular during tubular make up operations at an oil and gas wellsite by: operating a first video camera to generate a first video signal comprising first images encompassing the pin end of...
# 183942  1. a brake wear detection device for trailer units, suitable for emitting a command pulse with which to activate a warning or alarm device placed in the tractor unit (or in a variety of positions, accessible to the tractor driver) upon detection of improper or excessive wear in the lining of the...
# 184735  1. a method of removing hydrogen sulfide from contaminated air, the method comprising: flowing the contaminated air through a biotrickling filter including a media bed and a population of hydrogen sulfide oxidizing bacteria disposed on media in the media bed, the population of bacteria oxidizing...
# 184897  we claim:1. a system configured to detect a physiological response, comprising: an inward-facing head-mounted thermal camera (cam) configured to take thermal measurements of a region of interest (throi) on a user's face; a sensor configured to provide measurements (m) indicative of times at whic...
# 186491  1. a method of modelling the composition of cable segments in a network, said network comprising a plurality of circuits each connected to a respective customer premises, each circuit comprising at least one cable segment and at least one cable segment is shared between a plurality of circuits, ...
# 186505  1. a method of determining in situ a value of a parameter of a reservoir fluid taken from a formation traversed by a borehole, comprising:drawing the fluid into a tool located in the borehole, said tool having an optical module including a spectrometer;shining light through the fluid and sensing...
# 190133  1. a system for qualifying a loop with regard to digital subscriber line service in a network providing a plurality of levels of digital subscriber line service over a plurality of loops, comprising: a database of records regarding loops in service in a predefined section of the network, each re...
# 192962  1. a method for identifying one or more neoantigens from one or more tumor cells of a subject that are likely to be presented on surface of the tumor cells, comprising the steps of: obtaining at least one of exome, transcriptome, or whole genome nucleotide sequencing data from the tumor cells an...
# 196933  1. a system comprising: one or more sensors configured to capture a plurality of points that make up a point cloud, wherein respective ones of the points comprise spatial information for the point and attribute information for the point; and an encoder configured to: determine a first level of d...
# 198989  1. a fire suppression apparatus comprising: a speaker; and a material configured to manipulate a phase shift of sound waves that emanate from said speaker; wherein said material is configured to manipulate said phase shift at least by a surface shape of said material.2. the fire suppression appa...
# 199244  what is claimed is:1. a system for improving computer-based processing and monitoring of tubular tripping operations at a well site, comprising:a plurality of sensors to sample or detect parameters related to tubular tripping operations at a well site, said plurality of sensors comprising surfac...
# 199637  1. a method, comprising: receiving, by a data analysis platform comprising a processor and memory, one or more items of sensor data from a data collection platform, wherein the one or more items of sensor data are related to one or more reactors; based on the one or more items of sensor data, ge...
# 200018  what is claimed is:1. a method for treating cancer in a subject in need thereof comprising:(a) selecting at least one epitope sequence from a library of epitope sequences, wherein each epitope sequence in the library is matched to a protein encoded by an hla allele of the subject; and(b) contact...
# 201701  1. a method for identifying one or more antigens from one or more tumor cells of a subject that are likely to be presented on surface of the tumor cells, comprising the steps of: obtaining at least one of exome, transcriptome, or whole genome nucleotide sequencing data from the tumor cells and n...
# 203511  1. a water quality management device which manages a circulating water system of a plant including a circulation line through which circulating water is circulated, a supply line which supplies makeup water to the circulation line, a discharge line which discharges the circulating water from the...
# 204069  1. a computer-implemented method comprising: receiving, at a computer system, an audio signal; determining, by the computer system, an energy-independent component of a portion of the audio signal associated with a spectral shape of the portion; determining, by the computer system, an energy-dep...
# 208357  1. a virtual hair coloration system, comprising: a projector (22) configured to project digital content including a makeup application tutorial onto the user's hair; and a dynamic mapping unit (24; 30) operably coupled to the projector, wherein the dynamic mapping unit is configured to establish...
# 210442  1. a method for identifying one or more neoantigens from one or more tumor cells of asubject that are likely to be presented on a surface of the tumor cells, the method comprising the steps of:obtaining at least one of exome, transcriptome, or whole genome nucleotide sequencing data from the tum...

# %%
df_selected = pd.concat([df_selected, df[df.title == "water quality management device, water treatment system, water quality management method, and program for optimizing water treatment system"]])
df_selected = pd.concat([df_selected, df[df.title == "wearable pulse waveform measurement system and method"]])
len(df_selected)
# Out:
# 53

# %% [markdown]
# ##### cream

# %%
keyword = keywords_cosmetics[17]
keyword
# Out:
# ' cream'

# %%
df_candidate = df[(df[keyword] > 0)
                  & (df.ipc_classes.str.count("G(01|06)")==0)
                  & (df.ipc_classes.str.count("(^| )A")>0)
                 ].query("title not in @df_selected")

df_candidate[["filename", "title", "ipc_classes","abstract", "claims"]]
# Out:
#                    filename  \
# 538     US2013236417_A1.txt
# 15551     US10092235_B2.txt
# 18306   US2010086501_A1.txt
# 21464   US2020054018_A1.txt
# 22700   US2017164893_A1.txt
# 31251   WO2021007341_A2.txt
# 34424   WO2020198546_A1.txt
# 55007   WO2020210785_A1.txt
# 56455   US2020332344_A1.txt
# 73457   US2017079274_A1.txt
# 77413   US2007009470_A1.txt
# 88971   US2020397732_A1.txt
# 90992     US10292396_B2.txt
# 95067      US9491942_B2.txt
# 112206  WO2019036043_A2.txt
# 114796     US9591865_B2.txt
# 120991     EP3769852_A1.txt
# 121331  WO2013059364_A2.txt
# 130055  US2020297019_A1.txt
# 147791  US2015126437_A1.txt
# 149854  WO2013044118_A2.txt
# 166259  US2013079394_A1.txt
# 182672  US2020316037_A1.txt
# 202709  US2017196503_A1.txt
# 209315  WO2010025341_A2.txt
# 210756  WO2020227646_A1.txt
# 211107    US10780033_B2.txt
#
#                                                                                                                                                      title  \
# 538                                                                                                       ligands for odor receptors and olfactory neurons
# 15551                                                                                                  method and apparatus for enhancing nervous function
# 18306                                                                                                               determining age ranges of skin samples
# 21464                                   methods for assessing repellant quality of organic materials and methods and compositions for repelling arthropods
# 22700                                                            method and system for combining physiological and machine information to enhance function
# 31251                                                                                                         live biotherapeutic compositions and methods
# 34424                                                                         systems and methods involving non-surgical laser treatment of a fibrous mass
# 55007                                             d3 receptor agonist compounds; methods of preparation; intermediates thereof; and methods of use thereof
# 56455                                                                                                                     treating and detecting dysbiosis
# 73457                                   methods for assessing repellant quality of organic materials and methods and compositions for repelling arthropods
# 77413                                                   topical/on-the-skin estrogen cream, lotion, ointment, hair tonic, shampoo and wound healing powder
# 88971                                     methods and compositions for identification and modulation of microbiome biochemical pathways to alter phenotype
# 90992                                   methods for assessing repellant quality of organic materials and methods and compositions for repelling arthropods
# 95067                                   methods for assessing repellant quality of organic materials and methods and compositions for repelling arthropods
# 112206                  a method to generate a cocktail of personalized cancer vaccines from tumor-derived genetic alterations for the treatment of cancer
# 114796                                               container for a device for preparing a frozen confection and device for preparing a frozen confection
# 120991  pump- actuated dispenser with integrated switch, system and method for remote monitoring of product consumption from said pump- actuated dispenser
# 121331                                  methods for assessing repellant quality of organic materials and methods and compositions for repelling arthropods
# 130055                                                          composition comprising mannose oligosaccharide and process for making same and use thereof
# 147791                                  methods for assessing repellant quality of organic materials and methods and compositions for repelling arthropods
# 149854                                                                                                             coumarin derivates as insect repellents
# 166259                                                  indirect modeling of new repellent molecules active against insects, acarids, and other arthropods
# 182672                                                                                                     compositions and methods for treating neoplasia
# 202709                                                                                                 method and apparatus for enhancing nervous function
# 209315                                                                                                              determining age ranges of skin samples
# 210756                                                                                                          methods and compositions for treating pain
# 211107                                                                                                                     aloe derived mineral supplement
#
#                                                                                                                                                                                                                                                                                                         ipc_classes  \
# 538                                                                                                                                                                                                                                                                                  A01M1/10, A01N33/00, A23L27/10
# 15551                                                                                                                                                                                       A61B5/00, A61B5/01, A61B5/0205, A61B5/024, A61B5/04, A61B5/0402, A61B5/0476, A61B5/0488, A61B5/053, A61B5/08, A61B5/145
# 18306                                                                                                                                                                                                                          A61K31/56, A61K38/16, A61K38/43, A61K8/18, A61Q17/04, C12Q1/68, C40B30/04, C40B40/06
# 21464   A01N31/02, A01N31/06, A01N33/10, A01N35/02, A01N35/04, A01N35/06, A01N35/10, A01N37/10, A01N37/18, A01N37/20, A01N37/22, A01N37/36, A01N37/44, A01N37/46, A01N43/12, A01N43/16, A01N43/32, A01N43/38, A01N43/40, A01N43/42, A01N43/50, A01N43/54, A01N43/60, A01N43/78, A01N43/90, A01N47/16, A01N47/42,...
# 22700                                                                                                                                                                                                                                            A61B5/00, A61B5/0205, A61B5/04, A61B5/0408, A61B5/0488, A61B5/0492
# 31251                                                                                                                                                                                                                                                                                                     A61K39/02
# 34424                                                                                                                                                                                                                                                                                           A61B8/08, A61N5/067
# 55007                                                                                                                                                                                                                                                                            A61K31/5377, A61P25/00, C07D413/14
# 56455                                                                                                                                                                                                                                                       A61K35/747, A61K39/395, A61K45/06, A61P11/06, C12Q1/689
# 73457   A01N31/02, A01N31/06, A01N33/10, A01N35/02, A01N35/04, A01N35/06, A01N35/10, A01N37/10, A01N37/18, A01N37/20, A01N37/22, A01N37/36, A01N37/44, A01N37/46, A01N43/12, A01N43/16, A01N43/32, A01N43/38, A01N43/40, A01N43/42, A01N43/50, A01N43/54, A01N43/60, A01N43/78, A01N43/90, A01N47/16, A01N47/42,...
# 77413                                                                                                                                                                                                                                                                                                      A61K8/64
# 88971                                                                                                                                                                                                                                                         A61K31/015, A61K31/03, A61K31/11, A61K31/20, A61K9/00
# 90992   A01N31/02, A01N31/06, A01N33/10, A01N35/02, A01N35/04, A01N35/06, A01N35/10, A01N37/10, A01N37/18, A01N37/20, A01N37/22, A01N37/36, A01N37/44, A01N37/46, A01N43/12, A01N43/16, A01N43/32, A01N43/38, A01N43/40, A01N43/42, A01N43/50, A01N43/54, A01N43/60, A01N43/78, A01N43/90, A01N47/16, A01N47/42,...
# 95067                                                   A01N31/02, A01N33/10, A01N35/06, A01N35/10, A01N37/18, A01N37/20, A01N37/22, A01N37/36, A01N37/44, A01N37/46, A01N43/32, A01N43/38, A01N43/40, A01N43/42, A01N43/50, A01N43/54, A01N43/60, A01N43/78, A01N43/90, A01N47/16, A01N47/42, A01N47/46, C08G16/02
# 112206                                                                                                                                                                                                                                                                                A42B3/20, A61K39/00, C12Q1/68
# 114796                                                                                                                                                                                                                 A23G9/04, A23G9/08, A23G9/28, B65D83/00, B65D85/78, F25B21/02, F25C1/00, F25C5/14, F25D25/00
# 120991                                                                                                                                                                                                                                                          A47K5/12, B05B11/00, B05B12/00, B05B15/30, H02N2/18
# 121331                                                                                                                                                                                                                                                                               A01N37/46, A01N43/30, A01P7/00
# 130055                                                                                                                                                                                     A23K20/163, A23K50/30, A23K50/60, A23K50/75, A23L33/00, A23L33/125, A61K31/702, A61K8/60, A61Q1/00, A61Q11/00, A61Q19/00
# 147791                                                  A01N31/02, A01N33/10, A01N35/06, A01N35/10, A01N37/18, A01N37/20, A01N37/22, A01N37/36, A01N37/44, A01N37/46, A01N43/32, A01N43/38, A01N43/40, A01N43/42, A01N43/50, A01N43/54, A01N43/60, A01N43/78, A01N43/90, A01N47/16, A01N47/42, A01N47/46, C08G16/02
# 149854                                                                                                                                                                                           A01N31/04, A01N43/16, A01N47/02, C07C59/00, C07C69/732, C07D311/14, C07D311/16, C07D311/20, C07D311/46, C07D311/52
# 166259                                                                                                                                                                                                                                         A01N43/16, A01P17/00, C07D311/14, C07D311/16, C07D311/18, C07D311/46
# 182672                                                                                                                                                          A61K31/047, A61K31/196, A61K31/203, A61K31/415, A61K31/436, A61K31/437, A61K31/573, A61K47/36, A61K47/38, A61K47/40, A61K47/42, A61K9/00, A61P35/00
# 202709                                                                                                                                                                                      A61B5/00, A61B5/01, A61B5/0205, A61B5/024, A61B5/04, A61B5/0402, A61B5/0476, A61B5/0488, A61B5/053, A61B5/08, A61B5/145
# 209315                                                                                                                                                                                                                         A61K31/56, A61K38/16, A61K38/43, A61K8/18, A61Q17/04, C12Q1/68, C40B30/04, C40B40/06
# 210756                                                                                                                                                                                                                                                               A61K31/167, A61K31/192, A61K31/198, A61K31/428
# 211107                                                                                                                                                            A23L19/00, A23L33/16, A61K36/886, A61K8/19, A61K8/23, A61K8/24, A61K8/25, A61K8/26, A61K8/27, A61K8/28, A61K8/29, A61K8/66, A61K8/9794, A61Q19/08
#
#                                                                                                                                                                                                                                                                                                            abstract  \
# 538                                                                               the disclosure provides compounds useful as insect repellents and compositions comprising such repellents. the disclosure further provides insect traps and method for identifying ligands and cognates for biological molecules.
# 15551   disclosed is a method for interacting with the nervous system. the method includes detecting signals associated with a biological function at one or more sensors. it also includes processing the signals to create a representation thereof, delivering effector responses based on the representation...
# 18306   the present invention provides methods for characterizing a skin sample of a subject as belonging to an age range by analyzing nucleic acid or protein molecules obtained from the subject. the methods include analyzing expression or mutations in epidermal samples, of one or more skin markers. the...
# 21464   the disclosure provides compounds useful as insect repellents, compositions comprising such repellents, and methods of repelling an arthropod using such compounds and compositions. the disclosure further provides insect traps and method for identifying ligands and cognates for biological molecules.
# 22700                                                             the present invention relates generally and specifically to combining biological sensors with external machines using machine learning to form computerized representations that can control effectors to deliver therapy or enhance performance.
# 31251   live biotherapeutic compositions and methods are provided for treatment, prevention, or prevention of recurrence of skin and soft tissue infections, such as mastitis and/or intramammary infections, for example, in cows, goats, sows, and sheep. methods include decolonizing and durably replacing w...
# 34424   systems and methods for treating fibrous masses associated with conditions such as morton's neuroma, stump neuroma, plantar fibroma, plantar fibromatosis, plantar fasciitis, plantar fasciopathy, and achilles tendinopathy. according to implementation herein, exemplary methods may comprise non-sur...
# 55007                                 disclosed herein are novel compounds including dopamine d3 receptor agonists, compositions thereof, methods of use thereof, and processes of synthesizing the same. further disclosed are d3r selective agonist compounds, specifically bitopic ligands comprising chirality.
# 56455   provided herein are, inter alia, methods, compositions, and systems, for detecting and treating dysbiosis such as nasal and sinus dysbiosis. in aspects, included herein are methods, compositions, and systems for detecting asthma, chronic rhinosinusitis, and infections (such as rhinovirus infecti...
# 73457   the disclosure provides compounds useful as insect repellents, compositions comprising such repellents, and methods of repelling an arthropod using such compounds and compositions. the disclosure further provides insect traps and method for identifying ligands and cognates for biological molecules.
# 77413   the claimed invention is the topical-to-skin use of generic estradiol, estriol, conjugated estrogens, or any other synthetic estrogen within a non-absorbable generic vehicle of cream, lotion, ointment, shampoo, hair tonic, and wound-healing powder, having no absorbents or deconstructors in their...
# 88971   provided, in part, are methods, compositions, and systems are provided for detecting one or more repellent-generating enzymatic pathways by characterizing the skin microbiomes and metabolomes of populations of individuals both naturally resistant and highly prone to bites from blood sucking arth...
# 90992   the disclosure provides compounds useful as insect repellents, compositions comprising such repellents, and methods of repelling an arthropod using such compounds and compositions. the disclosure further provides insect traps and method for identifying ligands and cognates for biological molecules.
# 95067   the disclosure provides compounds useful as insect repellents, compositions comprising such repellents, and methods of repelling an arthropod using such compounds and compositions. the disclosure further provides insect traps and method for identifying ligands and cognates for biological molecules.
# 112206                                                                                                                                                               the invention provides methods of selecting cancer vaccines from genetically altered proteins expressed by mammalian cancer cells and tissues.
# 114796  the present invention relates to a container (20) designed for being inserted into a device (1) for preparing a frozen confection (17), said container (20) comprising a sealed flexible casing (25) and said container (20) containing ingredients (15) for producing a frozen confection (17) when bei...
# 120991  the invention refers to a pump-actuated dispenser (1) comprising: a compression pump (2), a pump actuator (3), an electronic circuit (9) having stored an unique identification code usable to identify the pump-actuated dispenser (1), a power source (21,24) connected with the electronic circuit (9...
# 121331  the disclosure provides compounds useful as insect repellents, compositions comprising such repellents, and methods of repelling an arthropod using such compounds and compositions. the disclosure further provides insect traps and method for identifying ligands and cognates for biological molecules.
# 130055                                                    the present invention relates to a composition comprising mannose oligosaccharide and a process for making such. the present invention further relates to a composition comprising mannose oligosaccharide for use in the treatment of a human or animal.
# 147791  the disclosure provides compounds useful as insect repellents, compositions comprising such repellents, and methods of repelling an arthropod using such compounds and compositions. the disclosure further provides insect traps and method for identifying ligands and cognates for biological molecules.
# 149854  this invention relates to novel coumarin derivatives of formula (i) and formula (ia), formulations comprising same, and to methods of making and using these compounds and formulations, which are useful as repellents against insects and/or pests. the compounds also prevent illness and disease cau...
# 166259  this invention relates to novel coumarin derivatives, formulations comprising same, and to methods of making and using these compounds and formulations, which are useful as repellents against insects and/or pests. the compounds also prevent illness and disease caused by insect/pest-borne vectors...
# 182672                                                                               the invention relates to unique compositions and methods for treating neoplasia. specifically, the invention relates to an off-label combinatorial therapy that modulates angiogenesis and immune response to treat neoplasia.
# 202709  disclosed is a method for interacting with the nervous system. the method includes detecting signals associated with a biological function at one or more sensors. it also includes processing the signals to create a representation thereof, delivering effector responses based on the representation...
# 209315  the present invention provides methods for characterizing a skin sample of a subject as belonging to an age range by analyzing nucleic acid or protein molecules obtained from the subject. the methods include analyzing expression or mutations in epidermal samples, of one or more skin markers. the...
# 210756  the present disclosure features combinations of dopaminergic agents and analgesic agents useful for treating pain. in particular, the combinations feature a low ratio of dopaminergic agent to analgesic agent. the dopaminergic agent can be an agonist of the dopamine receptor d1 -like family or th...
# 211107  a method of maintaining or improving tissue health, maintaining or improving bone health, maintaining or improving cardiovascular health, or improving the appearance or texture of skin by administering a composition of the aloe rind minerals. the aloe rind minerals can be prepared from aloe rind...
#
#                                                                                                                                                                                                                                                                                                              claims
# 538     1-41. (canceled)42. a composition, comprising one or more compounds selected from table 9, table 10, and any combination thereof, in a trap, a cream, a lotion, a spray, a dust, a vapor emitter, a candle, an oil, a wicked apparatus, a fan, a vaporizer, a perfume, a cologne, a fragrance, a deodora...
# 15551   1. a method for interacting with the nervous system, the method comprising: detecting signals of normal and abnormal function of a body function of an individual at one or more sensors, without requiring knowledge of the precise neurophysiological mapping of the signals; mathematically processin...
# 18306   1. a method for determining the age range of a skin sample of a subject comprising analyzing nucleic acid from one or more genes listed in table 1, table 2, table 3, or any combination thereof, in a sample of the skin from the subject, thereby determining the age range of the skin of the subject...
# 21464   1. a method of repelling an arthropod, comprising exposing the arthropod with a repelling composition, wherein the repelling composition comprises one or more compounds selected from the group consisting of methyl n,n-dimethyl anthranilate, ethyl anthranilate, butyl anthranilate, and 2,3-dimethy...
# 22700   1. a method for interacting with the human body, the method comprising: detecting bodily signals associated with one or more bodily functions at one or more sensors associated with the human body; processing the bodily signals to create one or more sensed signatures of the one of more bodily fun...
# 31251   1. a live biotherapeutic composition for treatment or prevention of bovine, caprine, ovine, or porcine mastitis and/or intramammary infection comprising at least one synthetic microorganism, and a pharmaceutically acceptable carrier, wherein the synthetic microorganism comprises a recombinant nu...
# 34424   1. a method for treating a fibrous mass, comprising:identifying a location of the fibrous mass; andnon-surgically delivering electromagnetic energy having a spot size of about 8-10 mm, and other specified parameters, to the fibrous mass.2. the method of claim 1 or the invention of any claim here...
# 55007   1. a compound of formula i:or a pharmaceutically acceptable salt thereof, whereinr1 is an aryl, a heteroaryl, or a heterocycloalkyl;t is a tether group;x1 is a covalent bond, o, s, nr3, -(c=o)-, or c(r4)2, n(r3)-(c=o)-, -(c=o)-n(r3), -o- (c=o)-o-, -o-(c=o)-n(r3)-, -n(r3)-(c=o)-o-, or -n(r3)-(c=o...
# 56455   1. a method of detecting a nasal or sinus microbiome in a subject who has asthma, the method comprising detecting bacteria, or a proportion of bacteria, in a biological sample from the subject that are in 1 of or any combination of the following taxa: moraxella, staphylococcaceae, corynebacteriu...
# 73457   1. 1-21. (canceled)22. a method of repelling an arthropod, comprising exposing the arthropod to a composition comprising one or more compounds selected from the group consisting of:23. the method of claim 22, wherein the composition is applied on the body of one or more vertebrates or one or mor...
# 77413   1. the problem: the natural aging of the skin, the body's largest organ, becomes apparent from the mid-30's to early 40's and beyond. the normal skin aging physiology evidences as skin gradually becoming thinner, dryer, more wrinkled, more easily bruised, injured and infected, and susceptible to...
# 88971   1. 1-50. (canceled)51. a method of repelling insects, comprising: topically applying on a subject a composition that modulates a skin microbiome biochemical pathway; and modulating the skin microbiome biochemical pathway to generate a compound that repels insects.52. the method of claim 51, wher...
# 90992   1. a method of repelling an arthropod, comprising exposing the arthropod to a composition comprising one or more compounds selected from the group consisting of:2. the method of claim 1, wherein the composition is applied on the body of one or more vertebrates or one or more plants to expose the...
# 95067   1. a method of repelling an arthropod, comprising exposing the arthropod to a repelling composition, wherein the repelling composition comprises at least one compound of formula i: wherein: r1 is selected from the group consisting of c6-c12 alkyl, c4-c12 alkenyl, aryl, and arylalkyl; r2 and r3 a...
# 112206  a method of validating peptide variant(s) as an immunogenic peptide comprising:a. selecting a peptide variant(s) predicted to be an immunogenic peptide comprising the steps of1) obtaining a sample from a subject with a tumor;2) identifying genetically altered protein(s) expressed by a mammalian ...
# 114796  1. a device for preparing a frozen confection, the device comprising: a cooling element designed to receive a flexible container so dimensioned as to contain only an individual portion of liquid ingredients comprising 80 ml to 200 ml for producing a frozen confection when cooled and mechanically...
# 120991  1. a pump-actuated dispenser (1) comprising: a compression pump (2) and a pump actuator (3) to operate the compression pump (2), the pump actuator (3) having a nozzle (4) for the output of a product to be dispensed, wherein the pump actuator (3) is displaceable between two end positions, a resti...
# 121331  1. a method of repelling an arthropod, comprising exposing the arthropod with a repelling composition, wherein the repelling composition comprises one or more compounds selected from the group consisting of methyl ν,ν-dimethyl anthranilate, ethyl anthranilate, butyl anthranilate, and 2,3-dimethy...
# 130055  1. a mannose oligosaccharide composition, characterized in that the composition is soluble in water.2. the composition of claim 1 characterized in that it comprises less than 0.1 wt % db of beta-glucan.3. the composition of claim 1 characterized in that a mannose oligosaccharide content that is ...
# 147791  1. a method of repelling an arthropod, comprising exposing the arthropod to a repelling composition, wherein the repelling composition comprises one or more compounds selected from the group consisting of methyl n,n-dimethyl anthranilate, ethyl anthranilate, butyl anthranilate, and 2,3-dimethyl-...
# 149854  1. compound according to formula (i) or (ia):   wherein   r1, r2, r3, r4, and r5 independently include h, c, or5, cr5, occ(=0)n(r5)(r8}, cc(=0)n(r5}<r8), a iky i, aryl, aralkyl, heteroaryi, alcohols, amine, aldehyde, heterocydyl, or salts of amines and caboxylates;   a is o, or the ring is opene...
# 166259  1. a compound according to formula (i) or (ia):    wherein r1, r2, r3, r4, and r6 independently include h, c, or5, cr5, occ(═o)n(r5)(r8), cc(═o)n(r5)(r8), alkyl, aryl, aralkyl, heteroaryl, alcohols, amine, aldehyde, heterocyclyl, or salts of amines and carboxylates; a is o, or the ring is opened...
# 182672  1. a composition comprising: a combination of a toll-like receptor 7 (tlr7) agonist, non-steroidal anti-inflammatory drug(s) (nsaids), a glucocorticoid anti-inflammatory agent, a vitamin a derivative, a vitamin d3 derivative, a mechanistic target of rapamycin (mtor) inhibitor or a combination th...
# 202709  1. a method for interacting with the nervous system, the method comprising: detecting signals associated with a body function at one or more sensors; processing said signals to create a symbolic representation in code; tailoring the representation to the body function in an individual person; de...
# 209315  1. a method for determining the age range of a skin sample of a subject comprising analyzing nucleic acid from one or more genes listed in table 1, table 2, table 3, or any combination thereof, in a sample of the skin from the subject, thereby determining the age range of the skin of the subject...
# 210756  1 . a method of reducing pain in a subject, the method comprising administering an analgesic agent, a first dopaminergic agent, and a second dopaminergic agent to the subject, wherein:(i) the analgesic agent is administered to the subject in an amount of from about 50 mg to about 500 mg per dose...
# 211107  1. a method of maintaining or improving tissue health comprising administering a mineral composition comprising prepared from aloe leaf rind free from other parts of the aloe leaf, wherein the composition is prepared by: separating aloe leaf rind from other parts of an aloe plant; drying the alo...

# %%
df_selected = pd.concat([df_selected, df[df.title == "a pump actuating cap for pump dispensers, system and method for remote monitoring of product consumption from said pump actuating cap"]])
df_selected = pd.concat([df_selected, df[df.title == "pump- actuated dispenser with integrated switch, system and method for remote monitoring of product consumption from said pump- actuated dispenser"]])
df_selected = pd.concat([df_selected, df[df.title == "topical/on-the-skin estrogen cream, lotion, ointment, hair tonic, shampoo and wound healing powder"]])
df_selected = pd.concat([df_selected, df[df.title == "method and system for combining physiological and machine information to enhance function"]])
len(df_selected)
# Out:
# 58

# %%
keyword = keywords_cosmetics[18]
keyword
# Out:
# ' soap'

# %%
df_selected = df_selected[df_original.columns]

# %%
df_selected.to_csv("selected_patents.csv", index=None)

# %%
##### VECCHIO CODICE:

# %%
df_selected[["filename"]].to_excel("selected_patents_filename.xlsx", index=False, header=False)

# %%
df_selected.to_excel("selected_patents.xlsx", index=False)

# %%
for ipc in very_interesting_ipc_classes:
    try:
        print(f"{ipc}: {ipc_class_dict[ipc].split(' - ')[-1]}")
    except:
        print(f"{ipc}: none")
# Out:
# A45D44/00: A45D44/00: Other cosmetic or personal care articles, e.g. for hairdressers' rooms +
# A45D29/14: A45D29/14: Manicuring or pedicuring implements + motor-driven
# A45D29/00: A45D29/00: Manicuring or pedicuring +
# A61K8/00: A61K8/00: Cosmetics or similar toilet preparations +
# A61Q1/00: A61Q1/00: Make-up preparations; Body powders; Preparations for removing make-up +
# A61Q15/00A61Q19/10: none
# C11B9/00: C11B9/00: Essential oils; Perfumes +
# A23L27/10: A23L27/10: Spices; Flavouring agents or condiments; Artificial sweetening agents; Table salts; Dietetic salt substitutes; Preparation or treatment thereof + Natural spices, flavouring agents or condiments; Extracts thereof
# A45D34/04: A45D34/04: Containers or accessories specially adapted for handling liquid toilet or cosmetic substances, e.g. perfumes + Appliances specially adapted for applying liquid, e.g. using roller or ball
# A45D31/00: A45D31/00: Artificial nails +
# A46B9/04: A46B9/04: Arrangements of the bristles in the brush body + for toothbrushes
# A46B15/00: A46B15/00: Other brushes; Brushes with additional arrangements +
# A61C17/22: A61C17/22: Devices for cleaning, polishing, rinsing or drying teeth, teeth cavities or prostheses (instruments acting like a sandblast machine A61C0003025000;tooth polishing discs or holders therefor A61C0003060000;devices for cleaning between the teeth A61C0015000000); Saliva removers; Dental appliances for receiving spittle + with brushes, cushions, cups or the like (brush bodies, e.g. arrangements of the bristles, A46B)
# A45D29/11: A45D29/11: Manicuring or pedicuring implements + Polishing devices for nails
# A45D29/12: A45D29/12: Manicuring or pedicuring implements + manually operated
# A01N43/00: none
# C11D17/04: C11D17/04: Detergent materials or soaps characterised by their shape or physical properties (shaping soap C11D0013140000) + combined with or containing other objects
# C11D17/02: none
# B24B53/017: B24B53/017: Devices or means for dressing or conditioning abrasive surfaces + Devices or means for dressing, cleaning or otherwise conditioning lapping tools
